# %% [markdown]
# # Introduction
#
# ### Get NetworKIN Result Files (Ben)
#
# ### About the data (Ben)
# - Version:
# - NetworKIN result files contain the following columns:
#     - #Name
#     - Position
#     - Tree
#     - NetPhorest Group
#     - Kinase/Phosphatase/Phospho-binding domain
#     - NetworKIN score
#     - NetPhorest probability
#     - STRING score
#     - Target STRING ID
#     - Kinase/Phosphatase/Phospho-binding domain
#     - STRING ID
#     - Target description
#     - Kinase/Phosphatase/Phospho-binding domain description
#     - Target Name
#     - Kinase/Phosphatase/Phospho-binding domain Name
#     - Peptide sequence window
#     - Intermediate nodes
#
# ### Preprocessing NetworKIN Raw
# 1. Filtering Date: only keep the results of kinase prediction (TREE == 'KIN')
# 2. Mapping accessions:
#     - **Mapping substrate accessions:**  Get the UniprotID from the sequence identifiers of the original fasta files that submitted in NetworKIN for prediction.
#     - **Mapping kinase accessions:** get uniprotID for the kinases using 'Kinase/Phosphatase/Phospho-binding domain description' column
#         - correcting duplicated names found above
# 3. **Mapping sites:**
#     - formatting pep seq (e.g. ----MsGSKSV --> ____MSGSKSV)
#     - update 'site' if the orignal sequence submitted for perdiction is different from the reference sequence due to changes causing shift in position
#
# **Output Files Dataframe:**
# - **substrate_id:** unique IDs for the substrate phosphorylation site (substrate_acc + position)
# - **substrate_name:** substrate gene name used in NetworKIN
# - **substrate_acc:** substrate uniprotID
# - **site:** aa + position in protein sequence
# - **Position:** position in protein sequence
# - **pep:** +/- 5 AA
# - **kinase_name:** kinase name used in NetworKIN
# - **kinase_acc:** kinase uniprotID
# - **score:** NetworKIN score
#
#
#
# ### Creating Resource Files
# 1.  **'globalKinaseMap.csv':**
#     - creat a new or add unique kinases from NetworKIN to the globel substrate resource file.
#     - get and add the Kinase Name that would use across all perdictors for the kinases to the result files
#
# ### Standard Formatted NetworKIN
# **'NetworKIN_formatted.csv':** Standardize the preprocessed file with following columns:
# - **substrate_id** - unique IDs for the substrate phosphorylation site (substrate_acc + position)
# - **substrate_name** - gene name for the substrates
# - **substrate_acc** - mapped UniprotIDs for the substrates
# - **site** - phosphorylation  site
# - **pep** - +/- 5 AA peptide sequence around the site
# - **score**
# - **Kinase Name**

# %%
# IMPORTS
import pandas as pd
import os
import re
import glob

import humanProteomesReference, networKin_convert, getUniprotID, checkSite

#only need when testing the code
import time

# %%
# DEFINE FILE NAMES/DIRs
##################
# Version (Date) #
##################
version = '2019-12-11'

##################
# File Location  #
##################
# local (../../)
base = '../../'

##################################################
# For Prepare Fasta Files to Submit in NetworKIN #
##################################################

# Human Proteome fasta file
HP_fasta = base + 'Data/Raw/HumanProteome/humanProteome_' + version + '.fasta'
# Dir for splited Human Proteome fasta files
HP_dir = base + 'Data/Raw/HumanProteome/'

# human proteome referece file 
HP_csv = base + 'Data/Map/humanProteome_' + version + '.csv'

####################################################
# For Preprocessing NetworKIN Prediction Results   #
#--------------------------------------------------#
# . The files submitted for NetworKIN predictor is #
#   NOT the up-to-date human proteom sequences     #
# . There has been an update in human proteomes    #
#   from the time the perdiction results were got  #
#   to running the preporcessing steps.            #
####################################################

# NetworKIN results dir
NW_dir = base + 'Data/Raw/NetworKIN/'
NW_update_dir = base + 'Data/Raw/NetworKIN/updated/'
# NetworKIN temp dir
NW_temp_dir_acc = base + 'Data/Temp/NetworKIN/mappedAcc/'
NW_temp_dir_site = base + 'Data/Temp/NetworKIN/mappedSite/'
NW_temp_dir_acc_update = base + 'Data/Temp/NetworKIN/mappedAcc/updated/'
NW_temp_dir_site_update = base + 'Data/Temp/NetworKIN/mappedSite/updated/'

# Resource Files
HK_org = base + 'Data/Raw/HumanKinase/globalKinaseMap.txt'                  # orginal manually created kinase file
KinaseMap = base + 'Data/Map/globalKinaseMap.csv'                           # add all unique kinase in HPRD to the global file

# Standard formatted output file
NW_formatted = base + 'Data/Formatted/NetworKIN/NetworKIN_formatted_' + version + '.csv'       # preprocessed file with cloumns: substrate_id/substrate/substrate_acc/kinase/site/pep/score

# %% [markdown]
# # Preprocessing NetworKIN Raw

# %% [markdown]
# In the NetworKIN raw file, most of the names in the 'Kinase/Phosphatase/Phospho-binding domain' column can not use to retrieve the uniprotID for the kinase, but all the names in the 'Kinase/Phosphatase/Phospho-binding domain description' column can. However, there are different 'Kinase/Phosphatase/Phospho-binding domain' with the same 'Kinase/Phosphatase/Phospho-binding domain description'.  We need to identify those and correct them if need.

# %% [markdown]
# ### Get unique kinases in NetworKIN

# %%
all_results = glob.glob(NW_dir + '*.tsv')
#create empty df to store unique kinases
df_unique_kin = pd.DataFrame()
for filename in all_results:
    df = pd.read_csv(filename, usecols = ['Tree','Kinase/Phosphatase/Phospho-binding domain', 'Kinase/Phosphatase/Phospho-binding domain description'], sep = '\t')
    # the only type of perdiction we are intreseted in is 'KIN'
    df = df[df.Tree == 'KIN']
    df = df[['Kinase/Phosphatase/Phospho-binding domain', 'Kinase/Phosphatase/Phospho-binding domain description']].drop_duplicates()
    # append unique kinases found in each result files
    df_unique_kin = df_unique_kin.append(df)
    
# drop any duplicated kinases
df_unique_kin = df_unique_kin.drop_duplicates()
# get the  kinase(s) with the same domain description
duplicateRowsDF = df_unique_kin[df_unique_kin.duplicated(['Kinase/Phosphatase/Phospho-binding domain description'],keep=False)]
duplicateRowsDF.sort_values(['Kinase/Phosphatase/Phospho-binding domain description','Kinase/Phosphatase/Phospho-binding domain'])
# Out:
#      Kinase/Phosphatase/Phospho-binding domain  \
# 1459                                      MST2
# 1484                                      MST4
#
#      Kinase/Phosphatase/Phospho-binding domain description
# 1459                                               STK3
# 1484                                               STK3

# %% [markdown]
# After manually check for the above kinases, MST4 should associate with STK26 not STK3. Create a dictionary to correct that in the result files.

# %%
correct_kinase = {'MST4' : 'STK26'}

# %% [markdown]
# ### Mapping Accessions (UniprotID) and Site
# 1. Filtering Date: only keep the results of kinase prediction (TREE == 'KIN')
# 2. Mapping accessions:
#     - **Mapping substrate accessions:**  Get the UniprotID from the sequence identifiers of the original fasta files that submitted in NetworKIN for prediction.
#     - **Mapping kinase accessions:** get uniprotID for the kinases using 'Kinase/Phosphatase/Phospho-binding domain description' column
#         - correcting duplicated names found above
# 3. **Mapping sites:**
#     - formatting pep seq (e.g. ----MsGSKSV --> ____MSGSKSV)
#     - update 'site' if the orignal sequence submitted for perdiction is different from the reference sequence due to changes causing shift in position
#
# **Output Files Dataframe:**
# - **substrate_id:** unique IDs for the substrate phosphorylation site (substrate_acc + position)
# - **substrate_name:** substrate gene name used in NetworKIN
# - **substrate_acc:** substrate uniprotID
# - **site:** aa + position in protein sequence
# - **Position:** position in protein sequence
# - **pep:** +/- 5 AA
# - **kinase_name:** kinase name used in NetworKIN
# - **kinase_acc:** kinase uniprotID
# - **score:** NetworKIN score

# %% [markdown]
# **Mapping Accessions**

# %%
# convert substrate_acc and kinase_acc
convert_type = 'acc'
networKin_convert.kin_convert_directory(NW_dir, 'na', NW_temp_dir_acc, convert_type)
# Out:
# reading  19.tsv
# getting unique sub
# getting sub_acc
# merge
# done 2.626702308654785
# getting unique kin
# getting kin_acc
# merge
# done 240.26136994361877
# saving
# Done 30.140185832977295
# reading  18.tsv
# getting unique sub
# getting sub_acc
# merge
# done 3.2055108547210693
# getting unique kin
# getting kin_acc
# merge
# done 251.04621005058289
# saving
# Done 38.56568384170532
# reading  20.tsv
# getting unique sub
# getting sub_acc
# merge
# done 3.681636095046997
# getting unique kin
# getting kin_acc
# merge
# done 326.4341878890991
# saving
# Done 40.38838195800781
# reading  21.tsv
# getting unique sub
# getting sub_acc
# merge
# done 1.4215641021728516
# getting unique kin
# getting kin_acc
# merge
# done 316.3874821662903
# saving
# Done 17.19068193435669
# reading  8.tsv
# getting unique sub
# getting sub_acc
# merge
# done 2.9008588790893555
# getting unique kin
# getting kin_acc
# merge
# done 276.8457570075989
# saving
# Done 27.926394939422607
# reading  9.tsv
# getting unique sub
# getting sub_acc
# merge
# done 2.908118724822998
# getting unique kin
# getting kin_acc
# merge
# done 234.78508710861206
# saving
# Done 29.946862936019897
# reading  4.tsv
# getting unique sub
# getting sub_acc
# merge
# done 2.738868236541748
# getting unique kin
# getting kin_acc
# merge
# done 258.28015995025635
# saving
# Done 33.840609073638916
# reading  5.tsv
# /Users/bx2ur/opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3249: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   if (await self.run_code(code, result,  async_=asy)):
# getting unique sub
# getting sub_acc
# merge
# done 2.7888870239257812
# getting unique kin
# getting kin_acc
# merge
# done 221.8265450000763
# saving
# Done 30.584384202957153
# reading  7.tsv
# getting unique sub
# getting sub_acc
# merge
# done 2.604299783706665
# getting unique kin
# getting kin_acc
# merge
# done 260.0229811668396
# saving
# Done 30.57912302017212
# reading  6.tsv
# getting unique sub
# getting sub_acc
# merge
# done 2.8214480876922607
# getting unique kin
# getting kin_acc
# merge
# done 269.59356689453125
# saving
# Done 41.610522985458374
# reading  2.tsv
# getting unique sub
# getting sub_acc
# merge
# done 3.613402843475342
# getting unique kin
# getting kin_acc
# merge
# done 251.59176588058472
# saving
# Done 28.798696756362915
# reading  3.tsv
# getting unique sub
# getting sub_acc
# merge
# done 2.4144513607025146
# getting unique kin
# getting kin_acc
# merge
# done 231.33128333091736
# saving
# Done 27.983081817626953
# reading  1.tsv
# getting unique sub
# getting sub_acc
# merge
# done 3.1557531356811523
# getting unique kin
# getting kin_acc
# merge
# done 241.90413618087769
# saving
# Done 35.28415012359619
# reading  13.tsv
# getting unique sub
# getting sub_acc
# merge
# done 2.6958887577056885
# getting unique kin
# getting kin_acc
# merge
# done 189.60271501541138
# saving
# Done 31.429659128189087
# reading  12.tsv
# getting unique sub
# getting sub_acc
# merge
# done 2.2913639545440674
# getting unique kin
# getting kin_acc
# merge
# done 165.95220279693604
# saving
# Done 27.102283000946045
# reading  10.tsv
# getting unique sub
# getting sub_acc
# merge
# done 2.4888088703155518
# getting unique kin
# getting kin_acc
# merge
# done 178.1351387500763
# saving
# Done 28.785897254943848
# reading  11.tsv
# getting unique sub
# getting sub_acc
# merge
# done 3.0667738914489746
# getting unique kin
# getting kin_acc
# merge
# done 163.88767886161804
# saving
# Done 33.63276410102844
# reading  15.tsv
# getting unique sub
# getting sub_acc
# merge
# done 2.811354875564575
# getting unique kin
# getting kin_acc
# merge
# done 159.54417395591736
# saving
# Done 29.35686707496643
# reading  14.tsv
# getting unique sub
# getting sub_acc
# merge
# done 2.854167938232422
# getting unique kin
# getting kin_acc
# merge
# done 272.46155881881714
# saving
# Done 29.03964614868164
# reading  16.tsv
# getting unique sub
# getting sub_acc
# merge
# done 2.879138946533203
# getting unique kin
# getting kin_acc
# merge
# done 241.52677392959595
# saving
# Done 29.548176050186157
# reading  17.tsv
# getting unique sub
# getting sub_acc
# merge
# done 3.269611120223999
# getting unique kin
# getting kin_acc
# merge
# done 264.7191410064697
# saving
# Done 34.99608111381531

# %% [markdown]
# **Mapping Site**

# %%
# map the site to the updated (new) human proteome reference
convert_type = 'site'
networKin_convert.kin_convert_directory(NW_temp_dir_acc, HP_csv, NW_temp_dir_site, convert_type)
# Out:
# Set input file dir...
# done
# read the Human Proteome df...
# done
# processing  9 .tsv
# Get unique substrate sites in  9 .tsv
# P30988 :   corrected:  (seqNotFound)S4  site:  S4  seq len:  474 pep:  MQFSGEKIS
# P30988 :   corrected:  (seqNotFound)S9  site:  S9  seq len:  474 pep:  SGEKISGQRDL
# P30988 :   corrected:  (seqNotFound)S17  site:  S17  seq len:  474 pep:  RDLQKSKMRFT
# P30988 :   corrected:  (seqNotFound)T22  site:  T22  seq len:  474 pep:  SKMRFTFTSRC
# P30988 :   corrected:  (seqNotFound)T195  site:  T195  seq len:  474 pep:  FFRKLTTIFPL
# P30988 :   corrected:  (seqNotFound)T196  site:  T196  seq len:  474 pep:  FRKLTTIFPLN
# P30988 :   corrected:  (seqNotFound)Y204  site:  Y204  seq len:  474 pep:  PLNWKYRKALS
# P30988 :   corrected:  (seqNotFound)S209  site:  S209  seq len:  474 pep:  YRKALSLGCQR
# Q9BSG1 :   corrected:  (seqNotFound)S161  site:  S161  seq len:  425 pep:  LRRRRSALSRE
# Saving  9 .tsv
# 9 .tsv Done  256.96863174438477
# processing  8 .tsv
# Get unique substrate sites in  8 .tsv
# Q86VQ6 :   corrected:  (seqNotFound)T637  site:  T637  seq len:  643 pep:  SGLDITQKGCG
# O15015 :   corrected:  (seqNotFound)S1811  site:  S1811  seq len:  1832 pep:  QWRGKSSPKVG
# O15015 :   corrected:  (seqNotFound)S1812  site:  S1812  seq len:  1832 pep:  WRGKSSPKVGG
# O15015 :   corrected:  (seqNotFound)S1792  site:  S1792  seq len:  1832 pep:  WTVAGSGRGHE
# O15015 :   corrected:  (seqNotFound)S1799  site:  S1799  seq len:  1832 pep:  RGHEGSQEEVG
# O15015 :   corrected:  (seqNotFound)S1821  site:  S1821  seq len:  1832 pep:  GGGARSERREP
# O15015 :   corrected:  (seqNotFound)T1805  site:  T1805  seq len:  1832 pep:  QEEVGTQWRGK
# Saving  8 .tsv
# 8 .tsv Done  236.89893293380737
# processing  13 .tsv
# Get unique substrate sites in  13 .tsv
# P22352 :   corrected:  (seqNotFound)S71  site:  S71  seq len:  226 pep:  FVNVASYGLTG
# P22352 :   corrected:  (seqNotFound)Y72  site:  Y72  seq len:  226 pep:  VNVASYGLTGQ
# P22352 :   corrected:  (seqNotFound)T75  site:  T75  seq len:  226 pep:  ASYGLTGQYIE
# P26378 :   corrected:  (seqNotFound)S6  site:  S6  seq len:  385 pep:  MVMIISTMEPQ
# P26378 :   corrected:  (seqNotFound)T7  site:  T7  seq len:  385 pep:  VMIISTMEPQV
# P11509 :   corrected:  (seqNotFound)S397  site:  S397  seq len:  494 pep:  FPMLGSVLRDP
# P11509 :   corrected:  (seqNotFound)T389  site:  T389  seq len:  494 pep:  FLPKGTEVFPM
# Q92813 :   corrected:  (seqNotFound)S130  site:  S130  seq len:  273 pep:  VVNFGSATPPF
# Q92813 :   corrected:  (seqNotFound)T132  site:  T132  seq len:  273 pep:  NFGSATPPFTS
# Q92813 :   corrected:  (seqNotFound)S262  site:  S262  seq len:  273 pep:  LEKNFSKRKKT
# Q92813 :   corrected:  (seqNotFound)T136  site:  T136  seq len:  273 pep:  ATPPFTSQLPA
# Q92813 :   corrected:  (seqNotFound)S137  site:  S137  seq len:  273 pep:  TPPFTSQLPAF
# Q92813 :   corrected:  (seqNotFound)T267  site:  T267  seq len:  273 pep:  SKRKKTRLAG
# P55073 :   corrected:  (seqNotFound)S167  site:  S167  seq len:  304 pep:  VLNFGSCTPPF
# P55073 :   corrected:  (seqNotFound)T169  site:  T169  seq len:  304 pep:  NFGSCTPPFMA
# Saving  13 .tsv
# 13 .tsv Done  276.87454080581665
# processing  12 .tsv
# Get unique substrate sites in  12 .tsv
# Q9UBA6 :   corrected:  (idNotFound)S64  site:  S64 pep:  LSCVSSCHLIG
# Q9UBA6 :   corrected:  (idNotFound)S33  site:  S33 pep:  HACSPSLLWNL
# Q9UBA6 :   corrected:  (idNotFound)S4  site:  S4 pep:  MERSFVWLS
# Q9UBA6 :   corrected:  (idNotFound)T40  site:  T40 pep:  LWNLLTQYLPP
# Q9UBA6 :   corrected:  (idNotFound)S9  site:  S9 pep:  SFVWLSCLDSD
# Q9UBA6 :   corrected:  (idNotFound)Y42  site:  Y42 pep:  NLLTQYLPPGA
# Q9UBA6 :   corrected:  (idNotFound)S13  site:  S13 pep:  LSCLDSDSCNL
# Q9UBA6 :   corrected:  (idNotFound)S63  site:  S63 pep:  VLSCVSSCHLI
# Q9UBA6 :   corrected:  (idNotFound)S15  site:  S15 pep:  CLDSDSCNLTF
# Q9UBA6 :   corrected:  (idNotFound)T19  site:  T19 pep:  DSCNLTFRLGE
# Q9UBA6 :   corrected:  (idNotFound)T53  site:  T53 pep:  GHILRTYNFPV
# Q9UBA6 :   corrected:  (idNotFound)Y54  site:  Y54 pep:  HILRTYNFPVL
# Q9UBA6 :   corrected:  (idNotFound)S27  site:  S27 pep:  LGEVESHACSP
# Q9UBA6 :   corrected:  (idNotFound)S60  site:  S60 pep:  NFPVLSCVSSC
# Q9UBA6 :   corrected:  (idNotFound)S31  site:  S31 pep:  ESHACSPSLLW
# Q53TQ3 :   corrected:  (seqNotFound)Y865  site:  Y865  seq len:  1027 pep:  VCFRGYHRPAS
# Q53TQ3 :   corrected:  (seqNotFound)S870  site:  S870  seq len:  1027 pep:  YHRPASVAWGL
# Q5JXX5 :   corrected:  (idNotFound)Y257  site:  Y257 pep:  ERQMGYYLIQM
# Q5JXX5 :   corrected:  (idNotFound)T2  site:  T2 pep:  MTTLVPA
# Q5JXX5 :   corrected:  (idNotFound)T3  site:  T3 pep:  MTTLVPAT
# Q5JXX5 :   corrected:  (idNotFound)Y263  site:  Y263 pep:  YLIQMYIPSLL
# Q5JXX5 :   corrected:  (idNotFound)T8  site:  T8 pep:  TLVPATLSFLL
# Q5JXX5 :   corrected:  (idNotFound)S393  site:  S393 pep:  GPMEGSGIYSP
# Q5JXX5 :   corrected:  (idNotFound)S10  site:  S10 pep:  VPATLSFLLLW
# Q5JXX5 :   corrected:  (idNotFound)S343  site:  S343 pep:  AINFVSRQHKE
# Q5JXX5 :   corrected:  (idNotFound)Y396  site:  Y396 pep:  EGSGIYSPQPP
# Q5JXX5 :   corrected:  (idNotFound)Y258  site:  Y258 pep:  RQMGYYLIQMY
# Q5JXX5 :   corrected:  (idNotFound)Y237  site:  Y237 pep:  CCTKHYNTGKF
# Q5JXX5 :   corrected:  (idNotFound)T16  site:  T16 pep:  FLLLWTLPGQV
# Q5JXX5 :   corrected:  (idNotFound)S273  site:  S273 pep:  LIVILSWVSFW
# Q5JXX5 :   corrected:  (idNotFound)T146  site:  T146 pep:  NFHEVTTDNKL
# Q5JXX5 :   corrected:  (idNotFound)T147  site:  T147 pep:  FHEVTTDNKLL
# Q5JXX5 :   corrected:  (idNotFound)S276  site:  S276 pep:  ILSWVSFWINM
# Q5JXX5 :   corrected:  (idNotFound)S171  site:  S171 pep:  LTLILSCLMDL
# Q5JXX5 :   corrected:  (idNotFound)T299  site:  T299 pep:  TVLTMTTQSSG
# Q5JXX5 :   corrected:  (idNotFound)T410  site:  T410 pep:  LREGETTRKLY
# Q5JXX5 :   corrected:  (idNotFound)T411  site:  T411 pep:  REGETTRKLYV
# Q5JXX5 :   corrected:  (idNotFound)Y415  site:  Y415 pep:  TTRKLYVD
# Q5JXX5 :   corrected:  (idNotFound)S34  site:  S34 pep:  KEEVKSGTKGS
# Q5JXX5 :   corrected:  (idNotFound)S163  site:  S163 pep:  GNVLYSIRLTL
# Q5JXX5 :   corrected:  (idNotFound)T36  site:  T36 pep:  EVKSGTKGSQP
# Q5JXX5 :   corrected:  (idNotFound)T293  site:  T293 pep:  VGLGITTVLTM
# Q5JXX5 :   corrected:  (idNotFound)T294  site:  T294 pep:  GLGITTVLTMT
# Q5JXX5 :   corrected:  (idNotFound)S39  site:  S39 pep:  SGTKGSQPMSP
# Q5JXX5 :   corrected:  (idNotFound)T297  site:  T297 pep:  ITTVLTMTTQS
# Q5JXX5 :   corrected:  (idNotFound)S43  site:  S43 pep:  GSQPMSPSDFL
# Q5JXX5 :   corrected:  (idNotFound)T300  site:  T300 pep:  VLTMTTQSSGS
# Q5JXX5 :   corrected:  (idNotFound)S45  site:  S45 pep:  QPMSPSDFLDK
# Q5JXX5 :   corrected:  (idNotFound)S302  site:  S302 pep:  TMTTQSSGSRA
# Q5JXX5 :   corrected:  (idNotFound)S303  site:  S303 pep:  MTTQSSGSRAS
# Q5JXX5 :   corrected:  (idNotFound)S305  site:  S305 pep:  TQSSGSRASLP
# Q5JXX5 :   corrected:  (idNotFound)S308  site:  S308 pep:  SGSRASLPKVS
# Q5JXX5 :   corrected:  (idNotFound)T55  site:  T55 pep:  KLMGRTSGYDA
# Q5JXX5 :   corrected:  (idNotFound)S56  site:  S56 pep:  LMGRTSGYDAR
# Q5JXX5 :   corrected:  (idNotFound)T185  site:  T185 pep:  PMDIQTCTMQL
# Q5JXX5 :   corrected:  (idNotFound)Y58  site:  Y58 pep:  GRTSGYDARIR
# Q5JXX5 :   corrected:  (idNotFound)T187  site:  T187 pep:  DIQTCTMQLES
# Q5JXX5 :   corrected:  (idNotFound)S266  site:  S266 pep:  QMYIPSLLIVI
# Q5JXX5 :   corrected:  (idNotFound)S192  site:  S192 pep:  TMQLESFGYTM
# Q5JXX5 :   corrected:  (idNotFound)Y195  site:  Y195 pep:  LESFGYTMKDL
# Q5JXX5 :   corrected:  (idNotFound)T196  site:  T196 pep:  ESFGYTMKDLV
# Q5JXX5 :   corrected:  (idNotFound)T74  site:  T74 pep:  PPVNVTCNIFI
# Q5JXX5 :   corrected:  (idNotFound)Y162  site:  Y162 pep:  NGNVLYSIRLT
# Q5JXX5 :   corrected:  (idNotFound)Y372  site:  Y372 pep:  QESRFYFRGYG
# Q5JXX5 :   corrected:  (idNotFound)S397  site:  S397 pep:  GSGIYSPQPPA
# Q5JXX5 :   corrected:  (idNotFound)Y336  site:  Y336 pep:  AALLEYAAINF
# Q5JXX5 :   corrected:  (idNotFound)S81  site:  S81 pep:  NIFINSFSSIT
# Q5JXX5 :   corrected:  (idNotFound)S83  site:  S83 pep:  FINSFSSITKT
# Q5JXX5 :   corrected:  (idNotFound)S84  site:  S84 pep:  INSFSSITKTT
# Q5JXX5 :   corrected:  (idNotFound)T86  site:  T86 pep:  SFSSITKTTMD
# Q5JXX5 :   corrected:  (idNotFound)S313  site:  S313 pep:  SLPKVSYVKAI
# Q5JXX5 :   corrected:  (idNotFound)T88  site:  T88 pep:  SSITKTTMDYR
# Q5JXX5 :   corrected:  (idNotFound)T89  site:  T89 pep:  SITKTTMDYRV
# Q5JXX5 :   corrected:  (idNotFound)T218  site:  T218 pep:  VAEGLTLPQFI
# Q5JXX5 :   corrected:  (idNotFound)Y92  site:  Y92 pep:  KTTMDYRVNVF
# Q5JXX5 :   corrected:  (idNotFound)Y314  site:  Y314 pep:  LPKVSYVKAID
# Q5JXX5 :   corrected:  (idNotFound)T234  site:  T234 pep:  DLGCCTKHYNT
# Q5JXX5 :   corrected:  (idNotFound)T167  site:  T167 pep:  YSIRLTLILSC
# Q5JXX5 :   corrected:  (idNotFound)S108  site:  S108 pep:  NDPRLSYREYP
# Q5JXX5 :   corrected:  (idNotFound)Y109  site:  Y109 pep:  DPRLSYREYPD
# Q5JXX5 :   corrected:  (idNotFound)T239  site:  T239 pep:  TKHYNTGKFTC
# Q5JXX5 :   corrected:  (idNotFound)Y112  site:  Y112 pep:  LSYREYPDDSL
# Q5JXX5 :   corrected:  (idNotFound)S369  site:  S369 pep:  DIIQESRFYFR
# Q5JXX5 :   corrected:  (idNotFound)T243  site:  T243 pep:  NTGKFTCIEVK
# Q5JXX5 :   corrected:  (idNotFound)S116  site:  S116 pep:  EYPDDSLDLDP
# Q5JXX5 :   corrected:  (idNotFound)Y376  site:  Y376 pep:  FYFRGYGLGHC
# Q5JXX5 :   corrected:  (idNotFound)S122  site:  S122 pep:  LDLDPSMLDSI
# Q5JXX5 :   corrected:  (idNotFound)S126  site:  S126 pep:  PSMLDSIWKPD
# Saving  12 .tsv
# 12 .tsv Done  227.0921070575714
# processing  10 .tsv
# Get unique substrate sites in  10 .tsv
# Q6P4E1 :   corrected:  (seqNotFound)T424  site:  T424  seq len:  436 pep:  GLHAITMKPTS
# Q6P4E1 :   corrected:  (seqNotFound)T428  site:  T428  seq len:  436 pep:  ITMKPTSKFFG
# Q6P4E1 :   corrected:  (seqNotFound)S429  site:  S429  seq len:  436 pep:  TMKPTSKFFG
# P05534 :   corrected:  (idNotFound)S129  site:  S129 pep:  GCDVGSDGRFL
# P05534 :   corrected:  (idNotFound)T257  site:  T257 pep:  TELVETRPAGD
# P05534 :   corrected:  (idNotFound)T8  site:  T8 pep:  VMAPRTLVLLL
# P05534 :   corrected:  (idNotFound)Y137  site:  Y137 pep:  RFLRGYHQYAY
# P05534 :   corrected:  (idNotFound)Y140  site:  Y140 pep:  RGYHQYAYDGK
# P05534 :   corrected:  (idNotFound)S14  site:  S14 pep:  LVLLLSGALAL
# P05534 :   corrected:  (idNotFound)S301  site:  S301 pep:  LRWEPSSQPTV
# P05534 :   corrected:  (idNotFound)Y344  site:  Y344 pep:  RKGGSYSQAAS
# P05534 :   corrected:  (idNotFound)Y147  site:  Y147 pep:  YDGKDYIALKE
# P05534 :   corrected:  (idNotFound)T20  site:  T20 pep:  GALALTQTWAG
# P05534 :   corrected:  (idNotFound)T22  site:  T22 pep:  LALTQTWAGSH
# P05534 :   corrected:  (idNotFound)Y281  site:  Y281 pep:  GEEQRYTCHVQ
# P05534 :   corrected:  (idNotFound)S26  site:  S26 pep:  QTWAGSHSMRY
# P05534 :   corrected:  (idNotFound)S28  site:  S28 pep:  WAGSHSMRYFS
# P05534 :   corrected:  (idNotFound)T282  site:  T282 pep:  EEQRYTCHVQH
# P05534 :   corrected:  (idNotFound)T158  site:  T158 pep:  DLRSWTAADMA
# P05534 :   corrected:  (idNotFound)Y31  site:  Y31 pep:  SHSMRYFSTSV
# P05534 :   corrected:  (idNotFound)S33  site:  S33 pep:  SMRYFSTSVSR
# P05534 :   corrected:  (idNotFound)T34  site:  T34 pep:  MRYFSTSVSRP
# P05534 :   corrected:  (idNotFound)S35  site:  S35 pep:  RYFSTSVSRPG
# P05534 :   corrected:  (idNotFound)S37  site:  S37 pep:  FSTSVSRPGRG
# P05534 :   corrected:  (idNotFound)T167  site:  T167 pep:  MAAQITKRKWE
# P05534 :   corrected:  (idNotFound)S156  site:  S156 pep:  KEDLRSWTAAD
# P05534 :   corrected:  (idNotFound)T240  site:  T240 pep:  AEITLTWQRDG
# P05534 :   corrected:  (idNotFound)S302  site:  S302 pep:  RWEPSSQPTVP
# P05534 :   corrected:  (idNotFound)T264  site:  T264 pep:  PAGDGTFQKWA
# P05534 :   corrected:  (idNotFound)Y51  site:  Y51 pep:  FIAVGYVDDTQ
# P05534 :   corrected:  (idNotFound)T55  site:  T55 pep:  GYVDDTQFVRF
# P05534 :   corrected:  (idNotFound)T187  site:  T187 pep:  AYLEGTCVDGL
# P05534 :   corrected:  (idNotFound)S62  site:  S62 pep:  FVRFDSDAASQ
# P05534 :   corrected:  (idNotFound)S352  site:  S352 pep:  AASSDSAQGSD
# P05534 :   corrected:  (idNotFound)S66  site:  S66 pep:  DSDAASQRMEP
# P05534 :   corrected:  (idNotFound)Y195  site:  Y195 pep:  DGLRRYLENGK
# P05534 :   corrected:  (idNotFound)S275  site:  S275 pep:  AVVVPSGEEQR
# P05534 :   corrected:  (idNotFound)T202  site:  T202 pep:  ENGKETLQRTD
# P05534 :   corrected:  (idNotFound)Y183  site:  Y183 pep:  EQQRAYLEGTC
# P05534 :   corrected:  (idNotFound)T305  site:  T305 pep:  PSSQPTVPIVG
# P05534 :   corrected:  (idNotFound)T206  site:  T206 pep:  ETLQRTDPPKT
# P05534 :   corrected:  (idNotFound)S336  site:  S336 pep:  MWRRNSSDRKG
# P05534 :   corrected:  (idNotFound)S337  site:  S337 pep:  WRRNSSDRKGG
# P05534 :   corrected:  (idNotFound)Y83  site:  Y83 pep:  QEGPEYWDEET
# P05534 :   corrected:  (idNotFound)Y142  site:  Y142 pep:  YHQYAYDGKDY
# P05534 :   corrected:  (idNotFound)T214  site:  T214 pep:  PKTHMTHHPIS
# P05534 :   corrected:  (idNotFound)S343  site:  S343 pep:  DRKGGSYSQAA
# P05534 :   corrected:  (idNotFound)T88  site:  T88 pep:  YWDEETGKVKA
# P05534 :   corrected:  (idNotFound)S345  site:  S345 pep:  KGGSYSQAASS
# P05534 :   corrected:  (idNotFound)S219  site:  S219 pep:  THHPISDHEAT
# P05534 :   corrected:  (idNotFound)S349  site:  S349 pep:  YSQAASSDSAQ
# P05534 :   corrected:  (idNotFound)S350  site:  S350 pep:  SQAASSDSAQG
# P05534 :   corrected:  (idNotFound)S95  site:  S95 pep:  KVKAHSQTDRE
# P05534 :   corrected:  (idNotFound)T224  site:  T224 pep:  SDHEATLRCWA
# P05534 :   corrected:  (idNotFound)T97  site:  T97 pep:  KAHSQTDRENL
# P05534 :   corrected:  (idNotFound)S356  site:  S356 pep:  DSAQGSDVSLT
# P05534 :   corrected:  (idNotFound)S359  site:  S359 pep:  QGSDVSLTACK
# P05534 :   corrected:  (idNotFound)Y233  site:  Y233 pep:  WALGFYPAEIT
# P05534 :   corrected:  (idNotFound)T323  site:  T323 pep:  LGAVITGAVVA
# P05534 :   corrected:  (idNotFound)T295  site:  T295 pep:  LPKPLTLRWEP
# P05534 :   corrected:  (idNotFound)Y108  site:  Y108 pep:  RIALRYYNQSE
# P05534 :   corrected:  (idNotFound)Y109  site:  Y109 pep:  IALRYYNQSEA
# P05534 :   corrected:  (idNotFound)T238  site:  T238 pep:  YPAEITLTWQR
# P05534 :   corrected:  (idNotFound)S112  site:  S112 pep:  RYYNQSEAGSH
# P05534 :   corrected:  (idNotFound)T211  site:  T211 pep:  TDPPKTHMTHH
# P05534 :   corrected:  (idNotFound)S116  site:  S116 pep:  QSEAGSHTLQM
# P05534 :   corrected:  (idNotFound)T118  site:  T118 pep:  EAGSHTLQMMF
# P05534 :   corrected:  (idNotFound)T361  site:  T361 pep:  SDVSLTACKV
# P05534 :   corrected:  (idNotFound)T249  site:  T249 pep:  DGEDQTQDTEL
# P05534 :   corrected:  (idNotFound)T252  site:  T252 pep:  DQTQDTELVET
# Q95604 :   corrected:  (idNotFound)T257  site:  T257 pep:  TELVETRPAGD
# Q95604 :   corrected:  (idNotFound)S363  site:  S363 pep:  NSAQGSDESLI
# Q95604 :   corrected:  (idNotFound)T264  site:  T264 pep:  PAGDGTFQKWA
# Q95604 :   corrected:  (idNotFound)Y137  site:  Y137 pep:  RLLRGYNQFAY
# Q95604 :   corrected:  (idNotFound)S14  site:  S14 pep:  LLLLLSGALAL
# Q95604 :   corrected:  (idNotFound)S301  site:  S301 pep:  LRWKPSSQPTI
# Q95604 :   corrected:  (idNotFound)S344  site:  S344 pep:  HRRKSSGGKGG
# Q95604 :   corrected:  (idNotFound)Y147  site:  Y147 pep:  YDGKDYIALNE
# Q95604 :   corrected:  (idNotFound)S366  site:  S366 pep:  QGSDESLIACK
# Q95604 :   corrected:  (idNotFound)T22  site:  T22 pep:  LALIETWAGSH
# Q95604 :   corrected:  (idNotFound)Y281  site:  Y281 pep:  GQEQRYTCHVQ
# Q95604 :   corrected:  (idNotFound)S26  site:  S26 pep:  ETWAGSHSMRY
# Q95604 :   corrected:  (idNotFound)S28  site:  S28 pep:  WAGSHSMRYFY
# Q95604 :   corrected:  (idNotFound)T282  site:  T282 pep:  QEQRYTCHVQH
# Q95604 :   corrected:  (idNotFound)T158  site:  T158 pep:  DLRSWTAADTA
# Q95604 :   corrected:  (idNotFound)Y31  site:  Y31 pep:  SHSMRYFYTAV
# Q95604 :   corrected:  (idNotFound)Y33  site:  Y33 pep:  SMRYFYTAVSR
# Q95604 :   corrected:  (idNotFound)T34  site:  T34 pep:  MRYFYTAVSRP
# Q95604 :   corrected:  (idNotFound)S219  site:  S219 pep:  THHPVSDHEAT
# Q95604 :   corrected:  (idNotFound)S37  site:  S37 pep:  FYTAVSRPGRG
# Q95604 :   corrected:  (idNotFound)S167  site:  S167 pep:  TAAQISQRKLE
# Q95604 :   corrected:  (idNotFound)S156  site:  S156 pep:  NEDLRSWTAAD
# Q95604 :   corrected:  (idNotFound)T240  site:  T240 pep:  AEITLTWQRDG
# Q95604 :   corrected:  (idNotFound)S302  site:  S302 pep:  RWKPSSQPTIP
# Q95604 :   corrected:  (idNotFound)T305  site:  T305 pep:  PSSQPTIPNLG
# Q95604 :   corrected:  (idNotFound)Y51  site:  Y51 pep:  FIAVGYVDDTQ
# Q95604 :   corrected:  (idNotFound)T55  site:  T55 pep:  GYVDDTQFVRF
# Q95604 :   corrected:  (idNotFound)S313  site:  S313 pep:  NLGIVSGPAVL
# Q95604 :   corrected:  (idNotFound)S62  site:  S62 pep:  FVRFDSDAASP
# Q95604 :   corrected:  (idNotFound)S352  site:  S352 pep:  KGGSCSQAASS
# Q95604 :   corrected:  (idNotFound)S66  site:  S66 pep:  DSDAASPRGEP
# Q95604 :   corrected:  (idNotFound)Y195  site:  Y195 pep:  EWLRGYLENGK
# Q95604 :   corrected:  (idNotFound)S275  site:  S275 pep:  AVVVPSGQEQR
# Q95604 :   corrected:  (idNotFound)T202  site:  T202 pep:  ENGKETLQRAE
# Q95604 :   corrected:  (idNotFound)Y183  site:  Y183 pep:  EQLRAYLEGEC
# Q95604 :   corrected:  (idNotFound)T162  site:  T162 pep:  WTAADTAAQIS
# Q95604 :   corrected:  (idNotFound)Y83  site:  Y83 pep:  QEGPEYWDRET
# Q95604 :   corrected:  (idNotFound)Y142  site:  Y142 pep:  YNQFAYDGKDY
# Q95604 :   corrected:  (idNotFound)T214  site:  T214 pep:  PKTHVTHHPVS
# Q95604 :   corrected:  (idNotFound)S343  site:  S343 pep:  IHRRKSSGGKG
# Q95604 :   corrected:  (idNotFound)T88  site:  T88 pep:  YWDRETQKYKR
# Q95604 :   corrected:  (idNotFound)Y91  site:  Y91 pep:  RETQKYKRQAQ
# Q95604 :   corrected:  (idNotFound)S350  site:  S350 pep:  GGKGGSCSQAA
# Q95604 :   corrected:  (idNotFound)T224  site:  T224 pep:  SDHEATLRCWA
# Q95604 :   corrected:  (idNotFound)S356  site:  S356 pep:  CSQAASSNSAQ
# Q95604 :   corrected:  (idNotFound)S357  site:  S357 pep:  SQAASSNSAQG
# Q95604 :   corrected:  (idNotFound)S359  site:  S359 pep:  AASSNSAQGSD
# Q95604 :   corrected:  (idNotFound)Y233  site:  Y233 pep:  WALGFYPAEIT
# Q95604 :   corrected:  (idNotFound)T295  site:  T295 pep:  LQEPCTLRWKP
# Q95604 :   corrected:  (idNotFound)Y108  site:  Y108 pep:  RKLRGYYNQSE
# Q95604 :   corrected:  (idNotFound)Y109  site:  Y109 pep:  KLRGYYNQSEA
# Q95604 :   corrected:  (idNotFound)T238  site:  T238 pep:  YPAEITLTWQR
# Q95604 :   corrected:  (idNotFound)S112  site:  S112 pep:  GYYNQSEAGSH
# Q95604 :   corrected:  (idNotFound)T211  site:  T211 pep:  AERPKTHVTHH
# Q95604 :   corrected:  (idNotFound)S116  site:  S116 pep:  QSEAGSHTIQR
# Q95604 :   corrected:  (idNotFound)T118  site:  T118 pep:  EAGSHTIQRMY
# Q95604 :   corrected:  (idNotFound)T249  site:  T249 pep:  DGEDQTQDTEL
# Q95604 :   corrected:  (idNotFound)Y123  site:  Y123 pep:  TIQRMYGCDLG
# Q95604 :   corrected:  (idNotFound)T252  site:  T252 pep:  DQTQDTELVET
# P30457 :   corrected:  (idNotFound)T257  site:  T257 pep:  TELVETRPAGD
# P30457 :   corrected:  (idNotFound)T8  site:  T8 pep:  VMAPRTLVLLL
# P30457 :   corrected:  (idNotFound)Y137  site:  Y137 pep:  RFLRGYQQDAY
# P30457 :   corrected:  (idNotFound)S14  site:  S14 pep:  LVLLLSGALAL
# P30457 :   corrected:  (idNotFound)S301  site:  S301 pep:  LRWEPSSQPTI
# P30457 :   corrected:  (idNotFound)Y344  site:  Y344 pep:  RKGGSYSQAAS
# P30457 :   corrected:  (idNotFound)Y147  site:  Y147 pep:  YDGKDYIALNE
# P30457 :   corrected:  (idNotFound)T20  site:  T20 pep:  GALALTQTWAG
# P30457 :   corrected:  (idNotFound)T22  site:  T22 pep:  LALTQTWAGSH
# P30457 :   corrected:  (idNotFound)Y281  site:  Y281 pep:  GQEQRYTCHVQ
# P30457 :   corrected:  (idNotFound)S26  site:  S26 pep:  QTWAGSHSMRY
# P30457 :   corrected:  (idNotFound)S28  site:  S28 pep:  WAGSHSMRYFY
# P30457 :   corrected:  (idNotFound)T282  site:  T282 pep:  QEQRYTCHVQH
# P30457 :   corrected:  (idNotFound)T158  site:  T158 pep:  DLRSWTAADMA
# P30457 :   corrected:  (idNotFound)Y31  site:  Y31 pep:  SHSMRYFYTSV
# P30457 :   corrected:  (idNotFound)Y33  site:  Y33 pep:  SMRYFYTSVSR
# P30457 :   corrected:  (idNotFound)T34  site:  T34 pep:  MRYFYTSVSRP
# P30457 :   corrected:  (idNotFound)S35  site:  S35 pep:  RYFYTSVSRPG
# P30457 :   corrected:  (idNotFound)S37  site:  S37 pep:  FYTSVSRPGRG
# P30457 :   corrected:  (idNotFound)T167  site:  T167 pep:  MAAQITQRKWE
# P30457 :   corrected:  (idNotFound)S156  site:  S156 pep:  NEDLRSWTAAD
# P30457 :   corrected:  (idNotFound)T173  site:  T173 pep:  QRKWETAHEAE
# P30457 :   corrected:  (idNotFound)S302  site:  S302 pep:  RWEPSSQPTIP
# P30457 :   corrected:  (idNotFound)S359  site:  S359 pep:  QGSDMSLTACK
# P30457 :   corrected:  (idNotFound)T264  site:  T264 pep:  PAGDGTFQKWA
# P30457 :   corrected:  (idNotFound)S270  site:  S270 pep:  FQKWASVVVPS
# P30457 :   corrected:  (idNotFound)Y51  site:  Y51 pep:  FIAVGYVDDTQ
# P30457 :   corrected:  (idNotFound)T55  site:  T55 pep:  GYVDDTQFVRF
# P30457 :   corrected:  (idNotFound)S62  site:  S62 pep:  FVRFDSDAASQ
# P30457 :   corrected:  (idNotFound)S352  site:  S352 pep:  AASSDSAQGSD
# P30457 :   corrected:  (idNotFound)S66  site:  S66 pep:  DSDAASQRMEP
# P30457 :   corrected:  (idNotFound)Y195  site:  Y195 pep:  EWLRRYLENGK
# P30457 :   corrected:  (idNotFound)S275  site:  S275 pep:  SVVVPSGQEQR
# P30457 :   corrected:  (idNotFound)T202  site:  T202 pep:  ENGKETLQRTD
# P30457 :   corrected:  (idNotFound)Y183  site:  Y183 pep:  EQWRAYLEGRC
# P30457 :   corrected:  (idNotFound)T305  site:  T305 pep:  PSSQPTIPIVG
# P30457 :   corrected:  (idNotFound)T206  site:  T206 pep:  ETLQRTDAPKT
# P30457 :   corrected:  (idNotFound)S336  site:  S336 pep:  MWRRKSSDRKG
# P30457 :   corrected:  (idNotFound)S337  site:  S337 pep:  WRRKSSDRKGG
# P30457 :   corrected:  (idNotFound)Y83  site:  Y83 pep:  QEGPEYWDRNT
# P30457 :   corrected:  (idNotFound)Y142  site:  Y142 pep:  YQQDAYDGKDY
# P30457 :   corrected:  (idNotFound)T214  site:  T214 pep:  PKTHMTHHAVS
# P30457 :   corrected:  (idNotFound)S343  site:  S343 pep:  DRKGGSYSQAA
# P30457 :   corrected:  (idNotFound)T88  site:  T88 pep:  YWDRNTRNVKA
# P30457 :   corrected:  (idNotFound)S345  site:  S345 pep:  KGGSYSQAASS
# P30457 :   corrected:  (idNotFound)S219  site:  S219 pep:  THHAVSDHEAT
# P30457 :   corrected:  (idNotFound)S349  site:  S349 pep:  YSQAASSDSAQ
# P30457 :   corrected:  (idNotFound)S350  site:  S350 pep:  SQAASSDSAQG
# P30457 :   corrected:  (idNotFound)S95  site:  S95 pep:  NVKAQSQTDRV
# P30457 :   corrected:  (idNotFound)T224  site:  T224 pep:  SDHEATLRCWA
# P30457 :   corrected:  (idNotFound)T97  site:  T97 pep:  KAQSQTDRVDL
# P30457 :   corrected:  (idNotFound)T240  site:  T240 pep:  AEITLTWQRDG
# P30457 :   corrected:  (idNotFound)S356  site:  S356 pep:  DSAQGSDMSLT
# P30457 :   corrected:  (idNotFound)S231  site:  S231 pep:  RCWALSFYPAE
# P30457 :   corrected:  (idNotFound)T104  site:  T104 pep:  RVDLGTLRGYY
# P30457 :   corrected:  (idNotFound)Y233  site:  Y233 pep:  WALSFYPAEIT
# P30457 :   corrected:  (idNotFound)T295  site:  T295 pep:  LPKPLTLRWEP
# P30457 :   corrected:  (idNotFound)Y108  site:  Y108 pep:  GTLRGYYNQSE
# P30457 :   corrected:  (idNotFound)Y109  site:  Y109 pep:  TLRGYYNQSED
# P30457 :   corrected:  (idNotFound)T238  site:  T238 pep:  YPAEITLTWQR
# P30457 :   corrected:  (idNotFound)S112  site:  S112 pep:  GYYNQSEDGSH
# P30457 :   corrected:  (idNotFound)T211  site:  T211 pep:  TDAPKTHMTHH
# P30457 :   corrected:  (idNotFound)S116  site:  S116 pep:  QSEDGSHTIQR
# P30457 :   corrected:  (idNotFound)T118  site:  T118 pep:  EDGSHTIQRMY
# P30457 :   corrected:  (idNotFound)T361  site:  T361 pep:  SDMSLTACKV
# P30457 :   corrected:  (idNotFound)T249  site:  T249 pep:  DGEDQTQDTEL
# P30457 :   corrected:  (idNotFound)Y123  site:  Y123 pep:  TIQRMYGCDVG
# P30457 :   corrected:  (idNotFound)T252  site:  T252 pep:  DQTQDTELVET
# P04222 :   corrected:  (idNotFound)T257  site:  T257 pep:  TELVETRPAGD
# P04222 :   corrected:  (idNotFound)T305  site:  T305 pep:  PSSQPTIPIVG
# P04222 :   corrected:  (idNotFound)T8  site:  T8 pep:  VMAPRTLILLL
# P04222 :   corrected:  (idNotFound)Y137  site:  Y137 pep:  RLLRGYDQYAY
# P04222 :   corrected:  (idNotFound)Y140  site:  Y140 pep:  RGYDQYAYDGK
# P04222 :   corrected:  (idNotFound)S14  site:  S14 pep:  LILLLSGALAL
# P04222 :   corrected:  (idNotFound)S301  site:  S301 pep:  LRWEPSSQPTI
# P04222 :   corrected:  (idNotFound)S344  site:  S344 pep:  GGKGGSCSQAA
# P04222 :   corrected:  (idNotFound)Y147  site:  Y147 pep:  YDGKDYIALNE
# P04222 :   corrected:  (idNotFound)T20  site:  T20 pep:  GALALTETWAG
# P04222 :   corrected:  (idNotFound)T22  site:  T22 pep:  LALTETWAGSH
# P04222 :   corrected:  (idNotFound)Y281  site:  Y281 pep:  GEEQRYTCHVQ
# P04222 :   corrected:  (idNotFound)S26  site:  S26 pep:  ETWAGSHSMRY
# P04222 :   corrected:  (idNotFound)S28  site:  S28 pep:  WAGSHSMRYFY
# P04222 :   corrected:  (idNotFound)T282  site:  T282 pep:  EEQRYTCHVQH
# P04222 :   corrected:  (idNotFound)T158  site:  T158 pep:  DLRSWTAADTA
# P04222 :   corrected:  (idNotFound)Y31  site:  Y31 pep:  SHSMRYFYTAV
# P04222 :   corrected:  (idNotFound)Y33  site:  Y33 pep:  SMRYFYTAVSR
# P04222 :   corrected:  (idNotFound)T34  site:  T34 pep:  MRYFYTAVSRP
# P04222 :   corrected:  (idNotFound)S219  site:  S219 pep:  THHPVSDHEAT
# P04222 :   corrected:  (idNotFound)S37  site:  S37 pep:  FYTAVSRPGRG
# P04222 :   corrected:  (idNotFound)T167  site:  T167 pep:  TAAQITQRKWE
# P04222 :   corrected:  (idNotFound)S156  site:  S156 pep:  NEDLRSWTAAD
# P04222 :   corrected:  (idNotFound)T240  site:  T240 pep:  AEITLTWQWDG
# P04222 :   corrected:  (idNotFound)S302  site:  S302 pep:  RWEPSSQPTIP
# P04222 :   corrected:  (idNotFound)T264  site:  T264 pep:  PAGDGTFQKWA
# P04222 :   corrected:  (idNotFound)Y51  site:  Y51 pep:  FIAVGYVDDTQ
# P04222 :   corrected:  (idNotFound)T55  site:  T55 pep:  GYVDDTQFVRF
# P04222 :   corrected:  (idNotFound)S62  site:  S62 pep:  FVRFDSDAASP
# P04222 :   corrected:  (idNotFound)S66  site:  S66 pep:  DSDAASPRGEP
# P04222 :   corrected:  (idNotFound)Y195  site:  Y195 pep:  EWLRRYLKNGK
# P04222 :   corrected:  (idNotFound)S353  site:  S353 pep:  AASSNSAQGSD
# P04222 :   corrected:  (idNotFound)S275  site:  S275 pep:  AVVVPSGEEQR
# P04222 :   corrected:  (idNotFound)T202  site:  T202 pep:  KNGKETLQRAE
# P04222 :   corrected:  (idNotFound)Y183  site:  Y183 pep:  EQLRAYLEGLC
# P04222 :   corrected:  (idNotFound)T162  site:  T162 pep:  WTAADTAAQIT
# P04222 :   corrected:  (idNotFound)S337  site:  S337 pep:  MCRRKSSGGKG
# P04222 :   corrected:  (idNotFound)S338  site:  S338 pep:  CRRKSSGGKGG
# P04222 :   corrected:  (idNotFound)Y83  site:  Y83 pep:  QEGPEYWDRET
# P04222 :   corrected:  (idNotFound)Y142  site:  Y142 pep:  YDQYAYDGKDY
# P04222 :   corrected:  (idNotFound)T214  site:  T214 pep:  PKTHVTHHPVS
# P04222 :   corrected:  (idNotFound)T88  site:  T88 pep:  YWDRETQKYKR
# P04222 :   corrected:  (idNotFound)S346  site:  S346 pep:  KGGSCSQAASS
# P04222 :   corrected:  (idNotFound)Y91  site:  Y91 pep:  RETQKYKRQAQ
# P04222 :   corrected:  (idNotFound)S350  site:  S350 pep:  CSQAASSNSAQ
# P04222 :   corrected:  (idNotFound)S351  site:  S351 pep:  SQAASSNSAQG
# P04222 :   corrected:  (idNotFound)T224  site:  T224 pep:  SDHEATLRCWA
# P04222 :   corrected:  (idNotFound)T97  site:  T97 pep:  KRQAQTDRVSL
# P04222 :   corrected:  (idNotFound)S101  site:  S101 pep:  QTDRVSLRNLR
# P04222 :   corrected:  (idNotFound)S357  site:  S357 pep:  NSAQGSDESLI
# P04222 :   corrected:  (idNotFound)S360  site:  S360 pep:  QGSDESLIACK
# P04222 :   corrected:  (idNotFound)Y233  site:  Y233 pep:  WALGFYPAEIT
# P04222 :   corrected:  (idNotFound)T295  site:  T295 pep:  LPEPLTLRWEP
# P04222 :   corrected:  (idNotFound)Y108  site:  Y108 pep:  RNLRGYYNQSE
# P04222 :   corrected:  (idNotFound)Y109  site:  Y109 pep:  NLRGYYNQSEA
# P04222 :   corrected:  (idNotFound)T238  site:  T238 pep:  YPAEITLTWQW
# P04222 :   corrected:  (idNotFound)S112  site:  S112 pep:  GYYNQSEAGSH
# P04222 :   corrected:  (idNotFound)T211  site:  T211 pep:  AEHPKTHVTHH
# P04222 :   corrected:  (idNotFound)S116  site:  S116 pep:  QSEAGSHIIQR
# P04222 :   corrected:  (idNotFound)T249  site:  T249 pep:  DGEDQTQDTEL
# P04222 :   corrected:  (idNotFound)Y123  site:  Y123 pep:  IIQRMYGCDVG
# P04222 :   corrected:  (idNotFound)T252  site:  T252 pep:  DQTQDTELVET
# Q8N1F1 :   corrected:  (idNotFound)T64  site:  T64 pep:  FCGRATSARAW
# Q8N1F1 :   corrected:  (idNotFound)S65  site:  S65 pep:  CGRATSARAWS
# Q8N1F1 :   corrected:  (idNotFound)S98  site:  S98 pep:  AYPLQSAEDGV
# Q8N1F1 :   corrected:  (idNotFound)Y36  site:  Y36 pep:  GAAARYWTAWQ
# Q8N1F1 :   corrected:  (idNotFound)S5  site:  S5 pep:  MFPGSLSRGR
# Q8N1F1 :   corrected:  (idNotFound)T38  site:  T38 pep:  AARYWTAWQGS
# Q8N1F1 :   corrected:  (idNotFound)S7  site:  S7 pep:  FPGSLSRGRRA
# Q8N1F1 :   corrected:  (idNotFound)T105  site:  T105 pep:  EDGVATRLQIR
# Q8N1F1 :   corrected:  (idNotFound)S43  site:  S43 pep:  TAWQGSAGPNP
# Q8N1F1 :   corrected:  (idNotFound)S78  site:  S78 pep:  RPGPGSPAHSG
# Q8N1F1 :   corrected:  (idNotFound)S113  site:  S113 pep:  QIREESASCLA
# Q8N1F1 :   corrected:  (idNotFound)S82  site:  S82 pep:  GSPAHSGGVQT
# Q8N1F1 :   corrected:  (idNotFound)S115  site:  S115 pep:  REESASCLAAE
# Q8N1F1 :   corrected:  (idNotFound)Y121  site:  Y121 pep:  CLAAEYWSQEP
# Q8N1F1 :   corrected:  (idNotFound)S22  site:  S22 pep:  AWLPGSCARVA
# Q8N1F1 :   corrected:  (idNotFound)T87  site:  T87 pep:  SGGVQTRENWI
# Q8N1F1 :   corrected:  (idNotFound)S57  site:  S57 pep:  AEAHGSLFCGR
# Q8N1F1 :   corrected:  (idNotFound)S123  site:  S123 pep:  AAEYWSQEPAM
# Q8N1F1 :   corrected:  (idNotFound)S70  site:  S70 pep:  SARAWSLRRPG
# Q8N1F1 :   corrected:  (idNotFound)Y94  site:  Y94 pep:  ENWIAYPLQSA
# Q9GIY3 :   corrected:  (idNotFound)T129  site:  T129 pep:  VHPKVTVYPSK
# Q9GIY3 :   corrected:  (idNotFound)Y131  site:  Y131 pep:  PKVTVYPSKTQ
# Q9GIY3 :   corrected:  (idNotFound)S133  site:  S133 pep:  VTVYPSKTQPL
# Q9GIY3 :   corrected:  (idNotFound)T135  site:  T135 pep:  VYPSKTQPLQH
# Q9GIY3 :   corrected:  (idNotFound)S10  site:  S10 pep:  RLPGGSCMAVL
# Q9GIY3 :   corrected:  (idNotFound)Y141  site:  Y141 pep:  QPLQHYNLLVC
# Q9GIY3 :   corrected:  (idNotFound)T16  site:  T16 pep:  CMAVLTVTLMV
# Q9GIY3 :   corrected:  (idNotFound)Y152  site:  Y152 pep:  SVSGFYPGSIE
# Q9GIY3 :   corrected:  (idNotFound)T18  site:  T18 pep:  AVLTVTLMVLS
# Q9GIY3 :   corrected:  (idNotFound)S147  site:  S147 pep:  NLLVCSVSGFY
# Q9GIY3 :   corrected:  (idNotFound)S149  site:  S149 pep:  LVCSVSGFYPG
# Q9GIY3 :   corrected:  (idNotFound)S23  site:  S23 pep:  TLMVLSSPLAL
# Q9GIY3 :   corrected:  (idNotFound)S24  site:  S24 pep:  LMVLSSPLALA
# Q9GIY3 :   corrected:  (idNotFound)S155  site:  S155 pep:  GFYPGSIEVRW
# Q9GIY3 :   corrected:  (idNotFound)T32  site:  T32 pep:  ALAGDTRPRFL
# Q9GIY3 :   corrected:  (idNotFound)Y39  site:  Y39 pep:  PRFLEYSTSEC
# Q9GIY3 :   corrected:  (idNotFound)S40  site:  S40 pep:  RFLEYSTSECH
# Q9GIY3 :   corrected:  (idNotFound)T41  site:  T41 pep:  FLEYSTSECHF
# Q9GIY3 :   corrected:  (idNotFound)S42  site:  S42 pep:  LEYSTSECHFF
# Q9GIY3 :   corrected:  (idNotFound)S257  site:  S257 pep:  NQKGHSGLQPR
# Q9GIY3 :   corrected:  (idNotFound)S173  site:  S173 pep:  KTGVVSTGLIH
# Q9GIY3 :   corrected:  (idNotFound)T174  site:  T174 pep:  TGVVSTGLIHN
# Q9GIY3 :   corrected:  (idNotFound)T50  site:  T50 pep:  HFFNGTERVRF
# Q9GIY3 :   corrected:  (idNotFound)T183  site:  T183 pep:  HNGDWTFQTLV
# Q9GIY3 :   corrected:  (idNotFound)T186  site:  T186 pep:  DWTFQTLVMLE
# Q9GIY3 :   corrected:  (idNotFound)Y59  site:  Y59 pep:  RFLDRYFHNQE
# Q9GIY3 :   corrected:  (idNotFound)S266  site:  S266 pep:  PRGFLS
# Q9GIY3 :   corrected:  (idNotFound)T192  site:  T192 pep:  LVMLETVPRSG
# Q9GIY3 :   corrected:  (idNotFound)S196  site:  S196 pep:  ETVPRSGEVYT
# Q9GIY3 :   corrected:  (idNotFound)S71  site:  S71 pep:  FVRFDSDVGEY
# Q9GIY3 :   corrected:  (idNotFound)Y200  site:  Y200 pep:  RSGEVYTCQVE
# Q9GIY3 :   corrected:  (idNotFound)T201  site:  T201 pep:  SGEVYTCQVEH
# Q9GIY3 :   corrected:  (idNotFound)Y76  site:  Y76 pep:  SDVGEYRAVTE
# Q9GIY3 :   corrected:  (idNotFound)T80  site:  T80 pep:  EYRAVTELGRP
# Q9GIY3 :   corrected:  (idNotFound)T210  site:  T210 pep:  EHPSVTSPLTV
# Q9GIY3 :   corrected:  (idNotFound)S211  site:  S211 pep:  HPSVTSPLTVE
# Q9GIY3 :   corrected:  (idNotFound)T214  site:  T214 pep:  VTSPLTVEWRA
# Q9GIY3 :   corrected:  (idNotFound)T169  site:  T169 pep:  GQEEKTGVVST
# Q9GIY3 :   corrected:  (idNotFound)S92  site:  S92 pep:  AEHWNSQKDLL
# Q9GIY3 :   corrected:  (idNotFound)S221  site:  S221 pep:  EWRARSESAQS
# Q9GIY3 :   corrected:  (idNotFound)S223  site:  S223 pep:  RARSESAQSKM
# Q9GIY3 :   corrected:  (idNotFound)S208  site:  S208 pep:  QVEHPSVTSPL
# Q9GIY3 :   corrected:  (idNotFound)S226  site:  S226 pep:  SESAQSKMLSG
# Q9GIY3 :   corrected:  (idNotFound)S230  site:  S230 pep:  QSKMLSGVGGF
# Q9GIY3 :   corrected:  (idNotFound)T106  site:  T106 pep:  RAEVDTYCRHN
# Q9GIY3 :   corrected:  (idNotFound)Y107  site:  Y107 pep:  AEVDTYCRHNY
# Q9GIY3 :   corrected:  (idNotFound)Y112  site:  Y112 pep:  YCRHNYGVVES
# Q9GIY3 :   corrected:  (idNotFound)S117  site:  S117 pep:  YGVVESFTVQR
# Q9GIY3 :   corrected:  (idNotFound)T119  site:  T119 pep:  VVESFTVQRRV
# Q9GIY3 :   corrected:  (idNotFound)Y249  site:  Y249 pep:  AGLFIYFRNQK
# P30447 :   corrected:  (idNotFound)S129  site:  S129 pep:  GCDVGSDGRFL
# P30447 :   corrected:  (idNotFound)T257  site:  T257 pep:  TELVETRPAGD
# P30447 :   corrected:  (idNotFound)T8  site:  T8 pep:  VMAPRTLVLLL
# P30447 :   corrected:  (idNotFound)Y137  site:  Y137 pep:  RFLRGYHQYAY
# P30447 :   corrected:  (idNotFound)Y140  site:  Y140 pep:  RGYHQYAYDGK
# P30447 :   corrected:  (idNotFound)S14  site:  S14 pep:  LVLLLSGALAL
# P30447 :   corrected:  (idNotFound)S301  site:  S301 pep:  LRWEPSSQPTV
# P30447 :   corrected:  (idNotFound)Y344  site:  Y344 pep:  RKGGSYSQAAS
# P30447 :   corrected:  (idNotFound)Y147  site:  Y147 pep:  YDGKDYIALKE
# P30447 :   corrected:  (idNotFound)T20  site:  T20 pep:  GALALTQTWAG
# P30447 :   corrected:  (idNotFound)T22  site:  T22 pep:  LALTQTWAGSH
# P30447 :   corrected:  (idNotFound)Y281  site:  Y281 pep:  GEEQRYTCHVQ
# P30447 :   corrected:  (idNotFound)S26  site:  S26 pep:  QTWAGSHSMRY
# P30447 :   corrected:  (idNotFound)S28  site:  S28 pep:  WAGSHSMRYFS
# P30447 :   corrected:  (idNotFound)T282  site:  T282 pep:  EEQRYTCHVQH
# P30447 :   corrected:  (idNotFound)T158  site:  T158 pep:  DLRSWTAADMA
# P30447 :   corrected:  (idNotFound)Y31  site:  Y31 pep:  SHSMRYFSTSV
# P30447 :   corrected:  (idNotFound)S33  site:  S33 pep:  SMRYFSTSVSR
# P30447 :   corrected:  (idNotFound)T34  site:  T34 pep:  MRYFSTSVSRP
# P30447 :   corrected:  (idNotFound)S35  site:  S35 pep:  RYFSTSVSRPG
# P30447 :   corrected:  (idNotFound)S37  site:  S37 pep:  FSTSVSRPGRG
# P30447 :   corrected:  (idNotFound)T167  site:  T167 pep:  MAAQITQRKWE
# P30447 :   corrected:  (idNotFound)S156  site:  S156 pep:  KEDLRSWTAAD
# P30447 :   corrected:  (idNotFound)T240  site:  T240 pep:  AEITLTWQRDG
# P30447 :   corrected:  (idNotFound)S302  site:  S302 pep:  RWEPSSQPTVH
# P30447 :   corrected:  (idNotFound)T264  site:  T264 pep:  PAGDGTFQKWA
# P30447 :   corrected:  (idNotFound)Y51  site:  Y51 pep:  FIAVGYVDDTQ
# P30447 :   corrected:  (idNotFound)T55  site:  T55 pep:  GYVDDTQFVRF
# P30447 :   corrected:  (idNotFound)T187  site:  T187 pep:  AYLEGTCVDGL
# P30447 :   corrected:  (idNotFound)S62  site:  S62 pep:  FVRFDSDAASQ
# P30447 :   corrected:  (idNotFound)S352  site:  S352 pep:  AASSDSAQGSD
# P30447 :   corrected:  (idNotFound)S66  site:  S66 pep:  DSDAASQRMEP
# P30447 :   corrected:  (idNotFound)Y195  site:  Y195 pep:  DGLRRYLENGK
# P30447 :   corrected:  (idNotFound)S275  site:  S275 pep:  AVVVPSGEEQR
# P30447 :   corrected:  (idNotFound)T202  site:  T202 pep:  ENGKETLQRTD
# P30447 :   corrected:  (idNotFound)Y183  site:  Y183 pep:  EQLRAYLEGTC
# P30447 :   corrected:  (idNotFound)T305  site:  T305 pep:  PSSQPTVHIVG
# P30447 :   corrected:  (idNotFound)T206  site:  T206 pep:  ETLQRTDPPKT
# P30447 :   corrected:  (idNotFound)S336  site:  S336 pep:  MWRRNSSDRKG
# P30447 :   corrected:  (idNotFound)S337  site:  S337 pep:  WRRNSSDRKGG
# P30447 :   corrected:  (idNotFound)Y83  site:  Y83 pep:  QEGPEYWDEET
# P30447 :   corrected:  (idNotFound)Y142  site:  Y142 pep:  YHQYAYDGKDY
# P30447 :   corrected:  (idNotFound)T214  site:  T214 pep:  PKTHMTHHPIS
# P30447 :   corrected:  (idNotFound)S343  site:  S343 pep:  DRKGGSYSQAA
# P30447 :   corrected:  (idNotFound)T88  site:  T88 pep:  YWDEETGKVKA
# P30447 :   corrected:  (idNotFound)S345  site:  S345 pep:  KGGSYSQAASS
# P30447 :   corrected:  (idNotFound)S219  site:  S219 pep:  THHPISDHEAT
# P30447 :   corrected:  (idNotFound)S349  site:  S349 pep:  YSQAASSDSAQ
# P30447 :   corrected:  (idNotFound)S350  site:  S350 pep:  SQAASSDSAQG
# P30447 :   corrected:  (idNotFound)S95  site:  S95 pep:  KVKAHSQTDRE
# P30447 :   corrected:  (idNotFound)T224  site:  T224 pep:  SDHEATLRCWA
# P30447 :   corrected:  (idNotFound)T97  site:  T97 pep:  KAHSQTDRENL
# P30447 :   corrected:  (idNotFound)S356  site:  S356 pep:  DSAQGSDVSLT
# P30447 :   corrected:  (idNotFound)S359  site:  S359 pep:  QGSDVSLTACK
# P30447 :   corrected:  (idNotFound)Y233  site:  Y233 pep:  WALGFYPAEIT
# P30447 :   corrected:  (idNotFound)T323  site:  T323 pep:  LGAVITGAVVA
# P30447 :   corrected:  (idNotFound)T295  site:  T295 pep:  LPKPLTLRWEP
# P30447 :   corrected:  (idNotFound)Y108  site:  Y108 pep:  RIALRYYNQSE
# P30447 :   corrected:  (idNotFound)Y109  site:  Y109 pep:  IALRYYNQSEA
# P30447 :   corrected:  (idNotFound)T238  site:  T238 pep:  YPAEITLTWQR
# P30447 :   corrected:  (idNotFound)S112  site:  S112 pep:  RYYNQSEAGSH
# P30447 :   corrected:  (idNotFound)T211  site:  T211 pep:  TDPPKTHMTHH
# P30447 :   corrected:  (idNotFound)S116  site:  S116 pep:  QSEAGSHTLQM
# P30447 :   corrected:  (idNotFound)T118  site:  T118 pep:  EAGSHTLQMMF
# P30447 :   corrected:  (idNotFound)T361  site:  T361 pep:  SDVSLTACKV
# P30447 :   corrected:  (idNotFound)T249  site:  T249 pep:  DGEDQTQDTEL
# P30447 :   corrected:  (idNotFound)T252  site:  T252 pep:  DQTQDTELVET
# Saving  10 .tsv
# 10 .tsv Done  240.43896985054016
# processing  11 .tsv
# Get unique substrate sites in  11 .tsv
# P30475 :   corrected:  (idNotFound)T257  site:  T257 pep:  TELVETRPAGD
# P30475 :   corrected:  (idNotFound)T305  site:  T305 pep:  PSSQSTVPIVG
# P30475 :   corrected:  (idNotFound)T8  site:  T8 pep:  VMAPRTVLLLL
# P30475 :   corrected:  (idNotFound)S14  site:  S14 pep:  VLLLLSAALAL
# P30475 :   corrected:  (idNotFound)S301  site:  S301 pep:  LRWEPSSQSTV
# P30475 :   corrected:  (idNotFound)Y344  site:  Y344 pep:  GKGGSYSQAAS
# P30475 :   corrected:  (idNotFound)Y147  site:  Y147 pep:  YDGKDYIALNE
# P30475 :   corrected:  (idNotFound)T20  site:  T20 pep:  AALALTETWAG
# P30475 :   corrected:  (idNotFound)T22  site:  T22 pep:  LALTETWAGSH
# P30475 :   corrected:  (idNotFound)Y281  site:  Y281 pep:  GEEQRYTCHVQ
# P30475 :   corrected:  (idNotFound)S26  site:  S26 pep:  ETWAGSHSMRY
# P30475 :   corrected:  (idNotFound)S155  site:  S155 pep:  LNEDLSSWTAA
# P30475 :   corrected:  (idNotFound)S28  site:  S28 pep:  WAGSHSMRYFY
# P30475 :   corrected:  (idNotFound)T282  site:  T282 pep:  EEQRYTCHVQH
# P30475 :   corrected:  (idNotFound)T158  site:  T158 pep:  DLSSWTAADTA
# P30475 :   corrected:  (idNotFound)Y31  site:  Y31 pep:  SHSMRYFYTSV
# P30475 :   corrected:  (idNotFound)Y33  site:  Y33 pep:  SMRYFYTSVSR
# P30475 :   corrected:  (idNotFound)T34  site:  T34 pep:  MRYFYTSVSRP
# P30475 :   corrected:  (idNotFound)S35  site:  S35 pep:  RYFYTSVSRPG
# P30475 :   corrected:  (idNotFound)S37  site:  S37 pep:  FYTSVSRPGRG
# P30475 :   corrected:  (idNotFound)T167  site:  T167 pep:  TAAQITQRKWE
# P30475 :   corrected:  (idNotFound)S156  site:  S156 pep:  NEDLSSWTAAD
# P30475 :   corrected:  (idNotFound)T240  site:  T240 pep:  AEITLTWQRDG
# P30475 :   corrected:  (idNotFound)S302  site:  S302 pep:  RWEPSSQSTVP
# P30475 :   corrected:  (idNotFound)S304  site:  S304 pep:  EPSSQSTVPIV
# P30475 :   corrected:  (idNotFound)S48  site:  S48 pep:  EPRFISVGYVD
# P30475 :   corrected:  (idNotFound)T264  site:  T264 pep:  PAGDRTFQKWA
# P30475 :   corrected:  (idNotFound)Y51  site:  Y51 pep:  FISVGYVDDTQ
# P30475 :   corrected:  (idNotFound)T182  site:  T182 pep:  AEQLRTYLEGT
# P30475 :   corrected:  (idNotFound)T55  site:  T55 pep:  GYVDDTQFVRF
# P30475 :   corrected:  (idNotFound)T187  site:  T187 pep:  TYLEGTCVEWL
# P30475 :   corrected:  (idNotFound)S62  site:  S62 pep:  FVRFDSDAASP
# P30475 :   corrected:  (idNotFound)S352  site:  S352 pep:  AASSDSAQGSD
# P30475 :   corrected:  (idNotFound)S66  site:  S66 pep:  DSDAASPREEP
# P30475 :   corrected:  (idNotFound)Y195  site:  Y195 pep:  EWLRRYLENGK
# P30475 :   corrected:  (idNotFound)S275  site:  S275 pep:  AVVVPSGEEQR
# P30475 :   corrected:  (idNotFound)T202  site:  T202 pep:  ENGKETLQRAD
# P30475 :   corrected:  (idNotFound)Y183  site:  Y183 pep:  EQLRTYLEGTC
# P30475 :   corrected:  (idNotFound)T162  site:  T162 pep:  WTAADTAAQIT
# P30475 :   corrected:  (idNotFound)S349  site:  S349 pep:  YSQAASSDSAQ
# P30475 :   corrected:  (idNotFound)S336  site:  S336 pep:  MCRRKSSGGKG
# P30475 :   corrected:  (idNotFound)S337  site:  S337 pep:  CRRKSSGGKGG
# P30475 :   corrected:  (idNotFound)Y83  site:  Y83 pep:  QEGPEYWDRNT
# P30475 :   corrected:  (idNotFound)Y142  site:  Y142 pep:  HNQFAYDGKDY
# P30475 :   corrected:  (idNotFound)T214  site:  T214 pep:  PKTHVTHHPIS
# P30475 :   corrected:  (idNotFound)S343  site:  S343 pep:  GGKGGSYSQAA
# P30475 :   corrected:  (idNotFound)T88  site:  T88 pep:  YWDRNTQICKT
# P30475 :   corrected:  (idNotFound)S345  site:  S345 pep:  KGGSYSQAASS
# P30475 :   corrected:  (idNotFound)S219  site:  S219 pep:  THHPISDHEAT
# P30475 :   corrected:  (idNotFound)T93  site:  T93 pep:  TQICKTNTQTD
# P30475 :   corrected:  (idNotFound)S350  site:  S350 pep:  SQAASSDSAQG
# P30475 :   corrected:  (idNotFound)T95  site:  T95 pep:  ICKTNTQTDRE
# P30475 :   corrected:  (idNotFound)T224  site:  T224 pep:  SDHEATLRCWA
# P30475 :   corrected:  (idNotFound)T97  site:  T97 pep:  KTNTQTDRESL
# P30475 :   corrected:  (idNotFound)S356  site:  S356 pep:  DSAQGSDVSLT
# P30475 :   corrected:  (idNotFound)S101  site:  S101 pep:  QTDRESLRNLR
# P30475 :   corrected:  (idNotFound)S359  site:  S359 pep:  QGSDVSLTA
# P30475 :   corrected:  (idNotFound)Y233  site:  Y233 pep:  WALGFYPAEIT
# P30475 :   corrected:  (idNotFound)T295  site:  T295 pep:  LPKPLTLRWEP
# P30475 :   corrected:  (idNotFound)Y108  site:  Y108 pep:  RNLRGYYNQSE
# P30475 :   corrected:  (idNotFound)Y109  site:  Y109 pep:  NLRGYYNQSEA
# P30475 :   corrected:  (idNotFound)T238  site:  T238 pep:  YPAEITLTWQR
# P30475 :   corrected:  (idNotFound)S112  site:  S112 pep:  GYYNQSEAGSH
# P30475 :   corrected:  (idNotFound)T211  site:  T211 pep:  ADPPKTHVTHH
# P30475 :   corrected:  (idNotFound)S116  site:  S116 pep:  QSEAGSHTLQR
# P30475 :   corrected:  (idNotFound)T118  site:  T118 pep:  EAGSHTLQRMY
# P30475 :   corrected:  (idNotFound)T361  site:  T361 pep:  SDVSLTA
# P30475 :   corrected:  (idNotFound)T249  site:  T249 pep:  DGEDQTQDTEL
# P30475 :   corrected:  (idNotFound)Y123  site:  Y123 pep:  TLQRMYGCDVG
# P30475 :   corrected:  (idNotFound)T252  site:  T252 pep:  DQTQDTELVET
# A6NJW9 :   corrected:  (seqNotFound)S133  site:  S133  seq len:  210 pep:  KGTQLSVVVDF
# A6NJW9 :   corrected:  (seqNotFound)Y210  site:  Y210  seq len:  210 pep:  FMKQLYK
# P30453 :   corrected:  (idNotFound)T257  site:  T257 pep:  TELVETRPAGD
# P30453 :   corrected:  (idNotFound)T8  site:  T8 pep:  IMAPRTLVLLL
# P30453 :   corrected:  (idNotFound)Y137  site:  Y137 pep:  RFLRGYQQDAY
# P30453 :   corrected:  (idNotFound)S14  site:  S14 pep:  LVLLLSGALAL
# P30453 :   corrected:  (idNotFound)S301  site:  S301 pep:  LRWEPSSQPTI
# P30453 :   corrected:  (idNotFound)Y344  site:  Y344 pep:  RKGGSYSQAAS
# P30453 :   corrected:  (idNotFound)Y147  site:  Y147 pep:  YDGKDYIALNE
# P30453 :   corrected:  (idNotFound)T20  site:  T20 pep:  GALALTQTWAG
# P30453 :   corrected:  (idNotFound)T22  site:  T22 pep:  LALTQTWAGSH
# P30453 :   corrected:  (idNotFound)Y281  site:  Y281 pep:  GQEQRYTCHVQ
# P30453 :   corrected:  (idNotFound)S26  site:  S26 pep:  QTWAGSHSMRY
# P30453 :   corrected:  (idNotFound)S28  site:  S28 pep:  WAGSHSMRYFY
# P30453 :   corrected:  (idNotFound)T282  site:  T282 pep:  QEQRYTCHVQH
# P30453 :   corrected:  (idNotFound)T158  site:  T158 pep:  DLRSWTAADMA
# P30453 :   corrected:  (idNotFound)Y31  site:  Y31 pep:  SHSMRYFYTSV
# P30453 :   corrected:  (idNotFound)Y33  site:  Y33 pep:  SMRYFYTSVSR
# P30453 :   corrected:  (idNotFound)T34  site:  T34 pep:  MRYFYTSVSRP
# P30453 :   corrected:  (idNotFound)S35  site:  S35 pep:  RYFYTSVSRPG
# P30453 :   corrected:  (idNotFound)S37  site:  S37 pep:  FYTSVSRPGRG
# P30453 :   corrected:  (idNotFound)T167  site:  T167 pep:  MAAQITQRKWE
# P30453 :   corrected:  (idNotFound)S156  site:  S156 pep:  NEDLRSWTAAD
# P30453 :   corrected:  (idNotFound)T173  site:  T173 pep:  QRKWETAHEAE
# P30453 :   corrected:  (idNotFound)S302  site:  S302 pep:  RWEPSSQPTIP
# P30453 :   corrected:  (idNotFound)S359  site:  S359 pep:  QGSDMSLTACK
# P30453 :   corrected:  (idNotFound)T264  site:  T264 pep:  PAGDGTFQKWA
# P30453 :   corrected:  (idNotFound)S270  site:  S270 pep:  FQKWASVVVPS
# P30453 :   corrected:  (idNotFound)Y51  site:  Y51 pep:  FIAVGYVDDTQ
# P30453 :   corrected:  (idNotFound)T55  site:  T55 pep:  GYVDDTQFVRF
# P30453 :   corrected:  (idNotFound)T187  site:  T187 pep:  AYLEGTCVEWL
# P30453 :   corrected:  (idNotFound)S62  site:  S62 pep:  FVRFDSDAASQ
# P30453 :   corrected:  (idNotFound)S352  site:  S352 pep:  AASSDSAQGSD
# P30453 :   corrected:  (idNotFound)S66  site:  S66 pep:  DSDAASQRMEP
# P30453 :   corrected:  (idNotFound)Y195  site:  Y195 pep:  EWLRRYLENGK
# P30453 :   corrected:  (idNotFound)S275  site:  S275 pep:  SVVVPSGQEQR
# P30453 :   corrected:  (idNotFound)T202  site:  T202 pep:  ENGKETLQRTD
# P30453 :   corrected:  (idNotFound)Y183  site:  Y183 pep:  EQWRAYLEGTC
# P30453 :   corrected:  (idNotFound)T305  site:  T305 pep:  PSSQPTIPIVG
# P30453 :   corrected:  (idNotFound)T206  site:  T206 pep:  ETLQRTDAPKT
# P30453 :   corrected:  (idNotFound)S336  site:  S336 pep:  MWRRKSSDRKG
# P30453 :   corrected:  (idNotFound)S337  site:  S337 pep:  WRRKSSDRKGG
# P30453 :   corrected:  (idNotFound)Y83  site:  Y83 pep:  QEGPEYWDRNT
# P30453 :   corrected:  (idNotFound)Y142  site:  Y142 pep:  YQQDAYDGKDY
# P30453 :   corrected:  (idNotFound)T214  site:  T214 pep:  PKTHMTHHAVS
# P30453 :   corrected:  (idNotFound)S343  site:  S343 pep:  DRKGGSYSQAA
# P30453 :   corrected:  (idNotFound)T88  site:  T88 pep:  YWDRNTRKVKA
# P30453 :   corrected:  (idNotFound)S345  site:  S345 pep:  KGGSYSQAASS
# P30453 :   corrected:  (idNotFound)S219  site:  S219 pep:  THHAVSDHEAT
# P30453 :   corrected:  (idNotFound)S349  site:  S349 pep:  YSQAASSDSAQ
# P30453 :   corrected:  (idNotFound)S350  site:  S350 pep:  SQAASSDSAQG
# P30453 :   corrected:  (idNotFound)S95  site:  S95 pep:  KVKAQSQTDRV
# P30453 :   corrected:  (idNotFound)T224  site:  T224 pep:  SDHEATLRCWA
# P30453 :   corrected:  (idNotFound)T97  site:  T97 pep:  KAQSQTDRVDL
# P30453 :   corrected:  (idNotFound)T240  site:  T240 pep:  AEITLTWQRDG
# P30453 :   corrected:  (idNotFound)S356  site:  S356 pep:  DSAQGSDMSLT
# P30453 :   corrected:  (idNotFound)S231  site:  S231 pep:  RCWALSFYPAE
# P30453 :   corrected:  (idNotFound)T104  site:  T104 pep:  RVDLGTLRGYY
# P30453 :   corrected:  (idNotFound)Y233  site:  Y233 pep:  WALSFYPAEIT
# P30453 :   corrected:  (idNotFound)T295  site:  T295 pep:  LPKPLTLRWEP
# P30453 :   corrected:  (idNotFound)Y108  site:  Y108 pep:  GTLRGYYNQSE
# P30453 :   corrected:  (idNotFound)Y109  site:  Y109 pep:  TLRGYYNQSED
# P30453 :   corrected:  (idNotFound)T238  site:  T238 pep:  YPAEITLTWQR
# P30453 :   corrected:  (idNotFound)S112  site:  S112 pep:  GYYNQSEDGSH
# P30453 :   corrected:  (idNotFound)T211  site:  T211 pep:  TDAPKTHMTHH
# P30453 :   corrected:  (idNotFound)S116  site:  S116 pep:  QSEDGSHTIQR
# P30453 :   corrected:  (idNotFound)T118  site:  T118 pep:  EDGSHTIQRMY
# P30453 :   corrected:  (idNotFound)T361  site:  T361 pep:  SDMSLTACKV
# P30453 :   corrected:  (idNotFound)T249  site:  T249 pep:  DGEDQTQDTEL
# P30453 :   corrected:  (idNotFound)Y123  site:  Y123 pep:  TIQRMYGCDVG
# P30453 :   corrected:  (idNotFound)T252  site:  T252 pep:  DQTQDTELVET
# P10314 :   corrected:  (idNotFound)T257  site:  T257 pep:  TELVETRPAGD
# P10314 :   corrected:  (idNotFound)T8  site:  T8 pep:  VMAPRTLLLLL
# P10314 :   corrected:  (idNotFound)Y137  site:  Y137 pep:  RLLRGYQQDAY
# P10314 :   corrected:  (idNotFound)Y142  site:  Y142 pep:  YQQDAYDGKDY
# P10314 :   corrected:  (idNotFound)Y344  site:  Y344 pep:  RKGGSYSQAAS
# P10314 :   corrected:  (idNotFound)Y147  site:  Y147 pep:  YDGKDYIALNE
# P10314 :   corrected:  (idNotFound)T20  site:  T20 pep:  GALALTQTWAG
# P10314 :   corrected:  (idNotFound)T22  site:  T22 pep:  LALTQTWAGSH
# ...
# P03989 :   corrected:  (idNotFound)T34  site:  T34 pep:  MRYFHTSVSRP
# P03989 :   corrected:  (idNotFound)S35  site:  S35 pep:  RYFHTSVSRPG
# P03989 :   corrected:  (idNotFound)S37  site:  S37 pep:  FHTSVSRPGRG
# P03989 :   corrected:  (idNotFound)T167  site:  T167 pep:  TAAQITQRKWE
# P03989 :   corrected:  (idNotFound)S156  site:  S156 pep:  NEDLSSWTAAD
# P03989 :   corrected:  (idNotFound)S301  site:  S301 pep:  LRWEPSSQSTV
# P03989 :   corrected:  (idNotFound)S302  site:  S302 pep:  RWEPSSQSTVP
# P03989 :   corrected:  (idNotFound)S304  site:  S304 pep:  EPSSQSTVPIV
# P03989 :   corrected:  (idNotFound)T48  site:  T48 pep:  EPRFITVGYVD
# P03989 :   corrected:  (idNotFound)T264  site:  T264 pep:  PAGDRTFQKWA
# P03989 :   corrected:  (idNotFound)Y51  site:  Y51 pep:  FITVGYVDDTL
# P03989 :   corrected:  (idNotFound)T55  site:  T55 pep:  GYVDDTLFVRF
# P03989 :   corrected:  (idNotFound)S62  site:  S62 pep:  FVRFDSDAASP
# P03989 :   corrected:  (idNotFound)S352  site:  S352 pep:  AACSDSAQGSD
# P03989 :   corrected:  (idNotFound)S66  site:  S66 pep:  DSDAASPREEP
# P03989 :   corrected:  (idNotFound)Y195  site:  Y195 pep:  EWLRRYLENGK
# P03989 :   corrected:  (idNotFound)S275  site:  S275 pep:  AVVVPSGEEQR
# P03989 :   corrected:  (idNotFound)T202  site:  T202 pep:  ENGKETLQRAD
# P03989 :   corrected:  (idNotFound)Y183  site:  Y183 pep:  EQLRAYLEGEC
# P03989 :   corrected:  (idNotFound)T162  site:  T162 pep:  WTAADTAAQIT
# P03989 :   corrected:  (idNotFound)S336  site:  S336 pep:  MCRRKSSGGKG
# P03989 :   corrected:  (idNotFound)S337  site:  S337 pep:  CRRKSSGGKGG
# P03989 :   corrected:  (idNotFound)Y83  site:  Y83 pep:  QEGPEYWDRET
# P03989 :   corrected:  (idNotFound)T214  site:  T214 pep:  PKTHVTHHPIS
# P03989 :   corrected:  (idNotFound)S343  site:  S343 pep:  GGKGGSYSQAA
# P03989 :   corrected:  (idNotFound)T88  site:  T88 pep:  YWDRETQICKA
# P03989 :   corrected:  (idNotFound)S345  site:  S345 pep:  KGGSYSQAACS
# P03989 :   corrected:  (idNotFound)S219  site:  S219 pep:  THHPISDHEAT
# P03989 :   corrected:  (idNotFound)S350  site:  S350 pep:  SQAACSDSAQG
# P03989 :   corrected:  (idNotFound)T224  site:  T224 pep:  SDHEATLRCWA
# P03989 :   corrected:  (idNotFound)T97  site:  T97 pep:  KAKAQTDREDL
# P03989 :   corrected:  (idNotFound)S356  site:  S356 pep:  DSAQGSDVSLT
# P03989 :   corrected:  (idNotFound)S359  site:  S359 pep:  QGSDVSLTA
# P03989 :   corrected:  (idNotFound)T104  site:  T104 pep:  REDLRTLLRYY
# P03989 :   corrected:  (idNotFound)Y233  site:  Y233 pep:  WALGFYPAEIT
# P03989 :   corrected:  (idNotFound)T295  site:  T295 pep:  LPKPLTLRWEP
# P03989 :   corrected:  (idNotFound)Y108  site:  Y108 pep:  RTLLRYYNQSE
# P03989 :   corrected:  (idNotFound)Y109  site:  Y109 pep:  TLLRYYNQSEA
# P03989 :   corrected:  (idNotFound)T238  site:  T238 pep:  YPAEITLTWQR
# P03989 :   corrected:  (idNotFound)S112  site:  S112 pep:  RYYNQSEAGSH
# P03989 :   corrected:  (idNotFound)T211  site:  T211 pep:  ADPPKTHVTHH
# P03989 :   corrected:  (idNotFound)S116  site:  S116 pep:  QSEAGSHTLQN
# P03989 :   corrected:  (idNotFound)T118  site:  T118 pep:  EAGSHTLQNMY
# P03989 :   corrected:  (idNotFound)T361  site:  T361 pep:  SDVSLTA
# P03989 :   corrected:  (idNotFound)T249  site:  T249 pep:  DGEDQTQDTEL
# P03989 :   corrected:  (idNotFound)Y123  site:  Y123 pep:  TLQNMYGCDVG
# P03989 :   corrected:  (idNotFound)T252  site:  T252 pep:  DQTQDTELVET
# Saving  1 .tsv
# 1 .tsv Done  297.54812383651733
# processing  5 .tsv
# Get unique substrate sites in  5 .tsv
# Q8IZQ5 :   corrected:  (seqNotFound)T42  site:  T42  seq len:  122 pep:  VIEHCTSRVYG
# Q8IZQ5 :   corrected:  (seqNotFound)S43  site:  S43  seq len:  122 pep:  IEHCTSRVYGR
# Q8IZQ5 :   corrected:  (seqNotFound)Y46  site:  Y46  seq len:  122 pep:  CTSRVYGRNAA
# Q9BQE4 :   corrected:  (seqNotFound)S184  site:  S184  seq len:  189 pep:  GRRGPSSGGG
# Q9BQE4 :   corrected:  (seqNotFound)S185  site:  S185  seq len:  189 pep:  RRGPSSGGG
# P59797 :   corrected:  (seqNotFound)Y269  site:  Y269  seq len:  346 pep:  LIRVTYCGLSY
# P59797 :   corrected:  (seqNotFound)S275  site:  S275  seq len:  346 pep:  CGLSYSLRYIL
# P59797 :   corrected:  (seqNotFound)S273  site:  S273  seq len:  346 pep:  TYCGLSYSLRY
# P59797 :   corrected:  (seqNotFound)T268  site:  T268  seq len:  346 pep:  VLIRVTYCGLS
# P59797 :   corrected:  (seqNotFound)Y274  site:  Y274  seq len:  346 pep:  YCGLSYSLRYI
# P62341 :   corrected:  (seqNotFound)S48  site:  S48  seq len:  195 pep:  FQICVSGYRRV
# P62341 :   corrected:  (seqNotFound)Y50  site:  Y50  seq len:  195 pep:  ICVSGYRRVFE
# Q9NZV5 :   corrected:  (seqNotFound)S127  site:  S127  seq len:  590 pep:  LPWLNSSCLSL
# Q9NZV5 :   corrected:  (seqNotFound)S128  site:  S128  seq len:  590 pep:  PWLNSSCLSLL
# Q9NZV5 :   corrected:  (seqNotFound)S131  site:  S131  seq len:  590 pep:  NSSCLSLLRST
# Q9NZV5 :   corrected:  (seqNotFound)S459  site:  S459  seq len:  590 pep:  ALDDQSCGSGR
# Q9NZV5 :   corrected:  (seqNotFound)S462  site:  S462  seq len:  590 pep:  DQSCGSGRTLR
# Q9NZV5 :   corrected:  (seqNotFound)T465  site:  T465  seq len:  590 pep:  CGSGRTLRETV
# A8MU46 :   corrected:  (seqNotFound)S175  site:  S175  seq len:  494 pep:  DAKTASQEETV
# A8MU46 :   corrected:  (seqNotFound)T179  site:  T179  seq len:  494 pep:  ASQEETVVEDE
# A8MU46 :   corrected:  (seqNotFound)S211  site:  S211  seq len:  494 pep:  ADEPGSPSEEQ
# Q8WWX9 :   corrected:  (seqNotFound)T44  site:  T44  seq len:  145 pep:  RARVETCGGQL
# Q9BVL4 :   corrected:  (seqNotFound)T666  site:  T666  seq len:  669 pep:  AELCVTSS
# Q9BVL4 :   corrected:  (seqNotFound)S667  site:  S667  seq len:  669 pep:  ELCVTSS
# Q9BVL4 :   corrected:  (seqNotFound)S668  site:  S668  seq len:  669 pep:  LCVTSS
# Saving  5 .tsv
# 5 .tsv Done  255.17887377738953
# processing  4 .tsv
# Get unique substrate sites in  4 .tsv
# Q9UJX0 :   corrected:  (seqNotFound)T23  site:  T23  seq len:  477 pep:  QEVPATLTSSE
# Q9UJX0 :   corrected:  (seqNotFound)T25  site:  T25  seq len:  477 pep:  VPATLTSSELF
# Q9UJX0 :   corrected:  (seqNotFound)S26  site:  S26  seq len:  477 pep:  PATLTSSELFS
# Q9UJX0 :   corrected:  (seqNotFound)S27  site:  S27  seq len:  477 pep:  ATLTSSELFST
# Q9UJX0 :   corrected:  (seqNotFound)S31  site:  S31  seq len:  477 pep:  SSELFSTRNQP
# Q9UJX0 :   corrected:  (seqNotFound)T32  site:  T32  seq len:  477 pep:  SELFSTRNQPQ
# Q9UJX0 :   corrected:  (seqNotFound)S55  site:  S55  seq len:  477 pep:  PWAVASRMCLT
# Q9UJX0 :   corrected:  (seqNotFound)T60  site:  T60  seq len:  477 pep:  SRMCLTPGQGC
# Q9UJX0 :   corrected:  (seqNotFound)S79  site:  S79  seq len:  477 pep:  PLPAPSPPPAM
# Q9UJX0 :   corrected:  (seqNotFound)S85  site:  S85  seq len:  477 pep:  PPPAMSSSRKD
# Q9UJX0 :   corrected:  (seqNotFound)S86  site:  S86  seq len:  477 pep:  PPAMSSSRKDH
# Q9UJX0 :   corrected:  (seqNotFound)S87  site:  S87  seq len:  477 pep:  PAMSSSRKDHL
# Q6ZR98 :   corrected:  (idNotFound)S3  site:  S3 pep:  MASQSGSS
# Q6ZR98 :   corrected:  (idNotFound)S260  site:  S260 pep:  HLRQASCLNSK
# Q6ZR98 :   corrected:  (idNotFound)S5  site:  S5 pep:  MASQSGSSLG
# Q6ZR98 :   corrected:  (idNotFound)S7  site:  S7 pep:  ASQSGSSLGLL
# Q6ZR98 :   corrected:  (idNotFound)S8  site:  S8 pep:  SQSGSSLGLLA
# Q6ZR98 :   corrected:  (idNotFound)T266  site:  T266 pep:  CLNSKTSSS
# Q6ZR98 :   corrected:  (idNotFound)T139  site:  T139 pep:  MVQAGTNCWVT
# Q6ZR98 :   corrected:  (idNotFound)S268  site:  S268 pep:  NSKTSSS
# Q6ZR98 :   corrected:  (idNotFound)S269  site:  S269 pep:  SKTSSS
# Q6ZR98 :   corrected:  (idNotFound)T144  site:  T144 pep:  TNCWVTGWGKV
# Q6ZR98 :   corrected:  (idNotFound)T152  site:  T152 pep:  GKVNETVSGPM
# Q6ZR98 :   corrected:  (idNotFound)S154  site:  S154 pep:  VNETVSGPMPL
# Q6ZR98 :   corrected:  (idNotFound)T164  site:  T164 pep:  LVLQETELNIM
# Q6ZR98 :   corrected:  (idNotFound)S42  site:  S42 pep:  ALLFPSALPSG
# Q6ZR98 :   corrected:  (idNotFound)S46  site:  S46 pep:  PSALPSGPGGQ
# Q6ZR98 :   corrected:  (idNotFound)S264  site:  S264 pep:  ASCLNSKTSSS
# Q6ZR98 :   corrected:  (idNotFound)S56  site:  S56 pep:  QDPGASGWEPP
# Q6ZR98 :   corrected:  (idNotFound)S186  site:  S186 pep:  KNISKSKMVTR
# Q6ZR98 :   corrected:  (idNotFound)T190  site:  T190 pep:  KSKMVTRGTVC
# Q6ZR98 :   corrected:  (idNotFound)T193  site:  T193 pep:  MVTRGTVCGYN
# Q6ZR98 :   corrected:  (idNotFound)S267  site:  S267 pep:  LNSKTSSS
# Q6ZR98 :   corrected:  (idNotFound)S68  site:  S68 pep:  VGAPGSPAAPQ
# Q6ZR98 :   corrected:  (idNotFound)Y197  site:  Y197 pep:  GTVCGYNDQGK
# Q6ZR98 :   corrected:  (idNotFound)S74  site:  S74 pep:  PAAPQSRGNAV
# Q6ZR98 :   corrected:  (idNotFound)S184  site:  S184 pep:  KNKNISKSKMV
# Q6ZR98 :   corrected:  (idNotFound)S83  site:  S83 pep:  AVRPASVLLPS
# Q6ZR98 :   corrected:  (idNotFound)S88  site:  S88 pep:  SVLLPSACGQR
# Q6ZR98 :   corrected:  (idNotFound)T220  site:  T220 pep:  CELNGTWVQVG
# Q6ZR98 :   corrected:  (idNotFound)T94  site:  T94 pep:  ACGQRTSRITG
# Q6ZR98 :   corrected:  (idNotFound)S95  site:  S95 pep:  CGQRTSRITGG
# Q6ZR98 :   corrected:  (idNotFound)T98  site:  T98 pep:  RTSRITGGLPA
# Q6ZR98 :   corrected:  (idNotFound)S228  site:  S228 pep:  QVGIVSWGIGC
# Q6ZR98 :   corrected:  (idNotFound)S209  site:  S209 pep:  ACQGDSGGPLV
# Q6ZR98 :   corrected:  (idNotFound)Y238  site:  Y238 pep:  CGRKGYPGVYT
# Q6ZR98 :   corrected:  (idNotFound)S113  site:  S113 pep:  WPWQVSLQTSN
# Q6ZR98 :   corrected:  (idNotFound)Y242  site:  Y242 pep:  GYPGVYTEVSF
# Q6ZR98 :   corrected:  (idNotFound)T243  site:  T243 pep:  YPGVYTEVSFY
# Q6ZR98 :   corrected:  (idNotFound)T116  site:  T116 pep:  QVSLQTSNRHI
# Q6ZR98 :   corrected:  (idNotFound)S117  site:  S117 pep:  VSLQTSNRHIC
# Q6ZR98 :   corrected:  (idNotFound)S246  site:  S246 pep:  VYTEVSFYKKW
# Q6ZR98 :   corrected:  (idNotFound)Y248  site:  Y248 pep:  TEVSFYKKWII
# Q6ZR98 :   corrected:  (idNotFound)S125  site:  S125 pep:  HICGGSLIARH
# Q9UMY4 :   corrected:  (seqNotFound)S160  site:  S160  seq len:  162 pep:  YVPGKSLAVSC
# Q9UMY4 :   corrected:  (seqNotFound)Y155  site:  Y155  seq len:  162 pep:  AIDRNYVPGKS
# Q9UMY4 :   corrected:  (seqNotFound)S164  site:  S164  seq len:  162 pep:  KSLAVSCPGWS
# Q9UMY4 :   corrected:  (seqNotFound)S169  site:  S169  seq len:  162 pep:  SCPGWSAVA
# Saving  4 .tsv
# 4 .tsv Done  270.4089620113373
# processing  6 .tsv
# Get unique substrate sites in  6 .tsv
# P63302 :   corrected:  (seqNotFound)Y9  site:  Y9  seq len:  87 pep:  AVRVVYCGAGY
# P63302 :   corrected:  (seqNotFound)Y14  site:  Y14  seq len:  87 pep:  YCGAGYKSKYL
# P63302 :   corrected:  (seqNotFound)S16  site:  S16  seq len:  87 pep:  GAGYKSKYLQL
# Q9H2Q1 :   corrected:  (idNotFound)Y128  site:  Y128 pep:  GKMQVYE
# Q9H2Q1 :   corrected:  (idNotFound)T2  site:  T2 pep:  MTSHHCV
# Q9H2Q1 :   corrected:  (idNotFound)S3  site:  S3 pep:  MTSHHCVG
# Q9H2Q1 :   corrected:  (idNotFound)S14  site:  S14 pep:  PGNHISWSGHE
# Q9H2Q1 :   corrected:  (idNotFound)S16  site:  S16 pep:  NHISWSGHEKE
# Q9H2Q1 :   corrected:  (idNotFound)Y26  site:  Y26 pep:  EHRLDYCPEVT
# Q9H2Q1 :   corrected:  (idNotFound)T31  site:  T31 pep:  YCPEVTFPLTK
# Q9H2Q1 :   corrected:  (idNotFound)T35  site:  T35 pep:  VTFPLTKGFPL
# Q9H2Q1 :   corrected:  (idNotFound)Y42  site:  Y42 pep:  GFPLGYTLLFN
# Q9H2Q1 :   corrected:  (idNotFound)T43  site:  T43 pep:  FPLGYTLLFNF
# Q9H2Q1 :   corrected:  (idNotFound)S50  site:  S50 pep:  LFNFASYPFLL
# Q9H2Q1 :   corrected:  (idNotFound)Y51  site:  Y51 pep:  FNFASYPFLLP
# Q9H2Q1 :   corrected:  (idNotFound)S57  site:  S57 pep:  PFLLPSKIKTL
# Q9H2Q1 :   corrected:  (idNotFound)T61  site:  T61 pep:  PSKIKTLLRNK
# Q9H2Q1 :   corrected:  (idNotFound)S68  site:  S68 pep:  LRNKDSFLNIL
# Q9H2Q1 :   corrected:  (idNotFound)Y88  site:  Y88 pep:  RCNIEYSSTGL
# Q9H2Q1 :   corrected:  (idNotFound)S89  site:  S89 pep:  CNIEYSSTGLN
# Q9H2Q1 :   corrected:  (idNotFound)S90  site:  S90 pep:  NIEYSSTGLNF
# Q9H2Q1 :   corrected:  (idNotFound)T91  site:  T91 pep:  IEYSSTGLNFL
# Q9H2Q1 :   corrected:  (idNotFound)T98  site:  T98 pep:  LNFLNTFTVSL
# Q9H2Q1 :   corrected:  (idNotFound)T100  site:  T100 pep:  FLNTFTVSLIV
# Q9H2Q1 :   corrected:  (idNotFound)S102  site:  S102 pep:  NTFTVSLIVTV
# Q9H2Q1 :   corrected:  (idNotFound)T106  site:  T106 pep:  VSLIVTVIPLL
# Q99611 :   corrected:  (seqNotFound)S55  site:  S55  seq len:  448 pep:  RLTGFSGMKGG
# Saving  6 .tsv
# 6 .tsv Done  265.63572096824646
# processing  7 .tsv
# Get unique substrate sites in  7 .tsv
# Q96S15 :   corrected:  (seqNotFound)T6  site:  T6  seq len:  790 pep:  MGKKRTTSGEG
# Q96S15 :   corrected:  (seqNotFound)T7  site:  T7  seq len:  790 pep:  GKKRTTSGEGR
# Q96S15 :   corrected:  (seqNotFound)S8  site:  S8  seq len:  790 pep:  KKRTTSGEGRE
# Q96S15 :   corrected:  (seqNotFound)T24  site:  T24  seq len:  790 pep:  ARRFRTTSPAA
# Q96S15 :   corrected:  (seqNotFound)T25  site:  T25  seq len:  790 pep:  RRFRTTSPAAL
# Q96S15 :   corrected:  (seqNotFound)S26  site:  S26  seq len:  790 pep:  RFRTTSPAALR
# Q96S15 :   corrected:  (seqNotFound)S34  site:  S34  seq len:  790 pep:  ALRADSVDGGS
# Q96S15 :   corrected:  (seqNotFound)S39  site:  S39  seq len:  790 pep:  SVDGGSLLAPL
# Q96S15 :   corrected:  (seqNotFound)T48  site:  T48  seq len:  790 pep:  PLLGLTDRAFS
# Q96S15 :   corrected:  (seqNotFound)S53  site:  S53  seq len:  790 pep:  TDRAFSDCPDL
# Q96S15 :   corrected:  (seqNotFound)S67  site:  S67  seq len:  790 pep:  AMEKMSRVTTA
# Q96S15 :   corrected:  (seqNotFound)S219  site:  S219  seq len:  790 pep:  RKDSVSTFSGE
# Q96S15 :   corrected:  (seqNotFound)T220  site:  T220  seq len:  790 pep:  KDSVSTFSGEA
# Q96S15 :   corrected:  (seqNotFound)S222  site:  S222  seq len:  790 pep:  SVSTFSGEATE
# Q96S15 :   corrected:  (seqNotFound)T226  site:  T226  seq len:  790 pep:  FSGEATEAGPR
# Q96S15 :   corrected:  (seqNotFound)S246  site:  S246  seq len:  790 pep:  ILPVLSCRILR
# Q96S15 :   corrected:  (seqNotFound)S255  site:  S255  seq len:  790 pep:  LRLHHSFAHGP
# Q96S15 :   corrected:  (seqNotFound)S266  site:  S266  seq len:  790 pep:  MQDAESTANDA
# Q96S15 :   corrected:  (seqNotFound)T267  site:  T267  seq len:  790 pep:  QDAESTANDAR
# Q96S15 :   corrected:  (seqNotFound)S274  site:  S274  seq len:  790 pep:  NDARESWGCPL
# Q96S15 :   corrected:  (seqNotFound)Y280  site:  Y280  seq len:  790 pep:  WGCPLYPLGLC
# Q96S15 :   corrected:  (seqNotFound)S286  site:  S286  seq len:  790 pep:  PLGLCSGPQAG
# Q96S15 :   corrected:  (seqNotFound)S293  site:  S293  seq len:  790 pep:  PQAGQSESVRD
# Q96S15 :   corrected:  (seqNotFound)S295  site:  S295  seq len:  790 pep:  AGQSESVRDVQ
# O43493 :   corrected:  (seqNotFound)Y437  site:  Y437  seq len:  437 pep:  RLDQKYVLILN
# O43493 :   corrected:  (seqNotFound)S451  site:  S451  seq len:  437 pep:  APPKRSFFPVL
# O43493 :   corrected:  (seqNotFound)T457  site:  T457  seq len:  437 pep:  FFPVLTEWYIP
# O43493 :   corrected:  (seqNotFound)Y460  site:  Y460  seq len:  437 pep:  VLTEWYIPLEK
# O43493 :   corrected:  (seqNotFound)S476  site:  S476  seq len:  437 pep:  WIVLLSFQL
# Q9C0I4 :   corrected:  (seqNotFound)T46  site:  T46  seq len:  1606 pep:  QFIWKTGPWGR
# Q9NNW7 :   corrected:  (seqNotFound)T520  site:  T520  seq len:  524 pep:  LDPTVTGCG
# Q9NNW7 :   corrected:  (seqNotFound)T518  site:  T518  seq len:  524 pep:  SGLDPTVTGCG
# Q9BQ50 :   corrected:  (seqNotFound)S6  site:  S6  seq len:  236 pep:  MGRAGSPLPRS
# Q9BQ50 :   corrected:  (seqNotFound)S11  site:  S11  seq len:  236 pep:  SPLPRSSWPRM
# Q9BQ50 :   corrected:  (seqNotFound)S12  site:  S12  seq len:  236 pep:  PLPRSSWPRMD
# Q9BQ50 :   corrected:  (seqNotFound)S21  site:  S21  seq len:  236 pep:  MDDCGSRSRCS
# Q9BQ50 :   corrected:  (seqNotFound)S23  site:  S23  seq len:  236 pep:  DCGSRSRCSPT
# Q9BQ50 :   corrected:  (seqNotFound)S26  site:  S26  seq len:  236 pep:  SRSRCSPTLCS
# Q9BQ50 :   corrected:  (seqNotFound)T28  site:  T28  seq len:  236 pep:  SRCSPTLCSSL
# Q9BQ50 :   corrected:  (seqNotFound)S31  site:  S31  seq len:  236 pep:  SPTLCSSLRTC
# Q9BQ50 :   corrected:  (seqNotFound)S32  site:  S32  seq len:  236 pep:  PTLCSSLRTCY
# Q9BQ50 :   corrected:  (seqNotFound)T35  site:  T35  seq len:  236 pep:  CSSLRTCYPRG
# Q9BQ50 :   corrected:  (seqNotFound)Y37  site:  Y37  seq len:  236 pep:  SLRTCYPRGNI
# Q9BQ50 :   corrected:  (seqNotFound)T43  site:  T43  seq len:  236 pep:  PRGNITMSEAP
# Q9BQ50 :   corrected:  (seqNotFound)S45  site:  S45  seq len:  236 pep:  GNITMSEAPRA
# Saving  7 .tsv
# 7 .tsv Done  250.8771460056305

# %% [markdown]
# **Remove unmapped/outdated results**
# - Check if there is any unmapped substrate/site due to outdated uniprot sequence records
#     - get a list of outdated uniprotID

# %%
all_results = glob.glob(NW_temp_dir_site + '*.csv')
    
updatedSub_li = []
for filename in all_results:
    start = time.time() 
    df_unmapped = pd.read_csv(filename, usecols = ['substrate_id','substrate_acc', 'site'])
    df_unmapped = df_unmapped[~(df_unmapped['site'].str.contains('S|T|Y', na=False)) | (df_unmapped['substrate_id'] == 'outdated')]
    df_unmapped = df_unmapped.substrate_acc.drop_duplicates()
    unmapped_li = df_unmapped.values.tolist()
    updatedSub_li.extend(unmapped_li)
    end = time.time()
    print (f"Time\t{(end-start):.3f}")
updatedSub_li
# Out:
# Time	8.223
# Time	9.399
# Time	9.811
# Time	10.685
# Time	9.016
# Time	8.493
# Time	9.990
# Time	5.003
# Time	12.716
# Time	9.222
# Time	8.385
# Time	9.441
# Time	8.693
# Time	8.373
# Time	8.131
# Time	8.660
# Time	11.187
# Time	10.031
# Time	8.585
# Time	8.566
# Time	9.941
# ['Q86VQ6',
#  'O15015',
#  'Q96S15',
#  'O43493',
#  'Q9C0I4',
#  'Q9NNW7',
#  'Q9BQ50',
#  'P63302',
#  'Q9H2Q1',
#  'Q99611',
#  'P04229',
#  'P30483',
#  'P10316',
#  'P30504',
#  'P10319',
#  'Q07000',
#  'P20039',
#  'Q31612',
#  'P01891',
#  'Q9TNN7',
#  'Q29718',
#  'Q95IE3',
#  'P16190',
#  'Q29836',
#  'P30466',
#  'Q29963',
#  'P30498',
#  'P30460',
#  'P30455',
#  'Q04826',
#  'P30443',
#  'P13761',
#  'P30487',
#  'Q9TQE0',
#  'P30461',
#  'P30490',
#  'P01892',
#  'Q09160',
#  'P30480',
#  'P30499',
#  'P30495',
#  'P30505',
#  'Q29974',
#  'P30481',
#  'P18465',
#  'P30450',
#  'P30459',
#  'Q29960',
#  'P30484',
#  'P13746',
#  'Q31610',
#  'P30462',
#  'Q30134',
#  'P16189',
#  'P30488',
#  'P30492',
#  'P01160',
#  'P16188',
#  'Q29940',
#  'P30685',
#  'P18464',
#  'Q30167',
#  'Q29865',
#  'Q5Y7A7',
#  'P18462',
#  'P30501',
#  'P30493',
#  'P30456',
#  'Q95365',
#  'P13760',
#  'P30479',
#  'P18463',
#  'P30508',
#  'P30510',
#  'P01912',
#  'P30464',
#  'P30485',
#  'P30486',
#  'P03989',
#  'P30988',
#  'Q9BSG1',
#  'E7EML9',
#  'Q06124',
#  'Q9UJ41',
#  'Q8N2Q7',
#  'Q9UJX0',
#  'Q6ZR98',
#  'Q9UMY4',
#  'P18283',
#  'P36969',
#  'Q86Y91',
#  'Q9Y6F6',
#  'Q8IZQ5',
#  'Q9BQE4',
#  'P59797',
#  'P62341',
#  'Q9NZV5',
#  'A8MU46',
#  'Q8WWX9',
#  'Q9BVL4',
#  'P22352',
#  'P26378',
#  'P11509',
#  'Q92813',
#  'P55073',
#  'P59796',
#  'P07203',
#  'Q9C0D9',
#  'P02751',
#  'Q8IXR5',
#  'Q52LJ0',
#  'Q9UBA6',
#  'Q53TQ3',
#  'Q5JXX5',
#  'Q6P4E1',
#  'P05534',
#  'Q95604',
#  'P30457',
#  'P04222',
#  'Q8N1F1',
#  'Q9GIY3',
#  'P30447',
#  'Q3C1V0',
#  'Q96SB3',
#  'Q68DE3',
#  'O60229',
#  'Q6QHF9',
#  'Q4FZB7',
#  'P49895',
#  'Q9NZV6',
#  'P30475',
#  'A6NJW9',
#  'P30453',
#  'P10314',
#  'P30491',
#  'P30512',
#  'Q53SF7',
#  'Q96AP0']

# %% [markdown]
# - Remove any record with unmapped substrate_acc/site in '*_mappedSite.csv'

# %%
all_results = glob.glob(NW_temp_dir_site + '*.csv')

for filename in all_results:
    start = time.time()
    df_mapSite = pd.read_csv(filename)
    # remove the outdated records from df_subMap
    df_update = df_mapSite[~df_mapSite['substrate_acc'].isin(updatedSub_li)]
    df_update.to_csv(filename, chunksize=100000, index=False)
    end = time.time()
    print (f"chunk time\t{(end-start):.3f}")
# Out:
# chunk time	32.552
# chunk time	34.708
# chunk time	37.731
# chunk time	42.370
# chunk time	35.697
# chunk time	32.222
# chunk time	37.086
# chunk time	19.179
# chunk time	45.215
# chunk time	36.513
# chunk time	33.216
# chunk time	37.718
# chunk time	33.076
# chunk time	33.881
# chunk time	32.461
# chunk time	33.712
# chunk time	39.761
# chunk time	37.249
# chunk time	32.760
# chunk time	32.690
# chunk time	37.350

# %% [markdown]
# ### Update NetworKIN results
# - The next 6 cells is only for NetworKIN results from outdated Human Proteomes sequences (input sequences for NetworKIN prediction an earlier version than the referece human proteome sequence)

# %% [markdown]
# 1. download the sequence fasta file of the above UniprotID (updatedSub_li) from Uniprot.org, save it as '../Data/Raw/HumanProteome/NetworKIN_updateSub.fasta'. Submit the 'NetworKIN_updateSub.fasta' in NetworKIN again
# 2. run mapAcc and mapSite function for the result file from 'NetworKIN_updateSub.fasta'

# %%
# convert substrate_acc and kinase_acc
convert_type = 'acc'
networKin_convert.kin_convert_directory(NW_update_dir, 'na', NW_temp_dir_acc_update, convert_type)
# Out:
# reading  2020.tsv
# getting unique sub
# getting sub_acc
# merge
# done 0.2106938362121582
# getting unique kin
# getting kin_acc
# merge
# done 124.0804557800293
# saving
# Done 2.124906063079834

# %%
# map the site to the updated (new) human proteome reference
convert_type = 'site'
networKin_convert.kin_convert_directory(NW_temp_dir_acc_update, HP_csv, NW_temp_dir_site_update, convert_type)
# Out:
# Set input file dir...
# done
# read the Human Proteome df...
# done
# processing  2020 .tsv
# Get unique substrate sites in  2020 .tsv
# P55073 :   corrected:  (seqNotFound)S167  site:  S167  seq len:  304 pep:  VLNFGSCTPPF
# P55073 :   corrected:  (seqNotFound)T169  site:  T169  seq len:  304 pep:  NFGSCTPPFMA
# P59797 :   corrected:  (seqNotFound)Y269  site:  Y269  seq len:  346 pep:  LIRVTYCGLSY
# P59797 :   corrected:  (seqNotFound)S275  site:  S275  seq len:  346 pep:  CGLSYSLRYIL
# P59797 :   corrected:  (seqNotFound)S273  site:  S273  seq len:  346 pep:  TYCGLSYSLRY
# P59797 :   corrected:  (seqNotFound)T268  site:  T268  seq len:  346 pep:  VLIRVTYCGLS
# P59797 :   corrected:  (seqNotFound)Y274  site:  Y274  seq len:  346 pep:  YCGLSYSLRYI
# Q9NZV6 :   corrected:  (seqNotFound)S92  site:  S92  seq len:  116 pep:  PKPGQSRFIFS
# Q9NZV6 :   corrected:  (seqNotFound)S97  site:  S97  seq len:  116 pep:  SRFIFSSSLKF
# Q9NZV6 :   corrected:  (seqNotFound)S98  site:  S98  seq len:  116 pep:  RFIFSSSLKFV
# Q9NZV6 :   corrected:  (seqNotFound)S99  site:  S99  seq len:  116 pep:  FIFSSSLKFVP
# P18283 :   corrected:  (seqNotFound)S38  site:  S38  seq len:  190 pep:  IENVASLGTTT
# P18283 :   corrected:  (seqNotFound)T41  site:  T41  seq len:  190 pep:  VASLGTTTRDF
# P18283 :   corrected:  (seqNotFound)T42  site:  T42  seq len:  190 pep:  ASLGTTTRDFT
# P18283 :   corrected:  (seqNotFound)T43  site:  T43  seq len:  190 pep:  SLGTTTRDFTQ
# Q9BQE4 :   corrected:  (seqNotFound)S184  site:  S184  seq len:  189 pep:  GRRGPSSGGG
# Q9BQE4 :   corrected:  (seqNotFound)S185  site:  S185  seq len:  189 pep:  RRGPSSGGG
# P49895 :   corrected:  (seqNotFound)S123  site:  S123  seq len:  249 pep:  VLNFGSCTPSF
# P49895 :   corrected:  (seqNotFound)T125  site:  T125  seq len:  249 pep:  NFGSCTPSFMF
# P49895 :   corrected:  (seqNotFound)S127  site:  S127  seq len:  249 pep:  GSCTPSFMFKF
# Q9BVL4 :   corrected:  (seqNotFound)T666  site:  T666  seq len:  669 pep:  AELCVTSS
# Q9BVL4 :   corrected:  (seqNotFound)S667  site:  S667  seq len:  669 pep:  ELCVTSS
# Q9BVL4 :   corrected:  (seqNotFound)S668  site:  S668  seq len:  669 pep:  LCVTSS
# Q99611 :   corrected:  (seqNotFound)S55  site:  S55  seq len:  448 pep:  RLTGFSGMKGG
# Q9NNW7 :   corrected:  (seqNotFound)T520  site:  T520  seq len:  524 pep:  LDPTVTGCG
# Q9NNW7 :   corrected:  (seqNotFound)T518  site:  T518  seq len:  524 pep:  SGLDPTVTGCG
# P07203 :   corrected:  (seqNotFound)T51  site:  T51  seq len:  203 pep:  ASLGTTVRDYT
# P07203 :   corrected:  (seqNotFound)T50  site:  T50  seq len:  203 pep:  VASLGTTVRDY
# P07203 :   corrected:  (seqNotFound)S47  site:  S47  seq len:  203 pep:  IENVASLGTTV
# P22352 :   corrected:  (seqNotFound)S71  site:  S71  seq len:  226 pep:  FVNVASYGLTG
# P22352 :   corrected:  (seqNotFound)Y72  site:  Y72  seq len:  226 pep:  VNVASYGLTGQ
# P22352 :   corrected:  (seqNotFound)T75  site:  T75  seq len:  226 pep:  ASYGLTGQYIE
# P59796 :   corrected:  (seqNotFound)Y72  site:  Y72  seq len:  221 pep:  VNVAAYGLAAQ
# P62341 :   corrected:  (seqNotFound)S48  site:  S48  seq len:  195 pep:  FQICVSGYRRV
# P62341 :   corrected:  (seqNotFound)Y50  site:  Y50  seq len:  195 pep:  ICVSGYRRVFE
# Q86VQ6 :   corrected:  (seqNotFound)T637  site:  T637  seq len:  643 pep:  SGLDITQKGCG
# P36969 :   corrected:  (seqNotFound)S71  site:  S71  seq len:  197 pep:  VTNVASQGKTE
# P36969 :   corrected:  (seqNotFound)T75  site:  T75  seq len:  197 pep:  ASQGKTEVNYT
# Q8WWX9 :   corrected:  (seqNotFound)T44  site:  T44  seq len:  145 pep:  RARVETCGGQL
# Q92813 :   corrected:  (seqNotFound)S130  site:  S130  seq len:  273 pep:  VVNFGSATPPF
# Q92813 :   corrected:  (seqNotFound)T132  site:  T132  seq len:  273 pep:  NFGSATPPFTS
# Q92813 :   corrected:  (seqNotFound)S262  site:  S262  seq len:  273 pep:  LEKNFSKRKKT
# Q92813 :   corrected:  (seqNotFound)T136  site:  T136  seq len:  273 pep:  ATPPFTSQLPA
# Q92813 :   corrected:  (seqNotFound)S137  site:  S137  seq len:  273 pep:  TPPFTSQLPAF
# Q92813 :   corrected:  (seqNotFound)T267  site:  T267  seq len:  273 pep:  SKRKKTRLAG
# Q8IZQ5 :   corrected:  (seqNotFound)T42  site:  T42  seq len:  122 pep:  VIEHCTSRVYG
# Q8IZQ5 :   corrected:  (seqNotFound)S43  site:  S43  seq len:  122 pep:  IEHCTSRVYGR
# Q8IZQ5 :   corrected:  (seqNotFound)Y46  site:  Y46  seq len:  122 pep:  CTSRVYGRNAA
# P63302 :   corrected:  (seqNotFound)Y9  site:  Y9  seq len:  87 pep:  AVRVVYCGAGY
# P63302 :   corrected:  (seqNotFound)Y14  site:  Y14  seq len:  87 pep:  YCGAGYKSKYL
# P63302 :   corrected:  (seqNotFound)S16  site:  S16  seq len:  87 pep:  GAGYKSKYLQL
# Q9C0D9 :   corrected:  (seqNotFound)S385  site:  S385  seq len:  397 pep:  LRKPNSDLGME
# Q9NZV5 :   corrected:  (seqNotFound)S127  site:  S127  seq len:  590 pep:  LPWLNSSCLSL
# Q9NZV5 :   corrected:  (seqNotFound)S128  site:  S128  seq len:  590 pep:  PWLNSSCLSLL
# Q9NZV5 :   corrected:  (seqNotFound)S131  site:  S131  seq len:  590 pep:  NSSCLSLLRST
# Q9NZV5 :   corrected:  (seqNotFound)S459  site:  S459  seq len:  590 pep:  ALDDQSCGSGR
# Q9NZV5 :   corrected:  (seqNotFound)S462  site:  S462  seq len:  590 pep:  DQSCGSGRTLR
# Q9NZV5 :   corrected:  (seqNotFound)T465  site:  T465  seq len:  590 pep:  CGSGRTLRETV
# Saving  2020 .tsv
# 2020 .tsv Done  18.765527725219727

# %% [markdown]
# 3. save '2020_mappedSite.csv' under the same dir as other *_mappedSite.csv files
#     - NetworKIN ignorgs the 'U'(Selenocysteine) in some substrate sequences, this causes frame shift of the downstream sequences
#     - those unmapped sites will not be included

# %%
start = time.time()
df_mapUpdateSite = pd.read_csv(NW_temp_dir_site_update + '2020_mappedSite.csv')
df_mapUpdateSite = df_mapUpdateSite[(df_mapUpdateSite['site'].str.contains('S|T|Y', na=False)) & (df_mapUpdateSite['substrate_id'] != 'outdated')]
df_mapUpdateSite.to_csv(NW_temp_dir_site + '2020_mappedSite.csv')
end = time.time()
print (f"Time\t{(end-start):.3f}")
df_mapUpdateSite
# Out:
# Time	3.122
#        Position   score substrate_name kinase_name          pep substrate_acc  \
# 0          Y256  0.3483           DIO3         SRC  SAYGAYFERLY        P55073
# 1          Y256  0.2997           DIO3       IGF1R  SAYGAYFERLY        P55073
# 2          Y256  0.2369           DIO3        FLT1  SAYGAYFERLY        P55073
# 3          Y256  0.2054           DIO3        ABL1  SAYGAYFERLY        P55073
# 4          Y256  0.1853           DIO3       MST1R  SAYGAYFERLY        P55073
# ...         ...     ...            ...         ...          ...           ...
# 677118    Y2038  0.0001           TRIO         HCK  AEYDAYFEEVK        O60229
# 677119    Y2038  0.0001           TRIO         BTK  AEYDAYFEEVK        O60229
# 677120    Y2038  0.0001           TRIO         FYN  AEYDAYFEEVK        O60229
# 677121    Y2038  0.0001           TRIO         KDR  AEYDAYFEEVK        O60229
# 677122    Y2038  0.0000           TRIO      PDGFRB  AEYDAYFEEVK        O60229
#
#        kinase_acc   site substrate_id
# 0          P12931   Y257   P55073_256
# 1          P08069   Y257   P55073_256
# 2          P17948   Y257   P55073_256
# 3          P00519   Y257   P55073_256
# 4          Q04912   Y257   P55073_256
# ...           ...    ...          ...
# 677118     P08631  Y2038  O60229_2038
# 677119     Q06187  Y2038  O60229_2038
# 677120     P06241  Y2038  O60229_2038
# 677121     P35968  Y2038  O60229_2038
# 677122     P09619  Y2038  O60229_2038
#
# [670235 rows x 9 columns]

# %% [markdown]
# ### Get the Gene Name of the Substrates from the Reference Human Proteome
# - get and add the Gene Name that would use across all perdictors for the substrates to the result files

# %%
# get the protein gene names and accessions from the Reference Human Proteome
df_unique_sub =  pd.read_csv(HP_csv, usecols = ['UniprotID','Gene Name'], sep = '\t')
df_unique_sub
# Out:
#       Gene Name   UniprotID
# 0         ACTN1      P12814
# 1         STAT3      P40763
# 2          ADD1      P35611
# 3          ADD2      P35612
# 4        ADRA2A      P08913
# ...         ...         ...
# 20358     HSFX4  A0A1B0GTS1
# 20359   TRBJ2-6  A0A0A0MT70
# 20360  TMEM225B      P0DP42
# 20361    SMIM29      Q86T20
# 20362    SCYGR6  A0A286YF77
#
# [20363 rows x 2 columns]

# %%
# add the Gene Name that would use across all perdictors for the substrates to the result files
start = time.time()
all_results = glob.glob(NW_temp_dir_site + '*.csv')

for filename in all_results:
    df = pd.read_csv(filename, usecols = ['substrate_id', 'substrate_acc', 'substrate_name', 'site', 'Position', 'pep', 'score', 'kinase_name', 'kinase_acc'])
    # merge df_subsMap with df_unique_sub to add the common substrate gene name to the df
    df = df.merge(df_unique_sub, left_on=['substrate_acc'], right_on=['UniprotID'], how = 'left')

    df = df.drop(columns = ['UniprotID'])
    df.to_csv(filename, index=False)
df
# Out:
#          Position   score substrate_name kinase_name          pep  \
# 0            S257  1.0740        NDUFAF1        PAK1  VKIPFSKFFFS
# 1            S257  0.9377        NDUFAF1       PRKCB  VKIPFSKFFFS
# 2            S257  0.5971        NDUFAF1       PRKCA  VKIPFSKFFFS
# 3            S257  0.3979        NDUFAF1       PRKCZ  VKIPFSKFFFS
# 4            S257  0.3288        NDUFAF1       PRKCD  VKIPFSKFFFS
# ...           ...     ...            ...         ...          ...
# 10144852     Y597  0.0001          WDR65       NTRK2  AFDVTYTAIVI
# 10144853     Y597  0.0001          WDR65         KDR  AFDVTYTAIVI
# 10144854     Y597  0.0000          WDR65      PDGFRB  AFDVTYTAIVI
# 10144855     Y597  0.0000          WDR65        TYK2  AFDVTYTAIVI
# 10144856     Y597  0.0000          WDR65         BTK  AFDVTYTAIVI
#
#          substrate_acc kinase_acc  site substrate_id Gene Name
# 0               Q9Y375     Q13153  S257   Q9Y375_257   NDUFAF1
# 1               Q9Y375     P05771  S257   Q9Y375_257   NDUFAF1
# 2               Q9Y375     P17252  S257   Q9Y375_257   NDUFAF1
# 3               Q9Y375     Q05513  S257   Q9Y375_257   NDUFAF1
# 4               Q9Y375     Q05655  S257   Q9Y375_257   NDUFAF1
# ...                ...        ...   ...          ...       ...
# 10144852        Q96MR6     Q16620  Y597   Q96MR6_597    CFAP57
# 10144853        Q96MR6     P35968  Y597   Q96MR6_597    CFAP57
# 10144854        Q96MR6     P09619  Y597   Q96MR6_597    CFAP57
# 10144855        Q96MR6     P29597  Y597   Q96MR6_597    CFAP57
# 10144856        Q96MR6     Q06187  Y597   Q96MR6_597    CFAP57
#
# [10144857 rows x 10 columns]

# %% [markdown]
# ### Creating Resource Files
# **globalKinaseMap**
# - creat a new or add unique kinases from NetworKIN to the globel kinase resource file.
# - get and add the Kinase Name that would use across all perdictors for the kinases to the result files

# %%
# get unique kinases in the NetworKIN result files

all_results = glob.glob(NW_temp_dir_site + '*.csv')

df_unique_kin = pd.DataFrame()

for filename in all_results:
    df = pd.read_csv(filename, usecols = ['kinase_acc', 'kinase_name'])
    df = df.drop_duplicates()
    df_unique_kin = df_unique_kin.append(df, ignore_index=True)
    
df_unique_kin = df_unique_kin.drop_duplicates()
df_unique_kin
# Out:
#     kinase_name kinase_acc
# 0         PRKCB     P05771
# 1         PRKCA     P17252
# 2         PRKCZ     Q05513
# 3         PRKCD     Q05655
# 4         PRKCG     P05129
# ..          ...        ...
# 189         FYN     P06241
# 190      MAPK13     O15264
# 191      MAPK12     P53778
# 192      MAPK11     Q15759
# 193      MAPK14     Q16539
#
# [194 rows x 2 columns]

# %%
# start = time.time()
unmapped_list = pd.DataFrame()

if os.path.isfile(KinaseMap): 
    df_humanKinase = pd.read_csv(KinaseMap)
# if globalkinaseMap.csv file does not exist, create an new df using orginal human kinase map
else:
    df_humanKinase = pd.read_csv(HK_org, usecols = ['Kinase Name', 'Preferred Name', 'UniprotID', 'Type', 'description'], sep = '\t')
    df_humanKinase['description'].replace(regex=True,inplace=True,to_replace=r'\[Source.+\]',value=r'')

# add unique kinases from NetworKIN to the globel kinases resource file
for index, row in df_unique_kin.iterrows():
    kinase = df_unique_kin.at[index, 'kinase_acc']
    # if the kinase/other enzyme already in the globalKinaseMap.csv file
    if any(df_humanKinase.UniprotID == kinase):
        # get the index of the substrate in the globalKinaseMap.csv file 
        idx = df_humanKinase.index[df_humanKinase.UniprotID == kinase].values[0] 

        df_humanKinase.at[idx, 'NetworKIN_kinase_name'] = df_unique_kin.at[index, 'kinase_name']
        
    # if the kinase is not in the globalKinaseMap.csv file, we need a list to check annotations manullay
    else:
        unmapped_list = unmapped_list.append(row,sort=False).reset_index(drop=True)
        
print (unmapped_list)
# Out:
#   kinase_acc kinase_name
# 0     Q16654        PDK4
# 1     Q15120        PDK3
# 2     Q15119        PDK2
# 3     Q86VQ0        LCA5

# %% [markdown]
# - Manually check the above unmapped kinase. Create a dictionay for the one(s) that are kinases to add in the globalKinaseMap.csv.  Create a list of the one(s) that are not kinases to drop records from the NetworKIN result files.

# %%
new_kinase = {'EPHB6':'Ephrin type-B receptor 6'}

not_kinase = ['PDK2','PDK3','PDK4','LCA5']

# %% [markdown]
# - add the 1 protein kinases to the globalKinaseMap.csv using above dictionary

# %%
# get the length (last index) of the current df_humanKinase
len = df_humanKinase.UniprotID.count()

# add the 1 new kinase in the globalKinaseMap.csv
for key in new_kinase:
    # add the kinase name and description for the new kinase 
    df_humanKinase = df_humanKinase.append({'Kinase Name': key}, ignore_index=True)
    df_humanKinase.at[len,'Preferred Name'] = key
    df_humanKinase.at[len,'description'] = new_kinase[key]
    # get the index of where the new kinase is in the df_unique_kinase
    i = df_unique_kin.index[df_unique_kin['kinase_name'] == key].values[0] 
    # add the uniprotID for the new kinase 
    df_humanKinase.at[len,'UniprotID'] = df_unique_kin.at[i, 'kinase_acc']
    # add the accs used in NetworKIN for the new kinase
    df_humanKinase.at[len,'NetworKIN_kinase_name'] = df_unique_kin.at[i, 'kinase_name']

    len += 1

df_humanKinase.to_csv(KinaseMap,index = False) 
df_humanKinase
# Out:
#     Kinase Name UniprotID                                        description  \
# 0          SGK1    O00141           serum/glucocorticoid regulated kinase 1
# 1        BMPR1B    O00238       bone morphogenetic protein receptor type 1B
# 2          CDC7    O00311                             cell division cycle 7
# 3          PLK4    O00444                                polo like kinase 4
# 4         STK25    O00506                        serine/threonine kinase 25
# ..          ...       ...                                                ...
# 484      TP53RK    Q96S44                   EKC/KEOPS complex subunit TP53RK
# 485       TRPM6    Q9BX84  Transient receptor potential cation channel su...
# 486     BCR/ABL    A9UF07                  BCR/ABL fusion protein isoform Y5
# 487       BCKDK    O14874  [3-methyl-2-oxobutanoate dehydrogenase [lipoam...
# 488       EPHB6    O15197                           Ephrin type-B receptor 6
#
#     HPRD_kinase_name HPRD_kinase_uniprot_id HPRD_kinase_refseq_id  \
# 0               SGK1                 O00141        NP_001137148.1
# 1             BMPR1B                 O00238           NP_001194.1
# 2                NaN                    NaN                   NaN
# 3                NaN                    NaN                   NaN
# 4              STK25                 O00506           NP_006365.2
# ..               ...                    ...                   ...
# 484              NaN                    NaN                   NaN
# 485              NaN                    NaN                   NaN
# 486              NaN                    NaN                   NaN
# 487              NaN                    NaN                   NaN
# 488              NaN                    NaN                   NaN
#
#     PhosphoSite_kinase_uniprot_id PhosphoSite_kinase_name  \
# 0                          O00141                    SGK1
# 1                          O00238                  BMPR1B
# 2                          O00311                    CDC7
# 3                          O00444                    PLK4
# 4                          O00506                    YSK1
# ..                            ...                     ...
# 484                        Q96S44                    PRPK
# 485                        Q9BX84                   ChaK2
# 486                        A9UF07                BCR-ABL1
# 487                           NaN                     NaN
# 488                           NaN                     NaN
#
#     PhosphoSite_kinase_gene_name GPS5_kinase_name NetworKIN_kinase_name
# 0                           SGK1             SGK1                  SGK1
# 1                         BMPR1B           BMPR1B                   NaN
# 2                           CDC7             CDC7                   NaN
# 3                           PLK4             PLK4                   NaN
# 4                          STK25            STK25                 STK25
# ..                           ...              ...                   ...
# 484                       TP53RK           TP53RK                   NaN
# 485                        TRPM6            TRPM6                   NaN
# 486                      BCR/ABL              NaN                   NaN
# 487                          NaN            BCKDK                 BCKDK
# 488                          NaN              NaN                 EPHB6
#
# [489 rows x 11 columns]

# %%
# get the new list kinase with common kinase name that would use across all referece and the uniprotID for these kinase
df_unique_kin = df_humanKinase[['Kinase Name','UniprotID']]
df_unique_kin
# Out:
#     Kinase Name UniprotID
# 0          SGK1    O00141
# 1        BMPR1B    O00238
# 2          CDC7    O00311
# 3          PLK4    O00444
# 4         STK25    O00506
# ..          ...       ...
# 484      TP53RK    Q96S44
# 485       TRPM6    Q9BX84
# 486     BCR/ABL    A9UF07
# 487       BCKDK    O14874
# 488       EPHB6    O15197
#
# [489 rows x 2 columns]

# %% [markdown]
# - remove the 4 enzyme records that are not protein kinase from the NetworKIN result files
# - add the Kinase Name that would use across all perdictors for the kinase to the result files

# %%
all_results = glob.glob(NW_temp_dir_site + '*.csv')

for filename in all_results:
    df = pd.read_csv(filename)
    # remove the 4 enzyme records that are not protein kinase from the df_kinaseMap
    df = df[~df['kinase_name'].isin(not_kinase)]

    # merge with df_unique_kinase to add the common kinase name to the df
    df = df.merge(df_unique_kin, left_on='kinase_acc', right_on='UniprotID', how = 'left')
    # drop the duplicated uniprot id for kinases
    df = df.drop(columns = 'UniprotID')

    df.to_csv(filename,index=False)  

df
# Out:
#         Position   score substrate_name kinase_name          pep  \
# 0           S257  1.0740        NDUFAF1        PAK1  VKIPFSKFFFS
# 1           S257  0.9377        NDUFAF1       PRKCB  VKIPFSKFFFS
# 2           S257  0.5971        NDUFAF1       PRKCA  VKIPFSKFFFS
# 3           S257  0.3979        NDUFAF1       PRKCZ  VKIPFSKFFFS
# 4           S257  0.3288        NDUFAF1       PRKCD  VKIPFSKFFFS
# ...          ...     ...            ...         ...          ...
# 9912858     Y597  0.0001          WDR65       NTRK2  AFDVTYTAIVI
# 9912859     Y597  0.0001          WDR65         KDR  AFDVTYTAIVI
# 9912860     Y597  0.0000          WDR65      PDGFRB  AFDVTYTAIVI
# 9912861     Y597  0.0000          WDR65        TYK2  AFDVTYTAIVI
# 9912862     Y597  0.0000          WDR65         BTK  AFDVTYTAIVI
#
#         substrate_acc kinase_acc  site substrate_id Gene Name Kinase Name
# 0              Q9Y375     Q13153  S257   Q9Y375_257   NDUFAF1        PAK1
# 1              Q9Y375     P05771  S257   Q9Y375_257   NDUFAF1       PRKCB
# 2              Q9Y375     P17252  S257   Q9Y375_257   NDUFAF1       PRKCA
# 3              Q9Y375     Q05513  S257   Q9Y375_257   NDUFAF1       PRKCZ
# 4              Q9Y375     Q05655  S257   Q9Y375_257   NDUFAF1       PRKCD
# ...               ...        ...   ...          ...       ...         ...
# 9912858        Q96MR6     Q16620  Y597   Q96MR6_597    CFAP57       NTRK2
# 9912859        Q96MR6     P35968  Y597   Q96MR6_597    CFAP57         KDR
# 9912860        Q96MR6     P09619  Y597   Q96MR6_597    CFAP57      PDGFRB
# 9912861        Q96MR6     P29597  Y597   Q96MR6_597    CFAP57        TYK2
# 9912862        Q96MR6     Q06187  Y597   Q96MR6_597    CFAP57         BTK
#
# [9912863 rows x 11 columns]

# %% [markdown]
# # Standard Formatted NetWorKIN
# ### 'NetworKIN_formatted.csv'
# Standardize the preprocessed file with following columns:
#
# - substrate_id - unique IDs for the substrate phosphorylation site (substrate_acc + position)
# - substrate_name - gene name for the substrates
# - substrate_acc - mapped UniprotIDs for the substrates
# - site - phosphorylation site
# - pep - +/- 5 AA peptide sequence around the site
# - score - perdiction score
# - Kinase Name - Kinase name

# %%
all_results = glob.glob(NW_temp_dir_site + '*.csv')
NW = []
for filename in all_results:
    df = pd.read_csv(filename, usecols = ['substrate_id','substrate_acc','Gene Name', 'site','pep', 'score', 'Kinase Name'])
    df = df.rename(columns={'Gene Name': 'substrate_name'})
    NW.append(df)
        
df_final = pd.concat(NW)
df_final = df_final.drop_duplicates()
df_final.to_csv(NW_formatted, chunksize = 1000000, index = False)
df_final
# Out:
#           substrate_id substrate_acc substrate_name  site          pep  \
# 0             O60294_5        O60294          LCMT2    S5  _MGPRSRERRA
# 1             O60294_5        O60294          LCMT2    S5  _MGPRSRERRA
# 2             O60294_5        O60294          LCMT2    S5  _MGPRSRERRA
# 3             O60294_5        O60294          LCMT2    S5  _MGPRSRERRA
# 4             O60294_5        O60294          LCMT2    S5  _MGPRSRERRA
# ...                ...           ...            ...   ...          ...
# 192836106   Q96MR6_597        Q96MR6         CFAP57  Y597  AFDVTYTAIVI
# 192836107   Q96MR6_597        Q96MR6         CFAP57  Y597  AFDVTYTAIVI
# 192836108   Q96MR6_597        Q96MR6         CFAP57  Y597  AFDVTYTAIVI
# 192836109   Q96MR6_597        Q96MR6         CFAP57  Y597  AFDVTYTAIVI
# 192836110   Q96MR6_597        Q96MR6         CFAP57  Y597  AFDVTYTAIVI
#
#             score Kinase Name
# 0          2.4948       PRKCB
# 1          1.3048       PRKCA
# 2          1.2440       PRKCZ
# 3          0.5110       PRKCD
# 4          0.4732       PRKCG
# ...           ...         ...
# 192836106  0.0001       NTRK2
# 192836107  0.0001         KDR
# 192836108  0.0000      PDGFRB
# 192836109  0.0000        TYK2
# 192836110  0.0000         BTK
#
# [192836111 rows x 7 columns]
