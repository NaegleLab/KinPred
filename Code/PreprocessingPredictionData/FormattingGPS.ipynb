# %% [markdown]
# # Introduction
#
# ### Get GPS Result Files
# 1.  The current version of human proteome conanical sequences were downloaded from [Uniprit.org](https://www.uniprot.org)
#     - use CreateHumanProteomeDF.ipynb
#     - Or, go [HERE](https://www.uniprot.org/uniprot/?query=*&fil=organism%3A%22Homo+sapiens+%28Human%29+%5B9606%5D%22+AND+reviewed%3Ayes), click on 'Download'-> FASTA(canonical)
# 2.  split the downloaded fasta file into smaller files with 1000 sequence in each. The last file has 367 sequences. (CreateHumanProteomeDF.ipynb)
# 3. Download the GPS softwarefor your operating system from [GPS downloading page](http://gps.biocuckoo.cn/download.php). Follow the user prompts through the installation.
# 4.  Follow the instruction of 'Batch Prediction' on page 8 of the [User Guide](http://gps.biocuckoo.cn/download/GPS_5.0_Manual_2019.pdf)
# 5.  submit the sequence files in GPS BatchPredictor with the following settings:
#     - **PKs**: select all kinases
#     - **Sequence File List:** add the sequence fasta files
#     - **result Export Folder:** choose the dir to save the output files ('../Data/Raw/GPS/')
#     - **Threshold:** all
#
#
# ### About the data
# - Version: Nov., 2019
# - GPS will take about 10 days to complete the prediction all the human proteomes
# - raw predictions are available upon request
#
# ### Preprocessing GPS Raw
# In order to convert this to standard format, here we:
# 1. Convert the GPS predictors in the manually created gps_predictor.csv file to kinases with kinase_acc (UniprotID).
#     - input files:  **'gps_predictor.csv'**
#     - output file: **'gps_predictor.csv'** output data frame with the following columns:
#        - **predictor** - GPS predictors for each kinase
#        - **kinase**	- kinase names used in GPS
#        - **kinase_acc** - UniprotIDs of the kinases
#
# 1. Convert the result files to a data frame containing following columns, and combine the 21 result files into one GPS file:
#     - **Mapping Substrate Accessions (UniprotID)** Extract the substrate UniprotID from the idendifiers of the submitted sequences. Create the the 'substrate_acc' column.
#     - **Mapping Kinase Accessions (UniprotID)** Merge the converted data frame with the manually generated 'gps_valid_kinases.csv'
#     - output data frame with the following columns:
#         - **substrate_acc** - UniprotIDs extracted from the idendifiers of the submitted sequences
#         - **site** -  'residue' + 'position'
#         - **residue** - AA at the phosphorylated position
#         - **position** - position in the protein sequence
#         - **predictor** - GPS predictor
#         - **pep** - +/- 7AA peptides
#         - **score**
#         - **threshold**
#         - **kinase** - kinase name used in GPS
#         - **kinase_acc** - UniprotIDs of the kinases
#
#         - input files:  21 GPS result files
#         - output file: **'GPS_temp_mappedAcc.csv'**
#
#     - **Mapping sites** Map the phosphorylation site relative to the current human proteome sequence. This will filter out the outdated records.
#         - input file:  'GPS_temp_mappedAcc.csv
#         - final output file: **'GPS_temp_mappedSite.csv'** added/updated columns:
#             - **substrate_id** - unique IDs for the substrate phosphorylation site (substrate_acc + position)
#             - **site** - mapped phosphorylation site
#
#
#
# ### Creating Resource Files
# 1.  **'globalKinaseMap.csv':** After step 1 in preprocessing, add unique kinases from GPS to the globel kinase resource.
#
#
# ### Standard Formatted GPS
# **'GPS.csv':** Standardize the preprocessed file with following columns:
# - **substrate_id** - unique IDs for the substrate phosphorylation site (substrate_acc + position)
# - **substrate** - gene name for the substrates
# - **substrate_acc** - mapped UniprotIDs for the substrates
# - **site** - phosphorylation  site
# - **pep** - +/- 7 AA peptide sequence around the site
# - **kinase** - Kinase name

# %% [markdown]
# # Initializing

# %%
# IMPORTS
#%pip install 
import pandas as pd
import glob
import os
import time
import re

import humanProteomesReference, gps_convert, getUniprotID, createSubKinMatrix

# %%
# DEFINE FILE NAMES/DIRs 
##################
# Version (Date) #
##################
version = '2019-12-11'

##################
# File Location  #
##################
# local (../../)
base = '../../'

###############################################
# For Prepare Fasta Files to Submit in GPS #
###############################################
# Human Proteome fasta file
HP_fasta = base + 'Data/Raw/HumanProteome/humanProteome_' + version + '.fasta'
# Dir for splited Human Proteome fasta files
HP_dir = base + 'Data/Raw/HumanProteome/'


###############################################
# For Preprocessing GPS Prediction Results #
###############################################

# human proteome referece file 
HP_csv = base + 'Data/Map/humanProteome_' + version + '.csv'

# manually prepared GPS perdictor table
GPS_predictor = base + 'Data/Raw/GPS/gps_predictor.csv'
GPS_kinase = base + 'Data/Raw/GPS/gps_valid_kinases.csv'

# GPS results dir
GPS_dir = base + 'Data/Raw/GPS/'
GPS_update_dir = base + 'Data/Raw/GPS/updated/'

# GPS temp dir
GPS_temp_dir_acc = base + 'Data/Temp/GPS/mappedAcc/'
GPS_temp_dir_site = base + 'Data/Temp/GPS/mappedSite/'
GPS_temp_dir_acc_update = base + 'Data/Temp/GPS/mappedAcc/updated/'
GPS_temp_dir_site_update = base + 'Data/Temp/GPS/mappedSite/updated/'

# Resource Files
HK_org = base + 'Data/Raw/HumanKinase/globalKinaseMap.txt'                  # orginal manually created kinase file
KinaseMap = base + 'Data/Map/globalKinaseMap.csv'                           # add all unique kinase in HPRD to the global file

# Standard formatted output file
GPS_formatted = base + 'Data/Formatted/GPS/GPS_formatted_' + version + '.csv'       # preprocessed file with cloumns: substrate_id/substrate/substrate_acc/kinase/site/pep/score

# %% [markdown]
# # Preprocessing GPS Raw Predictions
# ### Convert GPS predictor
# Convert the GPS predictors in the manually created gps5_predictor.csv file to kinases with kinase_acc (UniprotID).

# %%
# convert the predictor to kinases with kinase_acc
gps_predictor = pd.read_csv(GPS_predictor)
# the individual kinase name is after the last '/' in the predictor name (e.g. the kinase predicted by 'AGC/Akt/AKT1' is 'AKT1')
gps_predictor['kinase'] = gps_predictor.apply(lambda row :  re.search(r'.+\/(.+)$', str(row['predictor'])).group(1), axis = 1) 
# get the uniprotID of the kinases
gps_predictor['kinase_acc'] = gps_predictor.apply(lambda row :  getUniprotID.getUniprotID(str(row['kinase']), 'gene name'), axis = 1) 
gps_predictor
# Out:
# CBK1 no hit in human
# PKH1 no hit in human
# PKH2 no hit in human
# SRK2E no hit in human
# MLKA no hit in human
# DUN1 no hit in human
# CDC28 no hit in human
# PHO85 no hit in human
# GSK3 no hit in human
# FUS3 no hit in human
# HOG1 no hit in human
# CLA4 no hit in human
# STE20 no hit in human
# TOR2 no hit in human
# RIO no hit in human
# AurB no hit in human
# IPL1 no hit in human
# CDC5 no hit in human
# EPHB5 no hit in human
# AGC no hit in human
# Aur no hit in human
#                       predictor   kinase         kinase_acc
# 0                  AGC/Akt/AKT1     AKT1             P31749
# 1                  AGC/Akt/AKT2     AKT2             P31751
# 2                  AGC/Akt/AKT3     AKT3             Q9Y243
# 3             AGC/DMPK/CRIK/CIT      CIT             O14578
# 4             AGC/DMPK/GEK/DMPK     DMPK             Q09013
# ..                          ...      ...                ...
# 359  Dual/TKL/STKR/STKR2/TGFBR2   TGFBR2             P37173
# 360              Dual/Other/Aur      Aur  (no hit in human)
# 361  Dual/Other/PEK/PKR/EIF2AK2  EIF2AK2             P19525
# 362   Dual/Other/WEE/WEE1/WEE1B    WEE1B             P0C1S8
# 363    Dual/Other/WEE/WEE1/WEE1     WEE1             P30291
#
# [364 rows x 3 columns]

# %% [markdown]
# Create a dictionary of the human kinases that fail to retrieve Programmatically. Using the dictionary to make the chages in the gps_kinases dataframe.

# %%
new_kinase = {'AurB' : 'Q96GD4'}
# Manually add the uniprotID for the above kinase
for key in new_kinase:
    gps_predictor.loc[gps_predictor.kinase == key, ["kinase_acc"]] = new_kinase[key]
# remove non-human kinases
gps_predictor = gps_predictor[gps_predictor['kinase_acc'] != '(no hit in human)']

gps_predictor
# Out:
#                       predictor   kinase kinase_acc
# 0                  AGC/Akt/AKT1     AKT1     P31749
# 1                  AGC/Akt/AKT2     AKT2     P31751
# 2                  AGC/Akt/AKT3     AKT3     Q9Y243
# 3             AGC/DMPK/CRIK/CIT      CIT     O14578
# 4             AGC/DMPK/GEK/DMPK     DMPK     Q09013
# ..                          ...      ...        ...
# 358         Dual/TKL/LRRK/LRRK2    LRRK2     Q5S007
# 359  Dual/TKL/STKR/STKR2/TGFBR2   TGFBR2     P37173
# 361  Dual/Other/PEK/PKR/EIF2AK2  EIF2AK2     P19525
# 362   Dual/Other/WEE/WEE1/WEE1B    WEE1B     P0C1S8
# 363    Dual/Other/WEE/WEE1/WEE1     WEE1     P30291
#
# [344 rows x 3 columns]

# %% [markdown]
# get a list Kinases that are predicted by multiple predictors. Get the indexs of the ones predict by the Dual predictors, remove them from the gps_kinases, save the file.

# %%
duplicateKinase = gps_predictor[gps_predictor.duplicated(['kinase'], keep = False)].sort_values(by=['kinase'])
duplicateKinase = duplicateKinase[(duplicateKinase['predictor'].str.contains('Dual'))]
idx_li = duplicateKinase.index.values.tolist()
idx_li
# Out:
# [278,
#  346,
#  349,
#  350,
#  361,
#  358,
#  353,
#  354,
#  356,
#  355,
#  357,
#  351,
#  352,
#  347,
#  275,
#  276,
#  277,
#  359]

# %%
# remove the Dual predictor of the kinase predicted by multipule GPS predictor
for idx in idx_li:
    gps_predictor = gps_predictor.drop(idx)
# save the file
gps_predictor.to_csv(GPS_kinase, index=False)
gps_predictor
# Out:
#                      predictor   kinase kinase_acc
# 0                 AGC/Akt/AKT1     AKT1     P31749
# 1                 AGC/Akt/AKT2     AKT2     P31751
# 2                 AGC/Akt/AKT3     AKT3     Q9Y243
# 3            AGC/DMPK/CRIK/CIT      CIT     O14578
# 4            AGC/DMPK/GEK/DMPK     DMPK     Q09013
# ..                         ...      ...        ...
# 343               TK/VEGFR/KDR      KDR     P35968
# 345    Dual/Atypical/BAZ/BAZ1B    BAZ1B     Q9UIG0
# 348      Dual/CMGC/CK2/CSNK2A1  CSNK2A1     P68400
# 362  Dual/Other/WEE/WEE1/WEE1B    WEE1B     P0C1S8
# 363   Dual/Other/WEE/WEE1/WEE1     WEE1     P30291
#
# [326 rows x 3 columns]

# %% [markdown]
# ### Convert GPS Data Frame
#
# - convert the fasta like GPS result files to a pandas data frame
# - **Mapping Substrate Accessions (UniprotID)** Extract the substrate UniprotID from the idendifiers of the submitted sequences. Create the the 'substrate_acc' column.
# - **Mapping Kinase Accessions (UniprotID)** Merge the converted data frame with the manually generated 'gps_valid_kinases.csv' with  following coulmns:
#     - **predictor** - list of GPS predictor
#     - **kinase** - the name of the kinase used in GPS
#     - **is_kinase** - 0 (family or group) or 1 (kinase), **this file ONLY contains perdictions of kinase, kinase group/family are excluded.**
#     - **kinase_acc** - programmatically retreived UniprotID from the given kinase names with manual confirmation. (the ones that are not human kinase or no hit in Uniprot.org are '(no hit in human)' )
# - Combine the 'residue' and 'position' to create the 'site' column
# - the output df contains the following columns:
#     - **substrate_acc** - UniprotIDs extracted from the idendifiers of the submitted sequences
#     - **site** -  'residue' + 'position'
#     - **residue** - AA at the phosphorylated position
#     - **position** - position in the protein sequence
#     - **predictor** - GPS predictor
#     - **pep** - +/- 7AA peptides
#     - **score**
#     - **threshold**
#     - **kinase** - kinase name used in GPS
#     - **kinase_acc**

# %%
# create a data frame from the GPS raw, add substrate and kinase preotien acc (uniprotID)
convert_type = 'acc'
gps_convert.gps_convert_directory(GPS_dir, GPS_kinase, GPS_temp_dir_acc, convert_type)
# Out:
# Formatting  group_2 ...
# Done. Time	1518.487
# Formatting  group_17 ...
# Done. Time	1558.139
# Formatting  group_4 ...
# Done. Time	1710.565
# Formatting  group_9 ...
# Done. Time	1631.413
# Formatting  group_11 ...
# Done. Time	1962.357
# Formatting  group_3 ...
# Done. Time	1925.417
# Formatting  group_16 ...
# Done. Time	2118.729
# Formatting  group_5 ...
# Done. Time	2445.987
# Formatting  group_8 ...
# Done. Time	2148.243
# Formatting  group_10 ...
# Done. Time	2218.017
# Formatting  group_18 ...
# Done. Time	2198.258
# Formatting  group_20 ...
# Done. Time	2143.964
# Formatting  group_15 ...
# Done. Time	2150.675
# Formatting  group_6 ...
# Done. Time	2372.631
# Formatting  group_13 ...
# Done. Time	2279.974
# Formatting  group_1 ...
# Done. Time	2274.745
# Formatting  group_19 ...
# Done. Time	2372.402
# Formatting  group_21 ...
# Done. Time	358.565
# Formatting  group_14 ...
# Done. Time	1977.981
# Formatting  group_7 ...
# Done. Time	2007.099
# Formatting  group_12 ...
# Done. Time	2388.232

# %% [markdown]
# ### Mapping Sites against the current human Proteomes
# - get the +/- 7 AA peptide using the position from the referece human Proteomes csv file
# - compare the retrieved peptide sequence with the provied peptide sequence in the GPS df
# - assign substrate_id (substrate_acc + position) to the ones with matched pep seq,
# - assign substrate_id as 'outdated' to the ones that are not matched

# %%
# map the site to the reference human proteome seq (version at the time is Dec. 2019)
convert_type = 'site'
gps_convert.gps_convert_directory(GPS_temp_dir_acc, HP_csv, GPS_temp_dir_site, convert_type)
# Out:
# Formatting  group_21.csv ...
# Reading input file...
# Get unique substrate sites...
# Map unique substrate sites...
# Done. Time	96.451
# Formatting  group_8.csv ...
# Reading input file...
# Get unique substrate sites...
# Map unique substrate sites...
# Q29974 :   corrected:  (idNotFound)10  site:  10 pep:  CLKLPGGSCMTALTV
# Q29974 :   corrected:  (idNotFound)13  site:  13 pep:  LPGGSCMTALTVTLM
# Q29974 :   corrected:  (idNotFound)16  site:  16 pep:  GSCMTALTVTLMVLS
# Q29974 :   corrected:  (idNotFound)18  site:  18 pep:  CMTALTVTLMVLSSP
# Q29974 :   corrected:  (idNotFound)23  site:  23 pep:  TVTLMVLSSPLALAG
# Q29974 :   corrected:  (idNotFound)24  site:  24 pep:  VTLMVLSSPLALAGD
# Q29974 :   corrected:  (idNotFound)32  site:  32 pep:  PLALAGDTRPRFLWQ
# Q29974 :   corrected:  (idNotFound)50  site:  50 pep:  ECHFFNGTERVRFLD
# Q29974 :   corrected:  (idNotFound)66  site:  66 pep:  YFYNQEESVRFDSDV
# Q29974 :   corrected:  (idNotFound)71  site:  71 pep:  EESVRFDSDVGEYRA
# Q29974 :   corrected:  (idNotFound)80  site:  80 pep:  VGEYRAVTELGRPDA
# Q29974 :   corrected:  (idNotFound)92  site:  92 pep:  PDAEYWNSQKDFLED
# Q29974 :   corrected:  (idNotFound)106  site:  106 pep:  DRRAAVDTYCRHNYG
# Q29974 :   corrected:  (idNotFound)117  site:  117 pep:  HNYGVGESFTVQRRV
# Q29974 :   corrected:  (idNotFound)119  site:  119 pep:  YGVGESFTVQRRVQP
# Q29974 :   corrected:  (idNotFound)129  site:  129 pep:  RRVQPKVTVYPSKTQ
# Q29974 :   corrected:  (idNotFound)133  site:  133 pep:  PKVTVYPSKTQPLQH
# Q29974 :   corrected:  (idNotFound)135  site:  135 pep:  VTVYPSKTQPLQHHN
# Q29974 :   corrected:  (idNotFound)147  site:  147 pep:  HHNLLVCSVSGFYPG
# Q29974 :   corrected:  (idNotFound)149  site:  149 pep:  NLLVCSVSGFYPGSI
# Q29974 :   corrected:  (idNotFound)155  site:  155 pep:  VSGFYPGSIEVRWFL
# Q29974 :   corrected:  (idNotFound)173  site:  173 pep:  EEKAGMVSTGLIQNG
# Q29974 :   corrected:  (idNotFound)174  site:  174 pep:  EKAGMVSTGLIQNGD
# Q29974 :   corrected:  (idNotFound)183  site:  183 pep:  LIQNGDWTFQTLVML
# Q29974 :   corrected:  (idNotFound)186  site:  186 pep:  NGDWTFQTLVMLETV
# Q29974 :   corrected:  (idNotFound)192  site:  192 pep:  QTLVMLETVPRSGEV
# Q29974 :   corrected:  (idNotFound)196  site:  196 pep:  MLETVPRSGEVYTCQ
# Q29974 :   corrected:  (idNotFound)201  site:  201 pep:  PRSGEVYTCQVEHPS
# Q29974 :   corrected:  (idNotFound)208  site:  208 pep:  TCQVEHPSVTSPLTV
# Q29974 :   corrected:  (idNotFound)210  site:  210 pep:  QVEHPSVTSPLTVEW
# Q29974 :   corrected:  (idNotFound)211  site:  211 pep:  VEHPSVTSPLTVEWR
# Q29974 :   corrected:  (idNotFound)214  site:  214 pep:  PSVTSPLTVEWRARS
# Q29974 :   corrected:  (idNotFound)221  site:  221 pep:  TVEWRARSESAQSKM
# Q29974 :   corrected:  (idNotFound)223  site:  223 pep:  EWRARSESAQSKMLS
# Q29974 :   corrected:  (idNotFound)226  site:  226 pep:  ARSESAQSKMLSGVG
# Q29974 :   corrected:  (idNotFound)230  site:  230 pep:  SAQSKMLSGVGGFVL
# Q29974 :   corrected:  (idNotFound)257  site:  257 pep:  FRNQKGHSGLQPTGF
# Q29974 :   corrected:  (idNotFound)262  site:  262 pep:  GHSGLQPTGFLS
# Q29974 :   corrected:  (idNotFound)266  site:  266 pep:  LQPTGFLS
# P01160 :   corrected:  (seqNotFound)148  site:  148  seq len:  151 pep:  QSGLGCNSFRYRR
# Q95IE3 :   corrected:  (idNotFound)10  site:  10 pep:  CLRLPGGSCMAVLTV
# Q95IE3 :   corrected:  (idNotFound)16  site:  16 pep:  GSCMAVLTVTLMVLS
# Q95IE3 :   corrected:  (idNotFound)18  site:  18 pep:  CMAVLTVTLMVLSSP
# Q95IE3 :   corrected:  (idNotFound)23  site:  23 pep:  TVTLMVLSSPLALAG
# Q95IE3 :   corrected:  (idNotFound)24  site:  24 pep:  VTLMVLSSPLALAGD
# Q95IE3 :   corrected:  (idNotFound)32  site:  32 pep:  PLALAGDTRPRFLEY
# Q95IE3 :   corrected:  (idNotFound)40  site:  40 pep:  RPRFLEYSTGECYFF
# Q95IE3 :   corrected:  (idNotFound)41  site:  41 pep:  PRFLEYSTGECYFFN
# Q95IE3 :   corrected:  (idNotFound)50  site:  50 pep:  ECYFFNGTERVRLLE
# Q95IE3 :   corrected:  (idNotFound)71  site:  71 pep:  EELLRFDSDVGEFRA
# Q95IE3 :   corrected:  (idNotFound)80  site:  80 pep:  VGEFRAVTELGRPVA
# Q95IE3 :   corrected:  (idNotFound)89  site:  89 pep:  LGRPVAESWNSQKDI
# Q95IE3 :   corrected:  (idNotFound)92  site:  92 pep:  PVAESWNSQKDILED
# Q95IE3 :   corrected:  (idNotFound)106  site:  106 pep:  DRRAAVDTYCRHNYG
# Q95IE3 :   corrected:  (idNotFound)117  site:  117 pep:  HNYGAVESFTVQRRV
# Q95IE3 :   corrected:  (idNotFound)119  site:  119 pep:  YGAVESFTVQRRVHP
# Q95IE3 :   corrected:  (idNotFound)129  site:  129 pep:  RRVHPKVTVYPSKTQ
# Q95IE3 :   corrected:  (idNotFound)133  site:  133 pep:  PKVTVYPSKTQPLQH
# Q95IE3 :   corrected:  (idNotFound)135  site:  135 pep:  VTVYPSKTQPLQHHN
# Q95IE3 :   corrected:  (idNotFound)147  site:  147 pep:  HHNLLVCSVSGFYPG
# Q95IE3 :   corrected:  (idNotFound)149  site:  149 pep:  NLLVCSVSGFYPGSI
# Q95IE3 :   corrected:  (idNotFound)155  site:  155 pep:  VSGFYPGSIEVRWFR
# Q95IE3 :   corrected:  (idNotFound)169  site:  169 pep:  RNGQEEKTGVVSTGL
# Q95IE3 :   corrected:  (idNotFound)173  site:  173 pep:  EEKTGVVSTGLIHNG
# Q95IE3 :   corrected:  (idNotFound)174  site:  174 pep:  EKTGVVSTGLIHNGD
# Q95IE3 :   corrected:  (idNotFound)183  site:  183 pep:  LIHNGDWTFQTLVML
# Q95IE3 :   corrected:  (idNotFound)186  site:  186 pep:  NGDWTFQTLVMLETV
# Q95IE3 :   corrected:  (idNotFound)192  site:  192 pep:  QTLVMLETVPRSGEV
# Q95IE3 :   corrected:  (idNotFound)196  site:  196 pep:  MLETVPRSGEVYTCQ
# Q95IE3 :   corrected:  (idNotFound)201  site:  201 pep:  PRSGEVYTCQVEHPS
# Q95IE3 :   corrected:  (idNotFound)208  site:  208 pep:  TCQVEHPSVTSPLTV
# Q95IE3 :   corrected:  (idNotFound)210  site:  210 pep:  QVEHPSVTSPLTVEW
# Q95IE3 :   corrected:  (idNotFound)211  site:  211 pep:  VEHPSVTSPLTVEWR
# Q95IE3 :   corrected:  (idNotFound)214  site:  214 pep:  PSVTSPLTVEWRARS
# Q95IE3 :   corrected:  (idNotFound)221  site:  221 pep:  TVEWRARSESAQSKM
# Q95IE3 :   corrected:  (idNotFound)223  site:  223 pep:  EWRARSESAQSKMLS
# Q95IE3 :   corrected:  (idNotFound)226  site:  226 pep:  ARSESAQSKMLSGVG
# Q95IE3 :   corrected:  (idNotFound)230  site:  230 pep:  SAQSKMLSGVGGFVL
# Q95IE3 :   corrected:  (idNotFound)257  site:  257 pep:  FRNQKGHSGLQPRGF
# Q95IE3 :   corrected:  (idNotFound)266  site:  266 pep:  LQPRGFLS
# Q29974 :   corrected:  (idNotFound)59  site:  59 pep:  RVRFLDRYFYNQEES
# Q29974 :   corrected:  (idNotFound)61  site:  61 pep:  RFLDRYFYNQEESVR
# Q29974 :   corrected:  (idNotFound)76  site:  76 pep:  FDSDVGEYRAVTELG
# Q29974 :   corrected:  (idNotFound)89  site:  89 pep:  LGRPDAEYWNSQKDF
# Q29974 :   corrected:  (idNotFound)107  site:  107 pep:  RRAAVDTYCRHNYGV
# Q29974 :   corrected:  (idNotFound)112  site:  112 pep:  DTYCRHNYGVGESFT
# Q29974 :   corrected:  (idNotFound)131  site:  131 pep:  VQPKVTVYPSKTQPL
# Q29974 :   corrected:  (idNotFound)152  site:  152 pep:  VCSVSGFYPGSIEVR
# Q29974 :   corrected:  (idNotFound)200  site:  200 pep:  VPRSGEVYTCQVEHP
# Q29974 :   corrected:  (idNotFound)249  site:  249 pep:  LGAGLFIYFRNQKGH
# P01160 :   corrected:  (seqNotFound)151  site:  151  seq len:  151 pep:  LGCNSFRYRR
# Q95IE3 :   corrected:  (idNotFound)39  site:  39 pep:  TRPRFLEYSTGECYF
# Q95IE3 :   corrected:  (idNotFound)45  site:  45 pep:  EYSTGECYFFNGTER
# Q95IE3 :   corrected:  (idNotFound)107  site:  107 pep:  RRAAVDTYCRHNYGA
# Q95IE3 :   corrected:  (idNotFound)112  site:  112 pep:  DTYCRHNYGAVESFT
# Q95IE3 :   corrected:  (idNotFound)131  site:  131 pep:  VHPKVTVYPSKTQPL
# Q95IE3 :   corrected:  (idNotFound)152  site:  152 pep:  VCSVSGFYPGSIEVR
# Q95IE3 :   corrected:  (idNotFound)200  site:  200 pep:  VPRSGEVYTCQVEHP
# Q95IE3 :   corrected:  (idNotFound)249  site:  249 pep:  LGAGLFIYFRNQKGH
# Done. Time	241.336
# Formatting  group_9.csv ...
# Reading input file...
# Get unique substrate sites...
# Map unique substrate sites...
# Q30167 :   corrected:  (idNotFound)10  site:  10 pep:  CLRLPGGSCMAVLTV
# Q30167 :   corrected:  (idNotFound)16  site:  16 pep:  GSCMAVLTVTLMVLS
# Q30167 :   corrected:  (idNotFound)18  site:  18 pep:  CMAVLTVTLMVLSSP
# Q30167 :   corrected:  (idNotFound)23  site:  23 pep:  TVTLMVLSSPLALAG
# Q30167 :   corrected:  (idNotFound)24  site:  24 pep:  VTLMVLSSPLALAGD
# Q30167 :   corrected:  (idNotFound)32  site:  32 pep:  PLALAGDTRPRFLEE
# Q30167 :   corrected:  (idNotFound)50  site:  50 pep:  ECHFFNGTERVRLLE
# Q30167 :   corrected:  (idNotFound)71  site:  71 pep:  EEYARYDSDVGEYRA
# Q30167 :   corrected:  (idNotFound)80  site:  80 pep:  VGEYRAVTELGRPDA
# Q30167 :   corrected:  (idNotFound)92  site:  92 pep:  PDAEYWNSQKDLLER
# Q30167 :   corrected:  (idNotFound)106  site:  106 pep:  RRRAAVDTYCRHNYG
# Q30167 :   corrected:  (idNotFound)117  site:  117 pep:  HNYGVGESFTVQRRV
# Q30167 :   corrected:  (idNotFound)119  site:  119 pep:  YGVGESFTVQRRVQP
# Q30167 :   corrected:  (idNotFound)129  site:  129 pep:  RRVQPKVTVYPSKTQ
# Q30167 :   corrected:  (idNotFound)133  site:  133 pep:  PKVTVYPSKTQPLQH
# Q30167 :   corrected:  (idNotFound)135  site:  135 pep:  VTVYPSKTQPLQHHN
# Q30167 :   corrected:  (idNotFound)147  site:  147 pep:  HHNLLVCSVNGFYPG
# Q30167 :   corrected:  (idNotFound)155  site:  155 pep:  VNGFYPGSIEVRWFR
# Q30167 :   corrected:  (idNotFound)169  site:  169 pep:  RNGQEEKTGVVSTGL
# Q30167 :   corrected:  (idNotFound)173  site:  173 pep:  EEKTGVVSTGLIQNG
# Q30167 :   corrected:  (idNotFound)174  site:  174 pep:  EKTGVVSTGLIQNGD
# Q30167 :   corrected:  (idNotFound)183  site:  183 pep:  LIQNGDWTFQTLVML
# Q30167 :   corrected:  (idNotFound)186  site:  186 pep:  NGDWTFQTLVMLETV
# Q30167 :   corrected:  (idNotFound)192  site:  192 pep:  QTLVMLETVPQSGEV
# Q30167 :   corrected:  (idNotFound)196  site:  196 pep:  MLETVPQSGEVYTCQ
# Q30167 :   corrected:  (idNotFound)201  site:  201 pep:  PQSGEVYTCQVEHPS
# Q30167 :   corrected:  (idNotFound)208  site:  208 pep:  TCQVEHPSVMSPLTV
# Q30167 :   corrected:  (idNotFound)211  site:  211 pep:  VEHPSVMSPLTVEWR
# Q30167 :   corrected:  (idNotFound)214  site:  214 pep:  PSVMSPLTVEWRARS
# Q30167 :   corrected:  (idNotFound)221  site:  221 pep:  TVEWRARSESAQSKM
# Q30167 :   corrected:  (idNotFound)223  site:  223 pep:  EWRARSESAQSKMLS
# Q30167 :   corrected:  (idNotFound)226  site:  226 pep:  ARSESAQSKMLSGVG
# Q30167 :   corrected:  (idNotFound)230  site:  230 pep:  SAQSKMLSGVGGFVL
# Q30167 :   corrected:  (idNotFound)257  site:  257 pep:  FRNQKGHSGLPPTGF
# Q30167 :   corrected:  (idNotFound)262  site:  262 pep:  GHSGLPPTGFLS
# Q30167 :   corrected:  (idNotFound)266  site:  266 pep:  LPPTGFLS
# P49895 :   corrected:  (seqNotFound)123  site:  123  seq len:  249 pep:  PLVLNFGSCTPSFMF
# P49895 :   corrected:  (seqNotFound)125  site:  125  seq len:  249 pep:  VLNFGSCTPSFMFKF
# P49895 :   corrected:  (seqNotFound)127  site:  127  seq len:  249 pep:  NFGSCTPSFMFKFDQ
# Q30167 :   corrected:  (idNotFound)66  site:  66 pep:  RVHNQEEYARYDSDV
# Q30167 :   corrected:  (idNotFound)69  site:  69 pep:  NQEEYARYDSDVGEY
# Q30167 :   corrected:  (idNotFound)76  site:  76 pep:  YDSDVGEYRAVTELG
# Q30167 :   corrected:  (idNotFound)89  site:  89 pep:  LGRPDAEYWNSQKDL
# Q30167 :   corrected:  (idNotFound)107  site:  107 pep:  RRAAVDTYCRHNYGV
# Q30167 :   corrected:  (idNotFound)112  site:  112 pep:  DTYCRHNYGVGESFT
# Q30167 :   corrected:  (idNotFound)131  site:  131 pep:  VQPKVTVYPSKTQPL
# Q30167 :   corrected:  (idNotFound)152  site:  152 pep:  VCSVNGFYPGSIEVR
# Q30167 :   corrected:  (idNotFound)200  site:  200 pep:  VPQSGEVYTCQVEHP
# Q30167 :   corrected:  (idNotFound)249  site:  249 pep:  LGAGLFIYFRNQKGH
# Done. Time	227.834
# Formatting  group_20.csv ...
# Reading input file...
# Get unique substrate sites...
# Map unique substrate sites...
# P13760 :   corrected:  (idNotFound)10  site:  10 pep:  CLKFPGGSCMAALTV
# P13760 :   corrected:  (idNotFound)16  site:  16 pep:  GSCMAALTVTLMVLS
# P13760 :   corrected:  (idNotFound)18  site:  18 pep:  CMAALTVTLMVLSSP
# P13760 :   corrected:  (idNotFound)23  site:  23 pep:  TVTLMVLSSPLALAG
# P13760 :   corrected:  (idNotFound)24  site:  24 pep:  VTLMVLSSPLALAGD
# P13760 :   corrected:  (idNotFound)32  site:  32 pep:  PLALAGDTRPRFLEQ
# P13760 :   corrected:  (idNotFound)50  site:  50 pep:  ECHFFNGTERVRFLD
# P13760 :   corrected:  (idNotFound)71  site:  71 pep:  EEYVRFDSDVGEYRA
# P13760 :   corrected:  (idNotFound)80  site:  80 pep:  VGEYRAVTELGRPDA
# P13760 :   corrected:  (idNotFound)92  site:  92 pep:  PDAEYWNSQKDLLEQ
# P13760 :   corrected:  (idNotFound)106  site:  106 pep:  QKRAAVDTYCRHNYG
# P13760 :   corrected:  (idNotFound)117  site:  117 pep:  HNYGVGESFTVQRRV
# P13760 :   corrected:  (idNotFound)119  site:  119 pep:  YGVGESFTVQRRVYP
# P13760 :   corrected:  (idNotFound)129  site:  129 pep:  RRVYPEVTVYPAKTQ
# P13760 :   corrected:  (idNotFound)135  site:  135 pep:  VTVYPAKTQPLQHHN
# P13760 :   corrected:  (idNotFound)147  site:  147 pep:  HHNLLVCSVNGFYPG
# P13760 :   corrected:  (idNotFound)155  site:  155 pep:  VNGFYPGSIEVRWFR
# P13760 :   corrected:  (idNotFound)169  site:  169 pep:  RNGQEEKTGVVSTGL
# P13760 :   corrected:  (idNotFound)173  site:  173 pep:  EEKTGVVSTGLIQNG
# P13760 :   corrected:  (idNotFound)174  site:  174 pep:  EKTGVVSTGLIQNGD
# P13760 :   corrected:  (idNotFound)183  site:  183 pep:  LIQNGDWTFQTLVML
# P13760 :   corrected:  (idNotFound)186  site:  186 pep:  NGDWTFQTLVMLETV
# P13760 :   corrected:  (idNotFound)192  site:  192 pep:  QTLVMLETVPRSGEV
# P13760 :   corrected:  (idNotFound)196  site:  196 pep:  MLETVPRSGEVYTCQ
# P13760 :   corrected:  (idNotFound)201  site:  201 pep:  PRSGEVYTCQVEHPS
# P13760 :   corrected:  (idNotFound)208  site:  208 pep:  TCQVEHPSLTSPLTV
# P13760 :   corrected:  (idNotFound)210  site:  210 pep:  QVEHPSLTSPLTVEW
# P13760 :   corrected:  (idNotFound)211  site:  211 pep:  VEHPSLTSPLTVEWR
# P13760 :   corrected:  (idNotFound)214  site:  214 pep:  PSLTSPLTVEWRARS
# P13760 :   corrected:  (idNotFound)221  site:  221 pep:  TVEWRARSESAQSKM
# P13760 :   corrected:  (idNotFound)223  site:  223 pep:  EWRARSESAQSKMLS
# P13760 :   corrected:  (idNotFound)226  site:  226 pep:  ARSESAQSKMLSGVG
# P13760 :   corrected:  (idNotFound)230  site:  230 pep:  SAQSKMLSGVGGFVL
# P13760 :   corrected:  (idNotFound)257  site:  257 pep:  FRNQKGHSGLQPTGF
# P13760 :   corrected:  (idNotFound)262  site:  262 pep:  GHSGLQPTGFLS
# P13760 :   corrected:  (idNotFound)266  site:  266 pep:  LQPTGFLS
# P01912 :   corrected:  (idNotFound)10  site:  10 pep:  CLRLPGGSCMAVLTV
# P01912 :   corrected:  (idNotFound)16  site:  16 pep:  GSCMAVLTVTLMVLS
# P01912 :   corrected:  (idNotFound)18  site:  18 pep:  CMAVLTVTLMVLSSP
# P01912 :   corrected:  (idNotFound)23  site:  23 pep:  TVTLMVLSSPLALAG
# P01912 :   corrected:  (idNotFound)24  site:  24 pep:  VTLMVLSSPLALAGD
# P01912 :   corrected:  (idNotFound)32  site:  32 pep:  PLALAGDTRPRFLEY
# P01912 :   corrected:  (idNotFound)40  site:  40 pep:  RPRFLEYSTSECHFF
# P01912 :   corrected:  (idNotFound)41  site:  41 pep:  PRFLEYSTSECHFFN
# P01912 :   corrected:  (idNotFound)42  site:  42 pep:  RFLEYSTSECHFFNG
# P01912 :   corrected:  (idNotFound)50  site:  50 pep:  ECHFFNGTERVRYLD
# P01912 :   corrected:  (idNotFound)71  site:  71 pep:  EENVRFDSDVGEFRA
# P01912 :   corrected:  (idNotFound)80  site:  80 pep:  VGEFRAVTELGRPDA
# P01912 :   corrected:  (idNotFound)92  site:  92 pep:  PDAEYWNSQKDLLEQ
# P01912 :   corrected:  (idNotFound)117  site:  117 pep:  HNYGVVESFTVQRRV
# P01912 :   corrected:  (idNotFound)119  site:  119 pep:  YGVVESFTVQRRVHP
# P01912 :   corrected:  (idNotFound)129  site:  129 pep:  RRVHPKVTVYPSKTQ
# P01912 :   corrected:  (idNotFound)133  site:  133 pep:  PKVTVYPSKTQPLQH
# P01912 :   corrected:  (idNotFound)135  site:  135 pep:  VTVYPSKTQPLQHHN
# P01912 :   corrected:  (idNotFound)147  site:  147 pep:  HHNLLVCSVSGFYPG
# P01912 :   corrected:  (idNotFound)149  site:  149 pep:  NLLVCSVSGFYPGSI
# P01912 :   corrected:  (idNotFound)155  site:  155 pep:  VSGFYPGSIEVRWFR
# P01912 :   corrected:  (idNotFound)169  site:  169 pep:  RNGQEEKTGVVSTGL
# P01912 :   corrected:  (idNotFound)173  site:  173 pep:  EEKTGVVSTGLIHNG
# P01912 :   corrected:  (idNotFound)174  site:  174 pep:  EKTGVVSTGLIHNGD
# P01912 :   corrected:  (idNotFound)183  site:  183 pep:  LIHNGDWTFQTLVML
# P01912 :   corrected:  (idNotFound)186  site:  186 pep:  NGDWTFQTLVMLETV
# P01912 :   corrected:  (idNotFound)192  site:  192 pep:  QTLVMLETVPRSGEV
# P01912 :   corrected:  (idNotFound)196  site:  196 pep:  MLETVPRSGEVYTCQ
# P01912 :   corrected:  (idNotFound)201  site:  201 pep:  PRSGEVYTCQVEHPS
# P01912 :   corrected:  (idNotFound)208  site:  208 pep:  TCQVEHPSVTSPLTV
# P01912 :   corrected:  (idNotFound)210  site:  210 pep:  QVEHPSVTSPLTVEW
# P01912 :   corrected:  (idNotFound)211  site:  211 pep:  VEHPSVTSPLTVEWR
# P01912 :   corrected:  (idNotFound)214  site:  214 pep:  PSVTSPLTVEWRARS
# P01912 :   corrected:  (idNotFound)221  site:  221 pep:  TVEWRARSESAQSKM
# P01912 :   corrected:  (idNotFound)223  site:  223 pep:  EWRARSESAQSKMLS
# P01912 :   corrected:  (idNotFound)226  site:  226 pep:  ARSESAQSKMLSGVG
# P01912 :   corrected:  (idNotFound)230  site:  230 pep:  SAQSKMLSGVGGFVL
# P01912 :   corrected:  (idNotFound)257  site:  257 pep:  FRNQKGHSGLQPRGF
# P01912 :   corrected:  (idNotFound)266  site:  266 pep:  LQPRGFLS
# Q16881 :   corrected:  (seqNotFound)641  site:  641  seq len:  649 pep:  VTKRSGASILQAGCG
# P13760 :   corrected:  (idNotFound)59  site:  59 pep:  RVRFLDRYFYHQEEY
# P13760 :   corrected:  (idNotFound)61  site:  61 pep:  RFLDRYFYHQEEYVR
# P13760 :   corrected:  (idNotFound)66  site:  66 pep:  YFYHQEEYVRFDSDV
# P13760 :   corrected:  (idNotFound)76  site:  76 pep:  FDSDVGEYRAVTELG
# P13760 :   corrected:  (idNotFound)89  site:  89 pep:  LGRPDAEYWNSQKDL
# P13760 :   corrected:  (idNotFound)107  site:  107 pep:  KRAAVDTYCRHNYGV
# P13760 :   corrected:  (idNotFound)112  site:  112 pep:  DTYCRHNYGVGESFT
# P13760 :   corrected:  (idNotFound)125  site:  125 pep:  FTVQRRVYPEVTVYP
# P13760 :   corrected:  (idNotFound)131  site:  131 pep:  VYPEVTVYPAKTQPL
# P13760 :   corrected:  (idNotFound)152  site:  152 pep:  VCSVNGFYPGSIEVR
# P13760 :   corrected:  (idNotFound)200  site:  200 pep:  VPRSGEVYTCQVEHP
# P13760 :   corrected:  (idNotFound)249  site:  249 pep:  LGAGLFIYFRNQKGH
# P01912 :   corrected:  (idNotFound)39  site:  39 pep:  TRPRFLEYSTSECHF
# P01912 :   corrected:  (idNotFound)55  site:  55 pep:  NGTERVRYLDRYFHN
# P01912 :   corrected:  (idNotFound)59  site:  59 pep:  RVRYLDRYFHNQEEN
# P01912 :   corrected:  (idNotFound)89  site:  89 pep:  LGRPDAEYWNSQKDL
# P01912 :   corrected:  (idNotFound)107  site:  107 pep:  KRGRVDNYCRHNYGV
# P01912 :   corrected:  (idNotFound)112  site:  112 pep:  DNYCRHNYGVVESFT
# P01912 :   corrected:  (idNotFound)131  site:  131 pep:  VHPKVTVYPSKTQPL
# P01912 :   corrected:  (idNotFound)152  site:  152 pep:  VCSVSGFYPGSIEVR
# P01912 :   corrected:  (idNotFound)200  site:  200 pep:  VPRSGEVYTCQVEHP
# P01912 :   corrected:  (idNotFound)249  site:  249 pep:  LGAGLFIYFRNQKGH
# Done. Time	237.118
# Formatting  group_18.csv ...
# Reading input file...
# Get unique substrate sites...
# Map unique substrate sites...
# P13761 :   corrected:  (idNotFound)10  site:  10 pep:  CLKLPGGSCMAALTV
# P13761 :   corrected:  (idNotFound)16  site:  16 pep:  GSCMAALTVTLMVLS
# P13761 :   corrected:  (idNotFound)18  site:  18 pep:  CMAALTVTLMVLSSP
# P13761 :   corrected:  (idNotFound)23  site:  23 pep:  TVTLMVLSSPLALAG
# P13761 :   corrected:  (idNotFound)24  site:  24 pep:  VTLMVLSSPLALAGD
# P13761 :   corrected:  (idNotFound)32  site:  32 pep:  PLALAGDTQPRFLWQ
# P13761 :   corrected:  (idNotFound)50  site:  50 pep:  KCHFFNGTERVQFLE
# P13761 :   corrected:  (idNotFound)71  site:  71 pep:  EEFVRFDSDVGEYRA
# P13761 :   corrected:  (idNotFound)80  site:  80 pep:  VGEYRAVTELGRPVA
# P13761 :   corrected:  (idNotFound)89  site:  89 pep:  LGRPVAESWNSQKDI
# P13761 :   corrected:  (idNotFound)92  site:  92 pep:  PVAESWNSQKDILED
# P13761 :   corrected:  (idNotFound)106  site:  106 pep:  DRRGQVDTVCRHNYG
# P13761 :   corrected:  (idNotFound)117  site:  117 pep:  HNYGVGESFTVQRRV
# P13761 :   corrected:  (idNotFound)119  site:  119 pep:  YGVGESFTVQRRVHP
# P13761 :   corrected:  (idNotFound)129  site:  129 pep:  RRVHPEVTVYPAKTQ
# P13761 :   corrected:  (idNotFound)135  site:  135 pep:  VTVYPAKTQPLQHHN
# P13761 :   corrected:  (idNotFound)147  site:  147 pep:  HHNLLVCSVSGFYPG
# P13761 :   corrected:  (idNotFound)149  site:  149 pep:  NLLVCSVSGFYPGSI
# P13761 :   corrected:  (idNotFound)155  site:  155 pep:  VSGFYPGSIEVRWFR
# P13761 :   corrected:  (idNotFound)173  site:  173 pep:  EEKAGVVSTGLIQNG
# P13761 :   corrected:  (idNotFound)174  site:  174 pep:  EKAGVVSTGLIQNGD
# P13761 :   corrected:  (idNotFound)183  site:  183 pep:  LIQNGDWTFQTLVML
# P13761 :   corrected:  (idNotFound)186  site:  186 pep:  NGDWTFQTLVMLETV
# P13761 :   corrected:  (idNotFound)192  site:  192 pep:  QTLVMLETVPRSGEV
# P13761 :   corrected:  (idNotFound)196  site:  196 pep:  MLETVPRSGEVYTCQ
# P13761 :   corrected:  (idNotFound)201  site:  201 pep:  PRSGEVYTCQVEHPS
# P13761 :   corrected:  (idNotFound)208  site:  208 pep:  TCQVEHPSVMSPLTV
# P13761 :   corrected:  (idNotFound)211  site:  211 pep:  VEHPSVMSPLTVEWR
# P13761 :   corrected:  (idNotFound)214  site:  214 pep:  PSVMSPLTVEWRARS
# P13761 :   corrected:  (idNotFound)221  site:  221 pep:  TVEWRARSESAQSKM
# P13761 :   corrected:  (idNotFound)223  site:  223 pep:  EWRARSESAQSKMLS
# P13761 :   corrected:  (idNotFound)226  site:  226 pep:  ARSESAQSKMLSGVG
# P13761 :   corrected:  (idNotFound)230  site:  230 pep:  SAQSKMLSGVGGFVL
# P13761 :   corrected:  (idNotFound)257  site:  257 pep:  FRNQKGHSGLQPTGF
# P13761 :   corrected:  (idNotFound)262  site:  262 pep:  GHSGLQPTGFLS
# P13761 :   corrected:  (idNotFound)266  site:  266 pep:  LQPTGFLS
# Q5Y7A7 :   corrected:  (idNotFound)10  site:  10 pep:  CLRLPGGSCMAVLTV
# Q5Y7A7 :   corrected:  (idNotFound)16  site:  16 pep:  GSCMAVLTVTLMVLS
# Q5Y7A7 :   corrected:  (idNotFound)18  site:  18 pep:  CMAVLTVTLMVLSSP
# Q5Y7A7 :   corrected:  (idNotFound)23  site:  23 pep:  TVTLMVLSSPLALAG
# Q5Y7A7 :   corrected:  (idNotFound)24  site:  24 pep:  VTLMVLSSPLALAGD
# Q5Y7A7 :   corrected:  (idNotFound)32  site:  32 pep:  PLALAGDTRPRFLEY
# Q5Y7A7 :   corrected:  (idNotFound)40  site:  40 pep:  RPRFLEYSTSECHFF
# Q5Y7A7 :   corrected:  (idNotFound)41  site:  41 pep:  PRFLEYSTSECHFFN
# Q5Y7A7 :   corrected:  (idNotFound)42  site:  42 pep:  RFLEYSTSECHFFNG
# Q5Y7A7 :   corrected:  (idNotFound)50  site:  50 pep:  ECHFFNGTERVRFLD
# Q5Y7A7 :   corrected:  (idNotFound)71  site:  71 pep:  EENVRFDSDVGEFRA
# Q5Y7A7 :   corrected:  (idNotFound)80  site:  80 pep:  VGEFRAVTELGRPDA
# Q5Y7A7 :   corrected:  (idNotFound)92  site:  92 pep:  PDAEYWNSQKDILED
# Q5Y7A7 :   corrected:  (idNotFound)106  site:  106 pep:  DERAAVDTYCRHNYG
# Q5Y7A7 :   corrected:  (idNotFound)117  site:  117 pep:  HNYGVVESFTVQRRV
# Q5Y7A7 :   corrected:  (idNotFound)119  site:  119 pep:  YGVVESFTVQRRVHP
# Q5Y7A7 :   corrected:  (idNotFound)129  site:  129 pep:  RRVHPKVTVYPSKTQ
# Q5Y7A7 :   corrected:  (idNotFound)133  site:  133 pep:  PKVTVYPSKTQPLQH
# Q5Y7A7 :   corrected:  (idNotFound)135  site:  135 pep:  VTVYPSKTQPLQHHN
# Q5Y7A7 :   corrected:  (idNotFound)147  site:  147 pep:  HHNLLVCSVSGFYPG
# Q5Y7A7 :   corrected:  (idNotFound)149  site:  149 pep:  NLLVCSVSGFYPGSI
# Q5Y7A7 :   corrected:  (idNotFound)155  site:  155 pep:  VSGFYPGSIEVRWFR
# Q5Y7A7 :   corrected:  (idNotFound)169  site:  169 pep:  RNGQEEKTGVVSTGL
# Q5Y7A7 :   corrected:  (idNotFound)173  site:  173 pep:  EEKTGVVSTGLIHNG
# Q5Y7A7 :   corrected:  (idNotFound)174  site:  174 pep:  EKTGVVSTGLIHNGD
# Q5Y7A7 :   corrected:  (idNotFound)183  site:  183 pep:  LIHNGDWTFQTLVML
# Q5Y7A7 :   corrected:  (idNotFound)186  site:  186 pep:  NGDWTFQTLVMLETV
# Q5Y7A7 :   corrected:  (idNotFound)192  site:  192 pep:  QTLVMLETVPRSGEV
# Q5Y7A7 :   corrected:  (idNotFound)196  site:  196 pep:  MLETVPRSGEVYTCQ
# Q5Y7A7 :   corrected:  (idNotFound)201  site:  201 pep:  PRSGEVYTCQVEHPS
# Q5Y7A7 :   corrected:  (idNotFound)208  site:  208 pep:  TCQVEHPSVTSPLTV
# Q5Y7A7 :   corrected:  (idNotFound)210  site:  210 pep:  QVEHPSVTSPLTVEW
# Q5Y7A7 :   corrected:  (idNotFound)211  site:  211 pep:  VEHPSVTSPLTVEWR
# Q5Y7A7 :   corrected:  (idNotFound)214  site:  214 pep:  PSVTSPLTVEWRARS
# Q5Y7A7 :   corrected:  (idNotFound)221  site:  221 pep:  TVEWRARSESAQSKM
# Q5Y7A7 :   corrected:  (idNotFound)223  site:  223 pep:  EWRARSESAQSKMLS
# Q5Y7A7 :   corrected:  (idNotFound)226  site:  226 pep:  ARSESAQSKMLSGVG
# Q5Y7A7 :   corrected:  (idNotFound)230  site:  230 pep:  SAQSKMLSGVGGFVL
# Q5Y7A7 :   corrected:  (idNotFound)257  site:  257 pep:  FRNQKGHSGLQPRGF
# Q5Y7A7 :   corrected:  (idNotFound)266  site:  266 pep:  LQPRGFLS
# P13761 :   corrected:  (idNotFound)42  site:  42 pep:  RFLWQGKYKCHFFNG
# P13761 :   corrected:  (idNotFound)61  site:  61 pep:  QFLERLFYNQEEFVR
# P13761 :   corrected:  (idNotFound)76  site:  76 pep:  FDSDVGEYRAVTELG
# P13761 :   corrected:  (idNotFound)112  site:  112 pep:  DTVCRHNYGVGESFT
# P13761 :   corrected:  (idNotFound)131  site:  131 pep:  VHPEVTVYPAKTQPL
# P13761 :   corrected:  (idNotFound)152  site:  152 pep:  VCSVSGFYPGSIEVR
# P13761 :   corrected:  (idNotFound)200  site:  200 pep:  VPRSGEVYTCQVEHP
# P13761 :   corrected:  (idNotFound)249  site:  249 pep:  LGAGLFIYFRNQKGH
# Q5Y7A7 :   corrected:  (idNotFound)39  site:  39 pep:  TRPRFLEYSTSECHF
# Q5Y7A7 :   corrected:  (idNotFound)59  site:  59 pep:  RVRFLDRYFHNQEEN
# Q5Y7A7 :   corrected:  (idNotFound)89  site:  89 pep:  LGRPDAEYWNSQKDI
# Q5Y7A7 :   corrected:  (idNotFound)107  site:  107 pep:  ERAAVDTYCRHNYGV
# Q5Y7A7 :   corrected:  (idNotFound)112  site:  112 pep:  DTYCRHNYGVVESFT
# Q5Y7A7 :   corrected:  (idNotFound)131  site:  131 pep:  VHPKVTVYPSKTQPL
# Q5Y7A7 :   corrected:  (idNotFound)152  site:  152 pep:  VCSVSGFYPGSIEVR
# Q5Y7A7 :   corrected:  (idNotFound)200  site:  200 pep:  VPRSGEVYTCQVEHP
# Q5Y7A7 :   corrected:  (idNotFound)249  site:  249 pep:  LGAGLFIYFRNQKGH
# Done. Time	239.963
# Formatting  group_19.csv ...
# Reading input file...
# Get unique substrate sites...
# Map unique substrate sites...
# P22352 :   corrected:  (seqNotFound)71  site:  71  seq len:  226 pep:  VLFVNVASYGLTGQY
# P22352 :   corrected:  (seqNotFound)75  site:  75  seq len:  226 pep:  NVASYGLTGQYIELN
# P36969 :   corrected:  (seqNotFound)67  site:  67  seq len:  197 pep:  RGFVCIVTNVASQGK
# P36969 :   corrected:  (seqNotFound)71  site:  71  seq len:  197 pep:  CIVTNVASQGKTEVN
# P36969 :   corrected:  (seqNotFound)75  site:  75  seq len:  197 pep:  NVASQGKTEVNYTQL
# Q9C0D9 :   corrected:  (seqNotFound)385  site:  385  seq len:  397 pep:  FSLRKPNSDLGMEEK
# P22352 :   corrected:  (seqNotFound)72  site:  72  seq len:  226 pep:  LFVNVASYGLTGQYI
# P22352 :   corrected:  (seqNotFound)78  site:  78  seq len:  226 pep:  SYGLTGQYIELNALQ
# P36969 :   corrected:  (seqNotFound)79  site:  79  seq len:  197 pep:  QGKTEVNYTQLVDLH
# Done. Time	249.375
# Formatting  group_17.csv ...
# Reading input file...
# Get unique substrate sites...
# Map unique substrate sites...
# Done. Time	245.073
# Formatting  group_2.csv ...
# Reading input file...
# Get unique substrate sites...
# Map unique substrate sites...
# Done. Time	236.846
# Formatting  group_3.csv ...
# Reading input file...
# Get unique substrate sites...
# Map unique substrate sites...
# Done. Time	232.026
# Formatting  group_16.csv ...
# Reading input file...
# Get unique substrate sites...
# Map unique substrate sites...
# Q9BQE4 :   corrected:  (seqNotFound)184  site:  184  seq len:  189 pep:  RPGRRGPSSGGG
# Q9BQE4 :   corrected:  (seqNotFound)185  site:  185  seq len:  189 pep:  PGRRGPSSGGG
# Q86VQ6 :   corrected:  (seqNotFound)637  site:  637  seq len:  643 pep:  KSSGLDITQKGCG
# Done. Time	238.172
# Formatting  group_14.csv ...
# Reading input file...
# Get unique substrate sites...
# Map unique substrate sites...
# P59797 :   corrected:  (seqNotFound)268  site:  268  seq len:  346 pep:  KRVLIRVTYCGLSYS
# P59797 :   corrected:  (seqNotFound)273  site:  273  seq len:  346 pep:  RVTYCGLSYSLRYIL
# P59797 :   corrected:  (seqNotFound)275  site:  275  seq len:  346 pep:  TYCGLSYSLRYILLK
# P62341 :   corrected:  (seqNotFound)48  site:  48  seq len:  195 pep:  LKFQICVSGYRRVFE
# P59797 :   corrected:  (seqNotFound)269  site:  269  seq len:  346 pep:  RVLIRVTYCGLSYSL
# P59797 :   corrected:  (seqNotFound)274  site:  274  seq len:  346 pep:  VTYCGLSYSLRYILL
# P59797 :   corrected:  (seqNotFound)278  site:  278  seq len:  346 pep:  GLSYSLRYILLKKSL
# P62341 :   corrected:  (seqNotFound)50  site:  50  seq len:  195 pep:  FQICVSGYRRVFEEY
# Done. Time	231.999
# Formatting  group_1.csv ...
# Reading input file...
# Get unique substrate sites...
# Map unique substrate sites...
# Q9NZV6 :   corrected:  (seqNotFound)92  site:  92  seq len:  116 pep:  DGPKPGQSRFIFSSS
# Q9NZV6 :   corrected:  (seqNotFound)97  site:  97  seq len:  116 pep:  GQSRFIFSSSLKFVP
# Q9NZV6 :   corrected:  (seqNotFound)98  site:  98  seq len:  116 pep:  QSRFIFSSSLKFVPK
# Q9NZV6 :   corrected:  (seqNotFound)99  site:  99  seq len:  116 pep:  SRFIFSSSLKFVPKG
# Done. Time	255.401
# Formatting  group_15.csv ...
# Reading input file...
# Get unique substrate sites...
# Map unique substrate sites...
# Q9NZV5 :   corrected:  (seqNotFound)127  site:  127  seq len:  590 pep:  PQLPWLNSSCLSLLR
# Q9NZV5 :   corrected:  (seqNotFound)128  site:  128  seq len:  590 pep:  QLPWLNSSCLSLLRS
# Q9NZV5 :   corrected:  (seqNotFound)131  site:  131  seq len:  590 pep:  WLNSSCLSLLRSTPA
# Q9NZV5 :   corrected:  (seqNotFound)459  site:  459  seq len:  590 pep:  WGALDDQSCGSGRTL
# Q9NZV5 :   corrected:  (seqNotFound)462  site:  462  seq len:  590 pep:  LDDQSCGSGRTLRET
# Q9NZV5 :   corrected:  (seqNotFound)465  site:  465  seq len:  590 pep:  QSCGSGRTLRETVLE
# Done. Time	243.974
# Formatting  group_11.csv ...
# Reading input file...
# Get unique substrate sites...
# Map unique substrate sites...
# Q8IZQ5 :   corrected:  (seqNotFound)42  site:  42  seq len:  122 pep:  TVVIEHCTSRVYGRN
# Q8IZQ5 :   corrected:  (seqNotFound)43  site:  43  seq len:  122 pep:  VVIEHCTSRVYGRNA
# Q06124 :   corrected:  (seqNotFound)404  site:  404  seq len:  593 pep:  TLRELKLSKVGQALL
# Q06124 :   corrected:  (seqNotFound)415  site:  415  seq len:  593 pep:  QALLQGNTERTVWQY
# Q06124 :   corrected:  (seqNotFound)418  site:  418  seq len:  593 pep:  LQGNTERTVWQYHFR
# Q9NNW7 :   corrected:  (seqNotFound)518  site:  518  seq len:  524 pep:  KRSGLDPTVTGCG
# Q9NNW7 :   corrected:  (seqNotFound)520  site:  520  seq len:  524 pep:  SGLDPTVTGCG
# Q8WWX9 :   corrected:  (seqNotFound)44  site:  44  seq len:  145 pep:  LTRARVETCGGQLNR
# Q8IZQ5 :   corrected:  (seqNotFound)46  site:  46  seq len:  122 pep:  EHCTSRVYGRNAAAL
# Done. Time	259.519
# Formatting  group_4.csv ...
# Reading input file...
# Get unique substrate sites...
# Map unique substrate sites...
# Q6QHF9 :   corrected:  (seqNotFound)114  site:  114  seq len:  511 pep:  HVGLPSVSYASSGTS
# Q6QHF9 :   corrected:  (seqNotFound)117  site:  117  seq len:  511 pep:  LPSVSYASSGTSVSL
# Q6QHF9 :   corrected:  (seqNotFound)118  site:  118  seq len:  511 pep:  PSVSYASSGTSVSLQ
# Q6QHF9 :   corrected:  (seqNotFound)120  site:  120  seq len:  511 pep:  VSYASSGTSVSLQLV
# Q6QHF9 :   corrected:  (seqNotFound)121  site:  121  seq len:  511 pep:  SYASSGTSVSLQLVA
# Q6QHF9 :   corrected:  (seqNotFound)123  site:  123  seq len:  511 pep:  ASSGTSVSLQLVAEM
# Q6QHF9 :   corrected:  (seqNotFound)174  site:  174  seq len:  511 pep:  VARLCGHSAFPHLRV
# P18283 :   corrected:  (seqNotFound)38  site:  38  seq len:  190 pep:  VLIENVASLGTTTRD
# P18283 :   corrected:  (seqNotFound)41  site:  41  seq len:  190 pep:  ENVASLGTTTRDFTQ
# P18283 :   corrected:  (seqNotFound)42  site:  42  seq len:  190 pep:  NVASLGTTTRDFTQL
# P18283 :   corrected:  (seqNotFound)43  site:  43  seq len:  190 pep:  VASLGTTTRDFTQLN
# Q6QHF9 :   corrected:  (seqNotFound)115  site:  115  seq len:  511 pep:  VGLPSVSYASSGTSV
# Done. Time	259.512
# Formatting  group_5.csv ...
# Reading input file...
# Get unique substrate sites...
# Map unique substrate sites...
# Q30134 :   corrected:  (idNotFound)10  site:  10 pep:  CLRLPGGSCMAVLTV
# Q30134 :   corrected:  (idNotFound)16  site:  16 pep:  GSCMAVLTVTLMVLS
# Q30134 :   corrected:  (idNotFound)18  site:  18 pep:  CMAVLTVTLMVLSSP
# Q30134 :   corrected:  (idNotFound)23  site:  23 pep:  TVTLMVLSSPLALAG
# Q30134 :   corrected:  (idNotFound)24  site:  24 pep:  VTLMVLSSPLALAGD
# Q30134 :   corrected:  (idNotFound)32  site:  32 pep:  PLALAGDTRPRFLEY
# Q30134 :   corrected:  (idNotFound)40  site:  40 pep:  RPRFLEYSTGECYFF
# Q30134 :   corrected:  (idNotFound)41  site:  41 pep:  PRFLEYSTGECYFFN
# Q30134 :   corrected:  (idNotFound)50  site:  50 pep:  ECYFFNGTERVRFLD
# Q30134 :   corrected:  (idNotFound)71  site:  71 pep:  EEYVRFDSDVGEYRA
# Q30134 :   corrected:  (idNotFound)80  site:  80 pep:  VGEYRAVTELGRPSA
# Q30134 :   corrected:  (idNotFound)86  site:  86 pep:  VTELGRPSAEYWNSQ
# Q30134 :   corrected:  (idNotFound)92  site:  92 pep:  PSAEYWNSQKDFLED
# Q30134 :   corrected:  (idNotFound)106  site:  106 pep:  DRRALVDTYCRHNYG
# Q30134 :   corrected:  (idNotFound)117  site:  117 pep:  HNYGVGESFTVQRRV
# Q30134 :   corrected:  (idNotFound)119  site:  119 pep:  YGVGESFTVQRRVHP
# Q30134 :   corrected:  (idNotFound)129  site:  129 pep:  RRVHPKVTVYPSKTQ
# Q30134 :   corrected:  (idNotFound)133  site:  133 pep:  PKVTVYPSKTQPLQH
# Q30134 :   corrected:  (idNotFound)135  site:  135 pep:  VTVYPSKTQPLQHHN
# Q30134 :   corrected:  (idNotFound)147  site:  147 pep:  HHNLLVCSVSGFYPG
# Q30134 :   corrected:  (idNotFound)149  site:  149 pep:  NLLVCSVSGFYPGSI
# Q30134 :   corrected:  (idNotFound)155  site:  155 pep:  VSGFYPGSIEVRWFR
# Q30134 :   corrected:  (idNotFound)169  site:  169 pep:  RNGQEEKTGVVSTGL
# Q30134 :   corrected:  (idNotFound)173  site:  173 pep:  EEKTGVVSTGLIHNG
# Q30134 :   corrected:  (idNotFound)174  site:  174 pep:  EKTGVVSTGLIHNGD
# Q30134 :   corrected:  (idNotFound)183  site:  183 pep:  LIHNGDWTFQTLVML
# Q30134 :   corrected:  (idNotFound)186  site:  186 pep:  NGDWTFQTLVMLETV
# Q30134 :   corrected:  (idNotFound)192  site:  192 pep:  QTLVMLETVPRSGEV
# Q30134 :   corrected:  (idNotFound)196  site:  196 pep:  MLETVPRSGEVYTCQ
# Q30134 :   corrected:  (idNotFound)201  site:  201 pep:  PRSGEVYTCQVEHPS
# Q30134 :   corrected:  (idNotFound)208  site:  208 pep:  TCQVEHPSVTSPLTV
# Q30134 :   corrected:  (idNotFound)210  site:  210 pep:  QVEHPSVTSPLTVEW
# Q30134 :   corrected:  (idNotFound)211  site:  211 pep:  VEHPSVTSPLTVEWS
# Q30134 :   corrected:  (idNotFound)214  site:  214 pep:  PSVTSPLTVEWSARS
# Q30134 :   corrected:  (idNotFound)218  site:  218 pep:  SPLTVEWSARSESAQ
# Q30134 :   corrected:  (idNotFound)221  site:  221 pep:  TVEWSARSESAQSKM
# Q30134 :   corrected:  (idNotFound)223  site:  223 pep:  EWSARSESAQSKMLS
# Q30134 :   corrected:  (idNotFound)226  site:  226 pep:  ARSESAQSKMLSGVG
# Q30134 :   corrected:  (idNotFound)230  site:  230 pep:  SAQSKMLSGVGGFVL
# Q30134 :   corrected:  (idNotFound)257  site:  257 pep:  FRNQKGHSGLQPTGF
# Q30134 :   corrected:  (idNotFound)262  site:  262 pep:  GHSGLQPTGFLS
# Q30134 :   corrected:  (idNotFound)266  site:  266 pep:  LQPTGFLS
# P20039 :   corrected:  (idNotFound)10  site:  10 pep:  CLRLPGGSCMAVLTV
# P20039 :   corrected:  (idNotFound)16  site:  16 pep:  GSCMAVLTVTLMVLS
# P20039 :   corrected:  (idNotFound)18  site:  18 pep:  CMAVLTVTLMVLSSP
# P20039 :   corrected:  (idNotFound)23  site:  23 pep:  TVTLMVLSSPLALAG
# P20039 :   corrected:  (idNotFound)24  site:  24 pep:  VTLMVLSSPLALAGD
# P20039 :   corrected:  (idNotFound)32  site:  32 pep:  PLALAGDTRPRFLEY
# P20039 :   corrected:  (idNotFound)40  site:  40 pep:  RPRFLEYSTSECHFF
# P20039 :   corrected:  (idNotFound)41  site:  41 pep:  PRFLEYSTSECHFFN
# P20039 :   corrected:  (idNotFound)42  site:  42 pep:  RFLEYSTSECHFFNG
# P20039 :   corrected:  (idNotFound)50  site:  50 pep:  ECHFFNGTERVRFLD
# P20039 :   corrected:  (idNotFound)71  site:  71 pep:  EEYVRFDSDVGEFRA
# P20039 :   corrected:  (idNotFound)80  site:  80 pep:  VGEFRAVTELGRPDE
# P20039 :   corrected:  (idNotFound)92  site:  92 pep:  PDEEYWNSQKDFLED
# P20039 :   corrected:  (idNotFound)106  site:  106 pep:  DRRAAVDTYCRHNYG
# P20039 :   corrected:  (idNotFound)117  site:  117 pep:  HNYGVGESFTVQRRV
# P20039 :   corrected:  (idNotFound)119  site:  119 pep:  YGVGESFTVQRRVHP
# P20039 :   corrected:  (idNotFound)129  site:  129 pep:  RRVHPKVTVYPSKTQ
# P20039 :   corrected:  (idNotFound)133  site:  133 pep:  PKVTVYPSKTQPLQH
# P20039 :   corrected:  (idNotFound)135  site:  135 pep:  VTVYPSKTQPLQHHN
# P20039 :   corrected:  (idNotFound)147  site:  147 pep:  HHNLLVCSVSGFYPG
# P20039 :   corrected:  (idNotFound)149  site:  149 pep:  NLLVCSVSGFYPGSI
# P20039 :   corrected:  (idNotFound)155  site:  155 pep:  VSGFYPGSIEVRWFR
# P20039 :   corrected:  (idNotFound)169  site:  169 pep:  RNGQEEKTGVVSTGL
# P20039 :   corrected:  (idNotFound)173  site:  173 pep:  EEKTGVVSTGLIHNG
# P20039 :   corrected:  (idNotFound)174  site:  174 pep:  EKTGVVSTGLIHNGD
# P20039 :   corrected:  (idNotFound)183  site:  183 pep:  LIHNGDWTFQTLVML
# P20039 :   corrected:  (idNotFound)186  site:  186 pep:  NGDWTFQTLVMLETV
# P20039 :   corrected:  (idNotFound)192  site:  192 pep:  QTLVMLETVPRSGEV
# P20039 :   corrected:  (idNotFound)196  site:  196 pep:  MLETVPRSGEVYTCQ
# P20039 :   corrected:  (idNotFound)201  site:  201 pep:  PRSGEVYTCQVEHPS
# P20039 :   corrected:  (idNotFound)208  site:  208 pep:  TCQVEHPSVTSPLTV
# P20039 :   corrected:  (idNotFound)210  site:  210 pep:  QVEHPSVTSPLTVEW
# P20039 :   corrected:  (idNotFound)211  site:  211 pep:  VEHPSVTSPLTVEWR
# P20039 :   corrected:  (idNotFound)214  site:  214 pep:  PSVTSPLTVEWRARS
# P20039 :   corrected:  (idNotFound)221  site:  221 pep:  TVEWRARSESAQSKM
# P20039 :   corrected:  (idNotFound)223  site:  223 pep:  EWRARSESAQSKMLS
# P20039 :   corrected:  (idNotFound)226  site:  226 pep:  ARSESAQSKMLSGVG
# P20039 :   corrected:  (idNotFound)230  site:  230 pep:  SAQSKMLSGVGGFVL
# P20039 :   corrected:  (idNotFound)257  site:  257 pep:  FRNQKGHSGLQPRGF
# P20039 :   corrected:  (idNotFound)266  site:  266 pep:  LQPRGFLS
# Q9TQE0 :   corrected:  (idNotFound)10  site:  10 pep:  CLKLPGGSCMAALTV
# Q9TQE0 :   corrected:  (idNotFound)16  site:  16 pep:  GSCMAALTVTLMVLS
# Q9TQE0 :   corrected:  (idNotFound)18  site:  18 pep:  CMAALTVTLMVLSSP
# Q9TQE0 :   corrected:  (idNotFound)23  site:  23 pep:  TVTLMVLSSPLALAG
# Q9TQE0 :   corrected:  (idNotFound)24  site:  24 pep:  VTLMVLSSPLALAGD
# Q9TQE0 :   corrected:  (idNotFound)32  site:  32 pep:  PLALAGDTQPRFLKQ
# Q9TQE0 :   corrected:  (idNotFound)50  site:  50 pep:  ECHFFNGTERVRYLH
# Q9TQE0 :   corrected:  (idNotFound)71  site:  71 pep:  EENVRFDSDVGEYRA
# Q9TQE0 :   corrected:  (idNotFound)80  site:  80 pep:  VGEYRAVTELGRPVA
# Q9TQE0 :   corrected:  (idNotFound)89  site:  89 pep:  LGRPVAESWNSQKDF
# Q9TQE0 :   corrected:  (idNotFound)92  site:  92 pep:  PVAESWNSQKDFLER
# Q9TQE0 :   corrected:  (idNotFound)106  site:  106 pep:  RRRAEVDTVCRHNYG
# Q9TQE0 :   corrected:  (idNotFound)117  site:  117 pep:  HNYGVGESFTVQRRV
# Q9TQE0 :   corrected:  (idNotFound)119  site:  119 pep:  YGVGESFTVQRRVHP
# Q9TQE0 :   corrected:  (idNotFound)129  site:  129 pep:  RRVHPEVTVYPAKTQ
# Q9TQE0 :   corrected:  (idNotFound)135  site:  135 pep:  VTVYPAKTQPLQHHN
# Q9TQE0 :   corrected:  (idNotFound)147  site:  147 pep:  HHNLLVCSVSGFYPG
# Q9TQE0 :   corrected:  (idNotFound)149  site:  149 pep:  NLLVCSVSGFYPGSI
# Q9TQE0 :   corrected:  (idNotFound)155  site:  155 pep:  VSGFYPGSIEVRWFR
# Q9TQE0 :   corrected:  (idNotFound)173  site:  173 pep:  EEKAGVVSTGLIQNG
# Q9TQE0 :   corrected:  (idNotFound)174  site:  174 pep:  EKAGVVSTGLIQNGD
# Q9TQE0 :   corrected:  (idNotFound)183  site:  183 pep:  LIQNGDWTFQTLVML
# Q9TQE0 :   corrected:  (idNotFound)186  site:  186 pep:  NGDWTFQTLVMLETV
# Q9TQE0 :   corrected:  (idNotFound)192  site:  192 pep:  QTLVMLETVPRSGEV
# Q9TQE0 :   corrected:  (idNotFound)196  site:  196 pep:  MLETVPRSGEVYTCQ
# Q9TQE0 :   corrected:  (idNotFound)201  site:  201 pep:  PRSGEVYTCQVEHPS
# Q9TQE0 :   corrected:  (idNotFound)208  site:  208 pep:  TCQVEHPSVMSPLTV
# Q9TQE0 :   corrected:  (idNotFound)211  site:  211 pep:  VEHPSVMSPLTVEWR
# Q9TQE0 :   corrected:  (idNotFound)214  site:  214 pep:  PSVMSPLTVEWRARS
# Q9TQE0 :   corrected:  (idNotFound)221  site:  221 pep:  TVEWRARSESAQSKM
# Q9TQE0 :   corrected:  (idNotFound)223  site:  223 pep:  EWRARSESAQSKMLS
# Q9TQE0 :   corrected:  (idNotFound)226  site:  226 pep:  ARSESAQSKMLSGVG
# Q9TQE0 :   corrected:  (idNotFound)230  site:  230 pep:  SAQSKMLSGVGGFVL
# Q9TQE0 :   corrected:  (idNotFound)257  site:  257 pep:  FRNQKGHSGLQPTGF
# Q9TQE0 :   corrected:  (idNotFound)262  site:  262 pep:  GHSGLQPTGFLS
# Q9TQE0 :   corrected:  (idNotFound)266  site:  266 pep:  LQPTGFLS
# Q9GIY3 :   corrected:  (idNotFound)10  site:  10 pep:  CLRLPGGSCMAVLTV
# Q9GIY3 :   corrected:  (idNotFound)16  site:  16 pep:  GSCMAVLTVTLMVLS
# Q9GIY3 :   corrected:  (idNotFound)18  site:  18 pep:  CMAVLTVTLMVLSSP
# Q9GIY3 :   corrected:  (idNotFound)23  site:  23 pep:  TVTLMVLSSPLALAG
# Q9GIY3 :   corrected:  (idNotFound)24  site:  24 pep:  VTLMVLSSPLALAGD
# Q9GIY3 :   corrected:  (idNotFound)32  site:  32 pep:  PLALAGDTRPRFLEY
# Q9GIY3 :   corrected:  (idNotFound)40  site:  40 pep:  RPRFLEYSTSECHFF
# Q9GIY3 :   corrected:  (idNotFound)41  site:  41 pep:  PRFLEYSTSECHFFN
# Q9GIY3 :   corrected:  (idNotFound)42  site:  42 pep:  RFLEYSTSECHFFNG
# Q9GIY3 :   corrected:  (idNotFound)50  site:  50 pep:  ECHFFNGTERVRFLD
# Q9GIY3 :   corrected:  (idNotFound)71  site:  71 pep:  EEFVRFDSDVGEYRA
# Q9GIY3 :   corrected:  (idNotFound)80  site:  80 pep:  VGEYRAVTELGRPAA
# Q9GIY3 :   corrected:  (idNotFound)92  site:  92 pep:  PAAEHWNSQKDLLER
# Q9GIY3 :   corrected:  (idNotFound)106  site:  106 pep:  RRRAEVDTYCRHNYG
# Q9GIY3 :   corrected:  (idNotFound)117  site:  117 pep:  HNYGVVESFTVQRRV
# Q9GIY3 :   corrected:  (idNotFound)119  site:  119 pep:  YGVVESFTVQRRVHP
# Q9GIY3 :   corrected:  (idNotFound)129  site:  129 pep:  RRVHPKVTVYPSKTQ
# Q9GIY3 :   corrected:  (idNotFound)133  site:  133 pep:  PKVTVYPSKTQPLQH
# Q9GIY3 :   corrected:  (idNotFound)135  site:  135 pep:  VTVYPSKTQPLQHYN
# Q9GIY3 :   corrected:  (idNotFound)147  site:  147 pep:  HYNLLVCSVSGFYPG
# Q9GIY3 :   corrected:  (idNotFound)149  site:  149 pep:  NLLVCSVSGFYPGSI
# Q9GIY3 :   corrected:  (idNotFound)155  site:  155 pep:  VSGFYPGSIEVRWFR
# Q9GIY3 :   corrected:  (idNotFound)169  site:  169 pep:  RNGQEEKTGVVSTGL
# Q9GIY3 :   corrected:  (idNotFound)173  site:  173 pep:  EEKTGVVSTGLIHNG
# Q9GIY3 :   corrected:  (idNotFound)174  site:  174 pep:  EKTGVVSTGLIHNGD
# Q9GIY3 :   corrected:  (idNotFound)183  site:  183 pep:  LIHNGDWTFQTLVML
# Q9GIY3 :   corrected:  (idNotFound)186  site:  186 pep:  NGDWTFQTLVMLETV
# Q9GIY3 :   corrected:  (idNotFound)192  site:  192 pep:  QTLVMLETVPRSGEV
# Q9GIY3 :   corrected:  (idNotFound)196  site:  196 pep:  MLETVPRSGEVYTCQ
# Q9GIY3 :   corrected:  (idNotFound)201  site:  201 pep:  PRSGEVYTCQVEHPS
# Q9GIY3 :   corrected:  (idNotFound)208  site:  208 pep:  TCQVEHPSVTSPLTV
# Q9GIY3 :   corrected:  (idNotFound)210  site:  210 pep:  QVEHPSVTSPLTVEW
# Q9GIY3 :   corrected:  (idNotFound)211  site:  211 pep:  VEHPSVTSPLTVEWR
# Q9GIY3 :   corrected:  (idNotFound)214  site:  214 pep:  PSVTSPLTVEWRARS
# Q9GIY3 :   corrected:  (idNotFound)221  site:  221 pep:  TVEWRARSESAQSKM
# Q9GIY3 :   corrected:  (idNotFound)223  site:  223 pep:  EWRARSESAQSKMLS
# Q9GIY3 :   corrected:  (idNotFound)226  site:  226 pep:  ARSESAQSKMLSGVG
# Q9GIY3 :   corrected:  (idNotFound)230  site:  230 pep:  SAQSKMLSGVGGFVL
# Q9GIY3 :   corrected:  (idNotFound)257  site:  257 pep:  FRNQKGHSGLQPRGF
# Q9GIY3 :   corrected:  (idNotFound)266  site:  266 pep:  LQPRGFLS
# Q30134 :   corrected:  (idNotFound)39  site:  39 pep:  TRPRFLEYSTGECYF
# Q30134 :   corrected:  (idNotFound)45  site:  45 pep:  EYSTGECYFFNGTER
# Q30134 :   corrected:  (idNotFound)59  site:  59 pep:  RVRFLDRYFYNQEEY
# Q30134 :   corrected:  (idNotFound)61  site:  61 pep:  RFLDRYFYNQEEYVR
# Q30134 :   corrected:  (idNotFound)66  site:  66 pep:  YFYNQEEYVRFDSDV
# Q30134 :   corrected:  (idNotFound)76  site:  76 pep:  FDSDVGEYRAVTELG
# Q30134 :   corrected:  (idNotFound)89  site:  89 pep:  LGRPSAEYWNSQKDF
# Q30134 :   corrected:  (idNotFound)107  site:  107 pep:  RRALVDTYCRHNYGV
# Q30134 :   corrected:  (idNotFound)112  site:  112 pep:  DTYCRHNYGVGESFT
# Q30134 :   corrected:  (idNotFound)131  site:  131 pep:  VHPKVTVYPSKTQPL
# Q30134 :   corrected:  (idNotFound)152  site:  152 pep:  VCSVSGFYPGSIEVR
# Q30134 :   corrected:  (idNotFound)200  site:  200 pep:  VPRSGEVYTCQVEHP
# Q30134 :   corrected:  (idNotFound)249  site:  249 pep:  LGAGLFIYFRNQKGH
# P20039 :   corrected:  (idNotFound)39  site:  39 pep:  TRPRFLEYSTSECHF
# P20039 :   corrected:  (idNotFound)59  site:  59 pep:  RVRFLDRYFYNQEEY
# P20039 :   corrected:  (idNotFound)61  site:  61 pep:  RFLDRYFYNQEEYVR
# P20039 :   corrected:  (idNotFound)66  site:  66 pep:  YFYNQEEYVRFDSDV
# P20039 :   corrected:  (idNotFound)89  site:  89 pep:  LGRPDEEYWNSQKDF
# P20039 :   corrected:  (idNotFound)107  site:  107 pep:  RRAAVDTYCRHNYGV
# P20039 :   corrected:  (idNotFound)112  site:  112 pep:  DTYCRHNYGVGESFT
# P20039 :   corrected:  (idNotFound)131  site:  131 pep:  VHPKVTVYPSKTQPL
# P20039 :   corrected:  (idNotFound)152  site:  152 pep:  VCSVSGFYPGSIEVR
# P20039 :   corrected:  (idNotFound)200  site:  200 pep:  VPRSGEVYTCQVEHP
# P20039 :   corrected:  (idNotFound)249  site:  249 pep:  LGAGLFIYFRNQKGH
# Q9TQE0 :   corrected:  (idNotFound)55  site:  55 pep:  NGTERVRYLHRGIYN
# Q9TQE0 :   corrected:  (idNotFound)61  site:  61 pep:  RYLHRGIYNQEENVR
# Q9TQE0 :   corrected:  (idNotFound)76  site:  76 pep:  FDSDVGEYRAVTELG
# Q9TQE0 :   corrected:  (idNotFound)112  site:  112 pep:  DTVCRHNYGVGESFT
# Q9TQE0 :   corrected:  (idNotFound)131  site:  131 pep:  VHPEVTVYPAKTQPL
# Q9TQE0 :   corrected:  (idNotFound)152  site:  152 pep:  VCSVSGFYPGSIEVR
# Q9TQE0 :   corrected:  (idNotFound)200  site:  200 pep:  VPRSGEVYTCQVEHP
# Q9TQE0 :   corrected:  (idNotFound)249  site:  249 pep:  LGAGLFIYFRNQKGH
# Q9GIY3 :   corrected:  (idNotFound)39  site:  39 pep:  TRPRFLEYSTSECHF
# Q9GIY3 :   corrected:  (idNotFound)59  site:  59 pep:  RVRFLDRYFHNQEEF
# Q9GIY3 :   corrected:  (idNotFound)76  site:  76 pep:  FDSDVGEYRAVTELG
# Q9GIY3 :   corrected:  (idNotFound)107  site:  107 pep:  RRAEVDTYCRHNYGV
# Q9GIY3 :   corrected:  (idNotFound)112  site:  112 pep:  DTYCRHNYGVVESFT
# Q9GIY3 :   corrected:  (idNotFound)131  site:  131 pep:  VHPKVTVYPSKTQPL
# Q9GIY3 :   corrected:  (idNotFound)141  site:  141 pep:  KTQPLQHYNLLVCSV
# Q9GIY3 :   corrected:  (idNotFound)152  site:  152 pep:  VCSVSGFYPGSIEVR
# Q9GIY3 :   corrected:  (idNotFound)200  site:  200 pep:  VPRSGEVYTCQVEHP
# Q9GIY3 :   corrected:  (idNotFound)249  site:  249 pep:  LGAGLFIYFRNQKGH
# Done. Time	266.044
# Formatting  group_10.csv ...
# Reading input file...
# Get unique substrate sites...
# Map unique substrate sites...
# P07203 :   corrected:  (seqNotFound)47  site:  47  seq len:  203 pep:  LLIENVASLGTTVRD
# P07203 :   corrected:  (seqNotFound)50  site:  50  seq len:  203 pep:  ENVASLGTTVRDYTQ
# P07203 :   corrected:  (seqNotFound)51  site:  51  seq len:  203 pep:  NVASLGTTVRDYTQM
# P07203 :   corrected:  (seqNotFound)55  site:  55  seq len:  203 pep:  LGTTVRDYTQMNELQ
# Done. Time	267.639
# Formatting  group_12.csv ...
# Reading input file...
# Get unique substrate sites...
# Map unique substrate sites...
# Done. Time	282.563
# Formatting  group_7.csv ...
# Reading input file...
# Get unique substrate sites...
# Map unique substrate sites...
# P04229 :   corrected:  (idNotFound)10  site:  10 pep:  CLKLPGGSCMTALTV
# P04229 :   corrected:  (idNotFound)13  site:  13 pep:  LPGGSCMTALTVTLM
# P04229 :   corrected:  (idNotFound)16  site:  16 pep:  GSCMTALTVTLMVLS
# P04229 :   corrected:  (idNotFound)18  site:  18 pep:  CMTALTVTLMVLSSP
# P04229 :   corrected:  (idNotFound)23  site:  23 pep:  TVTLMVLSSPLALAG
# P04229 :   corrected:  (idNotFound)24  site:  24 pep:  VTLMVLSSPLALAGD
# P04229 :   corrected:  (idNotFound)32  site:  32 pep:  PLALAGDTRPRFLWQ
# P04229 :   corrected:  (idNotFound)50  site:  50 pep:  ECHFFNGTERVRLLE
# P04229 :   corrected:  (idNotFound)66  site:  66 pep:  CIYNQEESVRFDSDV
# P04229 :   corrected:  (idNotFound)71  site:  71 pep:  EESVRFDSDVGEYRA
# P04229 :   corrected:  (idNotFound)80  site:  80 pep:  VGEYRAVTELGRPDA
# P04229 :   corrected:  (idNotFound)92  site:  92 pep:  PDAEYWNSQKDLLEQ
# P04229 :   corrected:  (idNotFound)106  site:  106 pep:  QRRAAVDTYCRHNYG
# P04229 :   corrected:  (idNotFound)117  site:  117 pep:  HNYGVGESFTVQRRV
# P04229 :   corrected:  (idNotFound)119  site:  119 pep:  YGVGESFTVQRRVEP
# P04229 :   corrected:  (idNotFound)129  site:  129 pep:  RRVEPKVTVYPSKTQ
# P04229 :   corrected:  (idNotFound)133  site:  133 pep:  PKVTVYPSKTQPLQH
# P04229 :   corrected:  (idNotFound)135  site:  135 pep:  VTVYPSKTQPLQHHN
# P04229 :   corrected:  (idNotFound)147  site:  147 pep:  HHNLLVCSVSGFYPG
# P04229 :   corrected:  (idNotFound)149  site:  149 pep:  NLLVCSVSGFYPGSI
# P04229 :   corrected:  (idNotFound)155  site:  155 pep:  VSGFYPGSIEVRWFR
# P04229 :   corrected:  (idNotFound)173  site:  173 pep:  EEKAGVVSTGLIQNG
# P04229 :   corrected:  (idNotFound)174  site:  174 pep:  EKAGVVSTGLIQNGD
# P04229 :   corrected:  (idNotFound)183  site:  183 pep:  LIQNGDWTFQTLVML
# P04229 :   corrected:  (idNotFound)186  site:  186 pep:  NGDWTFQTLVMLETV
# P04229 :   corrected:  (idNotFound)192  site:  192 pep:  QTLVMLETVPRSGEV
# P04229 :   corrected:  (idNotFound)196  site:  196 pep:  MLETVPRSGEVYTCQ
# P04229 :   corrected:  (idNotFound)201  site:  201 pep:  PRSGEVYTCQVEHPS
# P04229 :   corrected:  (idNotFound)208  site:  208 pep:  TCQVEHPSVTSPLTV
# P04229 :   corrected:  (idNotFound)210  site:  210 pep:  QVEHPSVTSPLTVEW
# P04229 :   corrected:  (idNotFound)211  site:  211 pep:  VEHPSVTSPLTVEWR
# P04229 :   corrected:  (idNotFound)214  site:  214 pep:  PSVTSPLTVEWRARS
# P04229 :   corrected:  (idNotFound)221  site:  221 pep:  TVEWRARSESAQSKM
# P04229 :   corrected:  (idNotFound)223  site:  223 pep:  EWRARSESAQSKMLS
# P04229 :   corrected:  (idNotFound)226  site:  226 pep:  ARSESAQSKMLSGVG
# P04229 :   corrected:  (idNotFound)230  site:  230 pep:  SAQSKMLSGVGGFVL
# P04229 :   corrected:  (idNotFound)257  site:  257 pep:  FRNQKGHSGLQPTGF
# P04229 :   corrected:  (idNotFound)262  site:  262 pep:  GHSGLQPTGFLS
# P04229 :   corrected:  (idNotFound)266  site:  266 pep:  LQPTGFLS
# P04229 :   corrected:  (idNotFound)61  site:  61 pep:  RLLERCIYNQEESVR
# P04229 :   corrected:  (idNotFound)76  site:  76 pep:  FDSDVGEYRAVTELG
# P04229 :   corrected:  (idNotFound)89  site:  89 pep:  LGRPDAEYWNSQKDL
# P04229 :   corrected:  (idNotFound)107  site:  107 pep:  RRAAVDTYCRHNYGV
# P04229 :   corrected:  (idNotFound)112  site:  112 pep:  DTYCRHNYGVGESFT
# P04229 :   corrected:  (idNotFound)131  site:  131 pep:  VEPKVTVYPSKTQPL
# P04229 :   corrected:  (idNotFound)152  site:  152 pep:  VCSVSGFYPGSIEVR
# P04229 :   corrected:  (idNotFound)200  site:  200 pep:  VPRSGEVYTCQVEHP
# P04229 :   corrected:  (idNotFound)249  site:  249 pep:  LGAGLFIYFRNQKGH
# P59796 :   corrected:  (seqNotFound)72  site:  72  seq len:  221 pep:  LFVNVAAYGLAAQYP
# P59796 :   corrected:  (seqNotFound)78  site:  78  seq len:  221 pep:  AYGLAAQYPELNALQ
# Done. Time	250.298
# Formatting  group_6.csv ...
# Reading input file...
# Get unique substrate sites...
# Map unique substrate sites...
# Q92813 :   corrected:  (seqNotFound)130  site:  130  seq len:  273 pep:  PLVVNFGSATPPFTS
# Q92813 :   corrected:  (seqNotFound)132  site:  132  seq len:  273 pep:  VVNFGSATPPFTSQL
# Q92813 :   corrected:  (seqNotFound)136  site:  136  seq len:  273 pep:  GSATPPFTSQLPAFR
# Q92813 :   corrected:  (seqNotFound)137  site:  137  seq len:  273 pep:  SATPPFTSQLPAFRK
# Q92813 :   corrected:  (seqNotFound)262  site:  262  seq len:  273 pep:  HWLEKNFSKRKKTRL
# Q92813 :   corrected:  (seqNotFound)267  site:  267  seq len:  273 pep:  NFSKRKKTRLAG
# Done. Time	274.776
# Formatting  group_13.csv ...
# Reading input file...
# Get unique substrate sites...
# Map unique substrate sites...
# P63302 :   corrected:  (seqNotFound)16  site:  16  seq len:  87 pep:  YCGAGYKSKYLQLKK
# Q9BVL4 :   corrected:  (seqNotFound)666  site:  666  seq len:  669 pep:  WAAELCVTSS
# Q9BVL4 :   corrected:  (seqNotFound)667  site:  667  seq len:  669 pep:  AAELCVTSS
# Q9BVL4 :   corrected:  (seqNotFound)668  site:  668  seq len:  669 pep:  AELCVTSS
# P55073 :   corrected:  (seqNotFound)167  site:  167  seq len:  304 pep:  PLVLNFGSCTPPFMA
# P55073 :   corrected:  (seqNotFound)169  site:  169  seq len:  304 pep:  VLNFGSCTPPFMARM
# P49908 :   corrected:  (seqNotFound)58  site:  58  seq len:  381 pep:  VVALLQASYLCILQA
# P49908 :   corrected:  (seqNotFound)292  site:  292  seq len:  381 pep:  LCKLPTDSELAPRSC
# P49908 :   corrected:  (seqNotFound)298  site:  298  seq len:  381 pep:  DSELAPRSCCHCRHL
# P49908 :   corrected:  (seqNotFound)310  site:  310  seq len:  381 pep:  RHLIFEKTGSAITQC
# P49908 :   corrected:  (seqNotFound)312  site:  312  seq len:  381 pep:  LIFEKTGSAITQCKE
# P49908 :   corrected:  (seqNotFound)315  site:  315  seq len:  381 pep:  EKTGSAITQCKENLP
# P49908 :   corrected:  (seqNotFound)323  site:  323  seq len:  381 pep:  QCKENLPSLCSQGLR
# P49908 :   corrected:  (seqNotFound)326  site:  326  seq len:  381 pep:  ENLPSLCSQGLRAEE
# P49908 :   corrected:  (seqNotFound)336  site:  336  seq len:  381 pep:  LRAEENITESCQRLP
# P49908 :   corrected:  (seqNotFound)338  site:  338  seq len:  381 pep:  AEENITESCQRLPPA
# P49908 :   corrected:  (seqNotFound)349  site:  349  seq len:  381 pep:  LPPAAQISQQLIPTE
# P49908 :   corrected:  (seqNotFound)355  site:  355  seq len:  381 pep:  ISQQLIPTEASASRK
# P49908 :   corrected:  (seqNotFound)358  site:  358  seq len:  381 pep:  QLIPTEASASRKNQA
# P49908 :   corrected:  (seqNotFound)360  site:  360  seq len:  381 pep:  IPTEASASRKNQAKK
# P49908 :   corrected:  (seqNotFound)370  site:  370  seq len:  381 pep:  NQAKKEPSN
# Q99611 :   corrected:  (seqNotFound)55  site:  55  seq len:  448 pep:  SWRLTGFSGMKGGCK
# P63302 :   corrected:  (seqNotFound)9  site:  9  seq len:  87 pep:  ALAVRVVYCGAGYKS
# P63302 :   corrected:  (seqNotFound)14  site:  14  seq len:  87 pep:  VVYCGAGYKSKYLQL
# P63302 :   corrected:  (seqNotFound)18  site:  18  seq len:  87 pep:  GAGYKSKYLQLKKKL
# P49908 :   corrected:  (seqNotFound)59  site:  59  seq len:  381 pep:  VALLQASYLCILQAS
# Done. Time	268.268

# %% [markdown]
# **Remove unmapped/outdated results**
# - Check if there is any unmapped substrate/site due to outdated uniprot sequence records
#     - get a list of outdated uniprotID

# %%
all_results = glob.glob(GPS_temp_dir_site + '*.csv')
    
updatedSub_li = []
for filename in all_results:
    start = time.time() 
    df_unmapped = pd.read_csv(filename, usecols = ['substrate_id','substrate_acc', 'mapped site'])
    # if the mapped site is not S/T/Y
    df_unmapped = df_unmapped[~(df_unmapped['mapped site'].str.contains('S|T|Y', na=False)) | (df_unmapped['substrate_id'] == 'outdated')]
    df_unmapped = df_unmapped.substrate_acc.drop_duplicates()
    unmapped_li = df_unmapped.values.tolist()
    updatedSub_li.extend(unmapped_li)
    end = time.time()
    print (f"Time\t{(end-start):.3f}")
updatedSub_li
# Out:
# Time	0.297
# Time	9.753
# Time	26.570
# Time	25.189
# Time	26.773
# Time	27.444
# Time	28.355
# Time	27.789
# Time	27.169
# Time	26.256
# Time	27.105
# Time	25.683
# Time	27.346
# Time	26.498
# Time	28.012
# Time	28.322
# Time	28.491
# Time	28.384
# Time	29.279
# Time	25.995
# Time	28.823
# Time	27.255
# ['Q29974',
#  'P01160',
#  'Q95IE3',
#  'Q30167',
#  'P49895',
#  'P13760',
#  'P01912',
#  'Q16881',
#  'P13761',
#  'Q5Y7A7',
#  'P22352',
#  'P36969',
#  'Q9C0D9',
#  'Q9BQE4',
#  'Q86VQ6',
#  'P59797',
#  'P62341',
#  'Q9NZV6',
#  'Q9NZV5',
#  'Q8IZQ5',
#  'Q06124',
#  'Q9NNW7',
#  'Q8WWX9',
#  'Q6QHF9',
#  'P18283',
#  'Q30134',
#  'P20039',
#  'Q9TQE0',
#  'Q9GIY3',
#  'P07203',
#  'P04229',
#  'P59796',
#  'Q92813',
#  'P63302',
#  'Q9BVL4',
#  'P55073',
#  'P49908',
#  'Q99611']

# %%
all_results = glob.glob(GPS_temp_dir_site + '*.csv')

for filename in all_results:
    start = time.time()
    df_mapSite = pd.read_csv(filename)
    # remove the outdated records from df_subMap
    df_update = df_mapSite[~df_mapSite['substrate_acc'].isin(updatedSub_li)]
    df_update.to_csv(filename, chunksize=100000, index=False)
    end = time.time()
    print (f"chunk time\t{(end-start):.3f}")
# Out:
# chunk time	0.340
# chunk time	48.055
# chunk time	136.465
# chunk time	143.126
# chunk time	154.167
# chunk time	162.273
# chunk time	167.112
# chunk time	165.188
# chunk time	160.292
# chunk time	152.254
# chunk time	159.712
# chunk time	152.817
# chunk time	161.710
# chunk time	153.559
# chunk time	165.560
# chunk time	169.556
# chunk time	168.166
# chunk time	165.006
# chunk time	173.175
# chunk time	154.519
# chunk time	170.991
# chunk time	165.149

# %% [markdown]
# ### Update GPS results
# - The next 6 cells is only for NetworKIN results from outdated Human Proteomes sequences (input sequences for GPS prediction an earlier version than the referece human proteome sequence)

# %% [markdown]
# 1. download the sequence fasta file of the above UniprotID (updatedSub_li) from Uniprot.org, save it as '../Data/Raw/HumanProteome/GPS_updateSub.fasta'. Submit the 'GPS_updateSub.fasta' in GPS again
# 2. run gps_convert.gps_convert_directory for accession conversion and site mapping for the result file from 'GPS_updateSub.fasta'

# %%
convert_type = 'acc'
gps_convert.gps_convert_directory(GPS_update_dir, GPS_kinase, GPS_temp_dir_acc_update, convert_type)
# Out:
# Formatting  GPS5_updateSub ...
# Done. Time	3.313

# %%
convert_type = 'site'
gps_convert.gps_convert_directory(GPS_temp_dir_acc_update, HP_csv, GPS_temp_dir_site_update, convert_type)
# Out:
# Formatting  GPS5_updateSub.csv ...
# Reading input file...
# Get unique substrate sites...
# Map unique substrate sites...
# P49895 :   corrected:  (seqNotFound)123  site:  123  seq len:  249 pep:  PLVLNFGSCTPSFMF
# P49895 :   corrected:  (seqNotFound)125  site:  125  seq len:  249 pep:  VLNFGSCTPSFMFKF
# P49895 :   corrected:  (seqNotFound)127  site:  127  seq len:  249 pep:  NFGSCTPSFMFKFDQ
# Q16881 :   corrected:  (seqNotFound)641  site:  641  seq len:  649 pep:  VTKRSGASILQAGCG
# P22352 :   corrected:  (seqNotFound)71  site:  71  seq len:  226 pep:  VLFVNVASYGLTGQY
# P22352 :   corrected:  (seqNotFound)75  site:  75  seq len:  226 pep:  NVASYGLTGQYIELN
# P36969 :   corrected:  (seqNotFound)67  site:  67  seq len:  197 pep:  RGFVCIVTNVASQGK
# P36969 :   corrected:  (seqNotFound)71  site:  71  seq len:  197 pep:  CIVTNVASQGKTEVN
# P36969 :   corrected:  (seqNotFound)75  site:  75  seq len:  197 pep:  NVASQGKTEVNYTQL
# Q9C0D9 :   corrected:  (seqNotFound)385  site:  385  seq len:  397 pep:  FSLRKPNSDLGMEEK
# Q9BQE4 :   corrected:  (seqNotFound)184  site:  184  seq len:  189 pep:  RPGRRGPSSGGG
# Q9BQE4 :   corrected:  (seqNotFound)185  site:  185  seq len:  189 pep:  PGRRGPSSGGG
# Q86VQ6 :   corrected:  (seqNotFound)637  site:  637  seq len:  643 pep:  KSSGLDITQKGCG
# P59797 :   corrected:  (seqNotFound)268  site:  268  seq len:  346 pep:  KRVLIRVTYCGLSYS
# P59797 :   corrected:  (seqNotFound)273  site:  273  seq len:  346 pep:  RVTYCGLSYSLRYIL
# P59797 :   corrected:  (seqNotFound)275  site:  275  seq len:  346 pep:  TYCGLSYSLRYILLK
# P62341 :   corrected:  (seqNotFound)48  site:  48  seq len:  195 pep:  LKFQICVSGYRRVFE
# Q9NZV6 :   corrected:  (seqNotFound)92  site:  92  seq len:  116 pep:  DGPKPGQSRFIFSSS
# Q9NZV6 :   corrected:  (seqNotFound)97  site:  97  seq len:  116 pep:  GQSRFIFSSSLKFVP
# Q9NZV6 :   corrected:  (seqNotFound)98  site:  98  seq len:  116 pep:  QSRFIFSSSLKFVPK
# Q9NZV6 :   corrected:  (seqNotFound)99  site:  99  seq len:  116 pep:  SRFIFSSSLKFVPKG
# Q9NZV5 :   corrected:  (seqNotFound)127  site:  127  seq len:  590 pep:  PQLPWLNSSCLSLLR
# Q9NZV5 :   corrected:  (seqNotFound)128  site:  128  seq len:  590 pep:  QLPWLNSSCLSLLRS
# Q9NZV5 :   corrected:  (seqNotFound)131  site:  131  seq len:  590 pep:  WLNSSCLSLLRSTPA
# Q9NZV5 :   corrected:  (seqNotFound)459  site:  459  seq len:  590 pep:  WGALDDQSCGSGRTL
# Q9NZV5 :   corrected:  (seqNotFound)462  site:  462  seq len:  590 pep:  LDDQSCGSGRTLRET
# Q9NZV5 :   corrected:  (seqNotFound)465  site:  465  seq len:  590 pep:  QSCGSGRTLRETVLE
# Q8IZQ5 :   corrected:  (seqNotFound)42  site:  42  seq len:  122 pep:  TVVIEHCTSRVYGRN
# Q8IZQ5 :   corrected:  (seqNotFound)43  site:  43  seq len:  122 pep:  VVIEHCTSRVYGRNA
# Q9NNW7 :   corrected:  (seqNotFound)518  site:  518  seq len:  524 pep:  KRSGLDPTVTGCG
# Q9NNW7 :   corrected:  (seqNotFound)520  site:  520  seq len:  524 pep:  SGLDPTVTGCG
# Q8WWX9 :   corrected:  (seqNotFound)44  site:  44  seq len:  145 pep:  LTRARVETCGGQLNR
# P18283 :   corrected:  (seqNotFound)38  site:  38  seq len:  190 pep:  VLIENVASLGTTTRD
# P18283 :   corrected:  (seqNotFound)41  site:  41  seq len:  190 pep:  ENVASLGTTTRDFTQ
# P18283 :   corrected:  (seqNotFound)42  site:  42  seq len:  190 pep:  NVASLGTTTRDFTQL
# P18283 :   corrected:  (seqNotFound)43  site:  43  seq len:  190 pep:  VASLGTTTRDFTQLN
# P07203 :   corrected:  (seqNotFound)47  site:  47  seq len:  203 pep:  LLIENVASLGTTVRD
# P07203 :   corrected:  (seqNotFound)50  site:  50  seq len:  203 pep:  ENVASLGTTVRDYTQ
# P07203 :   corrected:  (seqNotFound)51  site:  51  seq len:  203 pep:  NVASLGTTVRDYTQM
# Q92813 :   corrected:  (seqNotFound)130  site:  130  seq len:  273 pep:  PLVVNFGSATPPFTS
# Q92813 :   corrected:  (seqNotFound)132  site:  132  seq len:  273 pep:  VVNFGSATPPFTSQL
# Q92813 :   corrected:  (seqNotFound)136  site:  136  seq len:  273 pep:  GSATPPFTSQLPAFR
# Q92813 :   corrected:  (seqNotFound)137  site:  137  seq len:  273 pep:  SATPPFTSQLPAFRK
# Q92813 :   corrected:  (seqNotFound)262  site:  262  seq len:  273 pep:  HWLEKNFSKRKKTRL
# Q92813 :   corrected:  (seqNotFound)267  site:  267  seq len:  273 pep:  NFSKRKKTRLAG
# P63302 :   corrected:  (seqNotFound)16  site:  16  seq len:  87 pep:  YCGAGYKSKYLQLKK
# Q9BVL4 :   corrected:  (seqNotFound)666  site:  666  seq len:  669 pep:  WAAELCVTSS
# Q9BVL4 :   corrected:  (seqNotFound)667  site:  667  seq len:  669 pep:  AAELCVTSS
# Q9BVL4 :   corrected:  (seqNotFound)668  site:  668  seq len:  669 pep:  AELCVTSS
# P55073 :   corrected:  (seqNotFound)167  site:  167  seq len:  304 pep:  PLVLNFGSCTPPFMA
# P55073 :   corrected:  (seqNotFound)169  site:  169  seq len:  304 pep:  VLNFGSCTPPFMARM
# P49908 :   corrected:  (seqNotFound)58  site:  58  seq len:  381 pep:  VVALLQASYLCILQA
# P49908 :   corrected:  (seqNotFound)292  site:  292  seq len:  381 pep:  LCKLPTDSELAPRSC
# P49908 :   corrected:  (seqNotFound)298  site:  298  seq len:  381 pep:  DSELAPRSCCHCRHL
# P49908 :   corrected:  (seqNotFound)310  site:  310  seq len:  381 pep:  RHLIFEKTGSAITQC
# P49908 :   corrected:  (seqNotFound)312  site:  312  seq len:  381 pep:  LIFEKTGSAITQCKE
# P49908 :   corrected:  (seqNotFound)315  site:  315  seq len:  381 pep:  EKTGSAITQCKENLP
# P49908 :   corrected:  (seqNotFound)323  site:  323  seq len:  381 pep:  QCKENLPSLCSQGLR
# P49908 :   corrected:  (seqNotFound)326  site:  326  seq len:  381 pep:  ENLPSLCSQGLRAEE
# P49908 :   corrected:  (seqNotFound)336  site:  336  seq len:  381 pep:  LRAEENITESCQRLP
# P49908 :   corrected:  (seqNotFound)338  site:  338  seq len:  381 pep:  AEENITESCQRLPPA
# P49908 :   corrected:  (seqNotFound)349  site:  349  seq len:  381 pep:  LPPAAQISQQLIPTE
# P49908 :   corrected:  (seqNotFound)355  site:  355  seq len:  381 pep:  ISQQLIPTEASASRK
# P49908 :   corrected:  (seqNotFound)358  site:  358  seq len:  381 pep:  QLIPTEASASRKNQA
# P49908 :   corrected:  (seqNotFound)360  site:  360  seq len:  381 pep:  IPTEASASRKNQAKK
# P49908 :   corrected:  (seqNotFound)370  site:  370  seq len:  381 pep:  NQAKKEPSN
# Q99611 :   corrected:  (seqNotFound)55  site:  55  seq len:  448 pep:  SWRLTGFSGMKGGCK
# P22352 :   corrected:  (seqNotFound)72  site:  72  seq len:  226 pep:  LFVNVASYGLTGQYI
# P22352 :   corrected:  (seqNotFound)78  site:  78  seq len:  226 pep:  SYGLTGQYIELNALQ
# P36969 :   corrected:  (seqNotFound)79  site:  79  seq len:  197 pep:  QGKTEVNYTQLVDLH
# P59797 :   corrected:  (seqNotFound)269  site:  269  seq len:  346 pep:  RVLIRVTYCGLSYSL
# P59797 :   corrected:  (seqNotFound)274  site:  274  seq len:  346 pep:  VTYCGLSYSLRYILL
# P59797 :   corrected:  (seqNotFound)278  site:  278  seq len:  346 pep:  GLSYSLRYILLKKSL
# P62341 :   corrected:  (seqNotFound)50  site:  50  seq len:  195 pep:  FQICVSGYRRVFEEY
# Q8IZQ5 :   corrected:  (seqNotFound)46  site:  46  seq len:  122 pep:  EHCTSRVYGRNAAAL
# P07203 :   corrected:  (seqNotFound)55  site:  55  seq len:  203 pep:  LGTTVRDYTQMNELQ
# P59796 :   corrected:  (seqNotFound)72  site:  72  seq len:  221 pep:  LFVNVAAYGLAAQYP
# P59796 :   corrected:  (seqNotFound)78  site:  78  seq len:  221 pep:  AYGLAAQYPELNALQ
# P63302 :   corrected:  (seqNotFound)9  site:  9  seq len:  87 pep:  ALAVRVVYCGAGYKS
# P63302 :   corrected:  (seqNotFound)14  site:  14  seq len:  87 pep:  VVYCGAGYKSKYLQL
# P63302 :   corrected:  (seqNotFound)18  site:  18  seq len:  87 pep:  GAGYKSKYLQLKKKL
# P49908 :   corrected:  (seqNotFound)59  site:  59  seq len:  381 pep:  VALLQASYLCILQAS
# Done. Time	3.890

# %% [markdown]
# 3. save 'GPS_updateSub.csv' under the same dir as other mapped site files
#     - GPS ignorgs the 'U'(Selenocysteine) in some substrate sequences, this causes frame shift of the downstream sequences
#     - those unmapped sites will not be included

# %%
df_mapUpdateSite = pd.read_csv(GPS_temp_dir_site_update + 'GPS_updateSub.csv')
df_mapUpdateSite = df_mapUpdateSite[(df_mapUpdateSite['mapped site'].str.contains('S|T|Y', na=False)) & (df_mapUpdateSite['substrate_id'] != 'outdated')]
df_mapUpdateSite.to_csv(GPS_temp_dir_site + 'GPS_updateSub.csv')

df_mapUpdateSite
# Out:
#        substrate_acc  site residue  position                 predictor kinase  \
# 0             P01160    S2       S         2              AGC/Akt/AKT1   AKT1
# 1             P01160    S3       S         3              AGC/Akt/AKT1   AKT1
# 2             P01160    S5       S         5              AGC/Akt/AKT1   AKT1
# 3             P01160    T6       T         6              AGC/Akt/AKT1   AKT1
# 4             P01160    T7       T         7              AGC/Akt/AKT1   AKT1
# ...              ...   ...     ...       ...                       ...    ...
# 288317        Q99611  Y140       Y       140  Dual/Other/WEE/WEE1/WEE1   WEE1
# 288318        Q99611  Y147       Y       147  Dual/Other/WEE/WEE1/WEE1   WEE1
# 288319        Q99611  Y162       Y       162  Dual/Other/WEE/WEE1/WEE1   WEE1
# 288320        Q99611  Y287       Y       287  Dual/Other/WEE/WEE1/WEE1   WEE1
# 288321        Q99611  Y394       Y       394  Dual/Other/WEE/WEE1/WEE1   WEE1
#
#        kinase_acc              pep   score  threshold mapped site substrate_id
# 0          P31749  ______MSSFSTTTV -14.300        NaN          S2     P01160_2
# 1          P31749  _____MSSFSTTTVS -12.700        NaN          S3     P01160_3
# 2          P31749  ___MSSFSTTTVSFL  -0.567        NaN          S5     P01160_5
# 3          P31749  __MSSFSTTTVSFLL   4.387        NaN          T6     P01160_6
# 4          P31749  _MSSFSTTTVSFLLL   7.142        NaN          T7     P01160_7
# ...           ...              ...     ...        ...         ...          ...
# 288317     P30291  VQTTDFFYPLVEDPY  -0.525        NaN        Y141   Q99611_141
# 288318     P30291  YPLVEDPYMMGRIAC   1.424        NaN        Y148   Q99611_148
# 288319     P30291  ANVLSDLYAMGITEC  -0.275        NaN        Y163   Q99611_163
# 288320     P30291  REEVELAYQEAMFNM   0.302        NaN        Y288   Q99611_288
# 288321     P30291  SEIKSSKYGEGHQAW   1.769        NaN        Y395   Q99611_395
#
# [270016 rows x 12 columns]

# %% [markdown]
# ### Get the Gene Name of the Substrates from the Reference Human Proteome
# - get and add the Gene Name that would use across all perdictors for the substrates to the result files

# %%
# get the protein gene names and accessions from the Reference Human Proteome
df_unique_sub = pd.read_csv(HP_csv, usecols = ['UniprotID','Gene Name'], sep = '\t')
df_unique_sub
# Out:
#       Gene Name   UniprotID
# 0         ACTN1      P12814
# 1         STAT3      P40763
# 2          ADD1      P35611
# 3          ADD2      P35612
# 4        ADRA2A      P08913
# ...         ...         ...
# 20358     HSFX4  A0A1B0GTS1
# 20359   TRBJ2-6  A0A0A0MT70
# 20360  TMEM225B      P0DP42
# 20361    SMIM29      Q86T20
# 20362    SCYGR6  A0A286YF77
#
# [20363 rows x 2 columns]

# %%
# add the Gene Name that would use across all perdictors for the substrates to the result files
all_results = glob.glob(GPS_temp_dir_site + '*.csv')

for filename in all_results:
    df = pd.read_csv(filename, usecols = ['substrate_id', 'substrate_acc', 'mapped site', 'predictor', 'kinase', 'kinase_acc', 'pep', 'score'])
    # merge df_subsMap with df_unique_sub to add the common substrate gene name to the df
    df = df.merge(df_unique_sub, left_on=['substrate_acc'], right_on=['UniprotID'], how = 'left')

    df = df.drop(columns = ['UniprotID'])
    df.to_csv(filename, index=False)
df
# Out:
#          substrate_acc                 predictor kinase kinase_acc  \
# 0               Q9Y6J8              AGC/Akt/AKT1   AKT1     P31749
# 1               Q9Y6J8              AGC/Akt/AKT1   AKT1     P31749
# 2               Q9Y6J8              AGC/Akt/AKT1   AKT1     P31749
# 3               Q9Y6J8              AGC/Akt/AKT1   AKT1     P31749
# 4               Q9Y6J8              AGC/Akt/AKT1   AKT1     P31749
# ...                ...                       ...    ...        ...
# 20762757        Q9HA92  Dual/Other/WEE/WEE1/WEE1   WEE1     P30291
# 20762758        Q9HA92  Dual/Other/WEE/WEE1/WEE1   WEE1     P30291
# 20762759        Q9HA92  Dual/Other/WEE/WEE1/WEE1   WEE1     P30291
# 20762760        Q9HA92  Dual/Other/WEE/WEE1/WEE1   WEE1     P30291
# 20762761        Q9HA92  Dual/Other/WEE/WEE1/WEE1   WEE1     P30291
#
#                       pep  score mapped site substrate_id Gene Name
# 0         GLLLCEPTELYNILN  7.126         T10    Q9Y6J8_10    STYXL1
# 1         YNILNQATKLSRLTD  2.233         T20    Q9Y6J8_20    STYXL1
# 2         LNQATKLSRLTDPNY  4.664         S23    Q9Y6J8_23    STYXL1
# 3         ATKLSRLTDPNYLCL  4.142         T26    Q9Y6J8_26    STYXL1
# 4         LCLLDVRSKWEYDES  2.135         S38    Q9Y6J8_38    STYXL1
# ...                   ...    ...         ...          ...       ...
# 20762757  CDDHLSLYQLSLERG  0.400        Y226   Q9HA92_226     RSAD1
# 20762758  PELAAEMYQRGRAVL -0.158        Y257   Q9HA92_257     RSAD1
# 20762759  REAGFHQYEVSNFAR  0.464        Y272   Q9HA92_272     RSAD1
# 20762760  LSTHNWTYWQCGQYL  0.479        Y290   Q9HA92_290     RSAD1
# 20762761  TYWQCGQYLGVGPGA -0.565        Y296   Q9HA92_296     RSAD1
#
# [20762762 rows x 9 columns]

# %% [markdown]
# ### Creating Resource Files
# **globalKinaseMap**
# - creat a new or add unique kinases from NetworKIN to the globel kinase resource file.
# - get and add the Kinase Name that would use across all perdictors for the kinases to the result files

# %%
# get unique kinases in the NetworKIN result files

all_results = glob.glob(GPS_temp_dir_site + '*.csv')

df_unique_kin = pd.DataFrame()

for filename in all_results:
    df = pd.read_csv(filename, usecols = ['kinase_acc', 'kinase'])
    df = df.drop_duplicates()
    df_unique_kin = df_unique_kin.append(df, ignore_index=True)
    
df_unique_kin = df_unique_kin.drop_duplicates()
df_unique_kin
# Out:
#       kinase kinase_acc
# 0       AKT1     P31749
# 1       AKT2     P31751
# 2       AKT3     Q9Y243
# 3      PDPK1     O15530
# 4      PKACA     P17612
# ..       ...        ...
# 321      LYN     P07948
# 322    BAZ1B     Q9UIG0
# 323  CSNK2A1     P68400
# 324    WEE1B     P0C1S8
# 325     WEE1     P30291
#
# [326 rows x 2 columns]

# %%
unmapped_list = pd.DataFrame()

if os.path.isfile(KinaseMap): 
    df_humanKinase = pd.read_csv(KinaseMap)
# if globalkinaseMap.csv file does not exist, create an new df using orginal human kinase map
else:
    df_humanKinase = pd.read_csv(HK_org, usecols = ['Kinase Name', 'Preferred Name', 'UniprotID', 'Type', 'description'], sep = '\t')
    df_humanKinase['description'].replace(regex=True,inplace=True,to_replace=r'\[Source.+\]',value=r'')

for index, row in df_unique_kin.iterrows():
    kinase = df_unique_kin.at[index, 'kinase_acc']
    # if the kinase/other enzyme already in the globalKinaseMap.csv file
    if any(df_humanKinase['UniprotID'] == kinase):
        # get the index of the substrate in the globalKinaseMap.csv file 
        idx = df_humanKinase.index[df_humanKinase.UniprotID == kinase].values[0] 

        df_humanKinase.at[idx, 'GPS5_kinase_name'] = df_unique_kin.at[index, 'kinase']
        
    # if the kinase is not in the globalSubstrateMap.csv file, we need a list to check annotations manullay
    else:
        unmapped_list = unmapped_list.append(row,sort=False).reset_index(drop=True)
        
print (unmapped_list)
    
df_humanKinase
# Out:
#     Kinase Name Preferred Name UniprotID         Type  \
# 0          AAK1           AAK1    Q2M2I8      Pkinase
# 1          ABL1           ABL1    P00519  Pkinase_tyr
# 2          ABL2           ABL2    P42684  Pkinase_tyr
# 3         ACVR1          ACVR1    Q04771      Pkinase
# 4        ACVR1B         ACVR1B    P36896      Pkinase
# ..          ...            ...       ...          ...
# 484        WNK2           WNK2    Q9Y3S1      Pkinase
# 485        WNK3           WNK3    Q9BYP7      Pkinase
# 486        WNK4           WNK4    Q96J92      Pkinase
# 487        YES1           YES1    P07947  Pkinase_tyr
# 488       ZAP70          ZAP70    P43403  Pkinase_tyr
#
#                                            description GPS5_kinase_name  \
# 0                             AP2 associated kinase 1              AAK1
# 1    ABL proto-oncogene 1, non-receptor tyrosine ki...             ABL1
# 2    ABL proto-oncogene 2, non-receptor tyrosine ki...             ABL2
# 3                           activin A receptor type 1               NaN
# 4                          activin A receptor type 1B               NaN
# ..                                                 ...              ...
# 484             WNK lysine deficient protein kinase 2              WNK2
# 485             WNK lysine deficient protein kinase 3              WNK3
# 486             WNK lysine deficient protein kinase 4              WNK4
# 487  YES proto-oncogene 1, Src family tyrosine kinase              YES1
# 488  zeta chain of T cell receptor associated prote...            ZAP70
#
#     NetworKIN_kinase_name PhosphoPICK_kinase_name
# 0                     NaN                     NaN
# 1                    ABL1                    ABL1
# 2                    ABL2                    ABL2
# 3                     NaN                     NaN
# 4                     NaN                     NaN
# ..                    ...                     ...
# 484                   NaN                     NaN
# 485                   NaN                     NaN
# 486                   NaN                     NaN
# 487                  YES1                     NaN
# 488                   NaN                     NaN
#
# [489 rows x 8 columns]

# %% [markdown]
# - After manully searched in uniprot records for the aboved 7 unmapped kinases/enzymes, 1 is annotated as protein kinase. These are added to the final **globalKinaseMap.csv**. The other 5 that are not protein kinase are removed from the **df_kinaseMap**.

# %%
not_kinase = ['PDK2', 'PDK3', 'PDK4', 'MSN', 'GTF2F1', 'MPS1']

new_kinase = {'BCKDK':'[3-methyl-2-oxobutanoate dehydrogenase [lipoamide]] kinase, mitochondrial'}

# %% [markdown]
# - add the 1 protein kinases to the globalKinaseMap.csv using above dictionary

# %%
# get the length (last index) of the current df_humanKinase
len = df_humanKinase.UniprotID.count()

# add the 16 new kinase in the globalKinaseMap.csv
for key in new_kinase:
    # add the kinase name and description for the new kinase 
    df_humanKinase = df_humanKinase.append({'Kinase Name': key}, ignore_index=True)
    df_humanKinase.at[len,'Preferred Name'] = key
    df_humanKinase.at[len,'description'] = new_kinase[key]
    # get the index of where the new kinase is in the df_unique_kinase
    i = df_unique_kinase.index[df_unique_kinase['kinase'] == key].values[0] 
    # add the uniprotID for the new kinase 
    df_humanKinase.at[len,'UniprotID'] = df_unique_kinase.at[i, 'kinase_acc']
    # add the accs used in HPRD for the new kinase
    df_humanKinase.at[len,'GPS5_kinase_name'] = df_unique_kinase.at[i, 'kinase']
    
    len += 1
    
df_humanKinase.to_csv(KinaseMap,index=False) 
df_humanKinase
# Out:
#     Kinase Name Preferred Name UniprotID         Type  \
# 0          AAK1           AAK1    Q2M2I8      Pkinase
# 1          ABL1           ABL1    P00519  Pkinase_tyr
# 2          ABL2           ABL2    P42684  Pkinase_tyr
# 3         ACVR1          ACVR1    Q04771      Pkinase
# 4        ACVR1B         ACVR1B    P36896      Pkinase
# ..          ...            ...       ...          ...
# 484        WNK2           WNK2    Q9Y3S1      Pkinase
# 485        WNK3           WNK3    Q9BYP7      Pkinase
# 486        WNK4           WNK4    Q96J92      Pkinase
# 487        YES1           YES1    P07947  Pkinase_tyr
# 488       ZAP70          ZAP70    P43403  Pkinase_tyr
#
#                                            description GPS5_kinase_name  \
# 0                             AP2 associated kinase 1              AAK1
# 1    ABL proto-oncogene 1, non-receptor tyrosine ki...             ABL1
# 2    ABL proto-oncogene 2, non-receptor tyrosine ki...             ABL2
# 3                           activin A receptor type 1               NaN
# 4                          activin A receptor type 1B               NaN
# ..                                                 ...              ...
# 484             WNK lysine deficient protein kinase 2              WNK2
# 485             WNK lysine deficient protein kinase 3              WNK3
# 486             WNK lysine deficient protein kinase 4              WNK4
# 487  YES proto-oncogene 1, Src family tyrosine kinase              YES1
# 488  zeta chain of T cell receptor associated prote...            ZAP70
#
#     NetworKIN_kinase_name PhosphoPICK_kinase_name
# 0                     NaN                     NaN
# 1                    ABL1                    ABL1
# 2                    ABL2                    ABL2
# 3                     NaN                     NaN
# 4                     NaN                     NaN
# ..                    ...                     ...
# 484                   NaN                     NaN
# 485                   NaN                     NaN
# 486                   NaN                     NaN
# 487                  YES1                     NaN
# 488                   NaN                     NaN
#
# [489 rows x 8 columns]

# %%
# get the new list kinase with common kinase name that would use across all referece and the uniprotID for these kinase
df_unique_kin = df_humanKinase[['Kinase Name','UniprotID']]
df_unique_kin
# Out:
#     Kinase Name UniprotID
# 0          SGK1    O00141
# 1        BMPR1B    O00238
# 2          CDC7    O00311
# 3          PLK4    O00444
# 4         STK25    O00506
# ..          ...       ...
# 484      TP53RK    Q96S44
# 485       TRPM6    Q9BX84
# 486     BCR/ABL    A9UF07
# 487       BCKDK    O14874
# 488       EPHB6    O15197
#
# [489 rows x 2 columns]

# %% [markdown]
# - remove the 6 enzyme records that are not protein kinase from the df_kinaseMap
# - add the Kinase Name that would use across all perdictors for the kinase to the result files

# %%
all_results = glob.glob(GPS_temp_dir_site + '*.csv')

for filename in all_results:
    df = pd.read_csv(filename)
    # remove the 4 enzyme records that are not protein kinase from the df_kinaseMap
    df = df[~df['kinase'].isin(not_kinase)]

    # merge with df_unique_kinase to add the common kinase name to the df
    df = df.merge(df_unique_kin, left_on='kinase_acc', right_on='UniprotID', how = 'left')
    # drop the duplicated uniprot id for kinases
    df = df.drop(columns = 'UniprotID')

    df.to_csv(filename,index=False)  

df
# Out:
#          substrate_acc                 predictor kinase kinase_acc  \
# 0               Q9Y6J8              AGC/Akt/AKT1   AKT1     P31749
# 1               Q9Y6J8              AGC/Akt/AKT1   AKT1     P31749
# 2               Q9Y6J8              AGC/Akt/AKT1   AKT1     P31749
# 3               Q9Y6J8              AGC/Akt/AKT1   AKT1     P31749
# 4               Q9Y6J8              AGC/Akt/AKT1   AKT1     P31749
# ...                ...                       ...    ...        ...
# 20303283        Q9HA92  Dual/Other/WEE/WEE1/WEE1   WEE1     P30291
# 20303284        Q9HA92  Dual/Other/WEE/WEE1/WEE1   WEE1     P30291
# 20303285        Q9HA92  Dual/Other/WEE/WEE1/WEE1   WEE1     P30291
# 20303286        Q9HA92  Dual/Other/WEE/WEE1/WEE1   WEE1     P30291
# 20303287        Q9HA92  Dual/Other/WEE/WEE1/WEE1   WEE1     P30291
#
#                       pep  score mapped site substrate_id Gene Name  \
# 0         GLLLCEPTELYNILN  7.126         T10    Q9Y6J8_10    STYXL1
# 1         YNILNQATKLSRLTD  2.233         T20    Q9Y6J8_20    STYXL1
# 2         LNQATKLSRLTDPNY  4.664         S23    Q9Y6J8_23    STYXL1
# 3         ATKLSRLTDPNYLCL  4.142         T26    Q9Y6J8_26    STYXL1
# 4         LCLLDVRSKWEYDES  2.135         S38    Q9Y6J8_38    STYXL1
# ...                   ...    ...         ...          ...       ...
# 20303283  CDDHLSLYQLSLERG  0.400        Y226   Q9HA92_226     RSAD1
# 20303284  PELAAEMYQRGRAVL -0.158        Y257   Q9HA92_257     RSAD1
# 20303285  REAGFHQYEVSNFAR  0.464        Y272   Q9HA92_272     RSAD1
# 20303286  LSTHNWTYWQCGQYL  0.479        Y290   Q9HA92_290     RSAD1
# 20303287  TYWQCGQYLGVGPGA -0.565        Y296   Q9HA92_296     RSAD1
#
#          Kinase Name
# 0               AKT1
# 1               AKT1
# 2               AKT1
# 3               AKT1
# 4               AKT1
# ...              ...
# 20303283        WEE1
# 20303284        WEE1
# 20303285        WEE1
# 20303286        WEE1
# 20303287        WEE1
#
# [20303288 rows x 10 columns]

# %% [markdown]
# # Standard Formatted GPS
# ### 'GPS_formatted.csv'
# Standardize the preprocessed file with following columns:
# - **substrate_id** - unique IDs for the substrate phosphorylation site (substrate_acc + position)
# - **substrate_name** - gene name for the substrates
# - **substrate_acc** - mapped UniprotIDs for the substrates
# - **site** - phosphorylation  site
# - **pep** - +/- 7 AA peptide sequence around the site
# - **score** - perdiction score
# - **Kinase Name** - Kinase name

# %%
all_results = glob.glob(GPS_temp_dir_site + '*.csv')
GPS = []
for filename in all_results:
    df = pd.read_csv(filename, usecols = ['substrate_id','substrate_acc','Gene Name', 'mapped site','pep', 'score', 'Kinase Name'])
    df = df.rename(columns={'Gene Name': 'substrate_name', 'mapped site' : 'site'})

    if not os.path.isfile(GPS_formatted):
        df.to_csv(GPS_formatted, mode='a', index=False, sep=',')
    else:
        df.to_csv(GPS_formatted, mode='a', index=False, sep=',', header=False)

# %%
df_final = pd.read_csv(GPS_formatted)
df_final = df_final.drop_duplicates()
df_final.to_csv(GPS_formatted, chunksize = 1000000, index = False)
